# %% [markdown]
# <center><b><u><h1><font color = 'orange'> Cab-Driver Agent </h1></u></b></center>

# %%
# Importing libraries
import numpy as np
import random
import math
from collections import deque
import collections
import pickle
import time

# for building DQN model
from keras import layers
from keras import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

# for plotting graphs
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# source file directory
file_path = r'D:\Assignment'

# %%
import sys
sys.path.append(file_path)

# %%
# Import the environment
# Note: Env.py file should be availabe in file_path (r'D:\Assignment') directory
from Env import CabDriver

# %% [markdown]
# <b><h3><font color = 'green'> 1. Load the Time Matrix </h3></b>

# %%
# Loading the time matrix provided
# Note: TM.npy file should be availabe in file_path (r'D:\Assignment') directory
Time_matrix = np.load(file_path+"\\"+"TM.npy")

# %% [markdown]
# #### Check what the max, min and mean time values are. This will help us in defining the 'next_step' function in the Environment.

# %%
print(type(Time_matrix))
print(Time_matrix.max())
print(Time_matrix.min())
print(Time_matrix.mean())
print(Time_matrix.var())
# Out:
# <class 'numpy.ndarray'>
# 11.0
# 0.0
# 3.0542857142857143
# 7.93705306122449

# %% [markdown]
# #### Since the max time is 11 hours between any 2 points, the next state of the cab driver may increase at most by  1 day.

# %% [markdown]
# <b><h3><font color = 'green'> 2. Agent Class </h3></b>
#
# If you are using this framework, you need to fill the following to complete the following code block:
# 1. State and Action Size
# 2. Hyperparameters
# 3. Create a neural-network model in function 'build_model()'
# 4. Define epsilon-greedy strategy in function 'get_action()'
# 5. Complete the function 'append_sample()'. This function appends the recent experience tuple <state, action, reward, new-state> to the memory
# 6. Complete the 'train_model()' function with following logic:
#    - If the memory size is greater than mini-batch size, you randomly sample experiences from memory as per the mini-batch size and do the following:
#       - Initialise your input and output batch for training the model
#       - Calculate the target Q value for each sample: reward + gamma*max(Q(s'a,))
#       - Get Q(s', a) values from the last trained model
#       - Update the input batch as your encoded state and output batch as your Q-values
#       - Then fit your DQN model using the updated input and output batch.

# %%
class DQNAgent:
    
    def __init__(self, state_size, action_size):
        # Define size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # Write here: Specify you hyper parameters for the DQN
        self.discount_factor = 0.95
        self.learning_rate = 0.01
        self.epsilon = 1
        self.epsilon_max = 1
        self.epsilon_decay = -0.0005 #for 15k
        #self.epsilon_decay = -0.00015 #for 20k
        self.epsilon_min = 0.00001
        
        self.batch_size = 32

        # create replay memory using deque
        self.memory = deque(maxlen=2000)

        # Initialize the value of the states tracked
        self.states_tracked = []
        
        # We are going to track state [0,0,0] and action (0,2) at index 2 in the action space.
        self.track_state = np.array(env.state_encod_arch1([0,0,0])).reshape(1, 36)

        # create main model and target model
        self.model = self.build_model()

    # approximate Q function using Neural Network
    def build_model(self):
        """
        Function that takes in the agent and constructs the network
        to train it
        @return model
        @params agent
        """
        input_shape = self.state_size
        model = Sequential()
        # Write your code here: Add layers to your neural nets       
        model.add(Dense(32, input_dim=self.state_size, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))
        # the output layer: output is of size num_actions
        model.add(Dense(self.action_size, activation='relu', kernel_initializer='he_uniform'))
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        model.summary
        return model

    def get_action(self, state, possible_actions_index, actions):
        """
        get action in a state according to an epsilon-greedy approach
        possible_actions_index, actions are the 'ride requests' that teh driver got.
        """        
        # get action from model using epsilon-greedy policy
        # Decay in ε after each episode       
        if np.random.rand() <= self.epsilon:
            # explore: choose a random action from the ride requests
            return random.choice(possible_actions_index)
        else:
            # choose the action with the highest q(s, a)
            # the first index corresponds to the batch size, so
            # reshape state to (1, state_size) so that the first index corresponds to the batch size
            state = np.array(env.state_encod_arch1(state)).reshape(1, 36)

            # Use the model to predict the Q_values.
            q_value = self.model.predict(state)

            # truncate the array to only those actions that are part of the ride  requests.
            q_vals_possible = [q_value[0][i] for i in possible_actions_index]

            return possible_actions_index[np.argmax(q_vals_possible)]

    def append_sample(self, state, action_index, reward, next_state, done):
        """appends the new agent run output to replay buffer"""
        self.memory.append((state, action_index, reward, next_state, done))
        
    # pick samples randomly from replay memory (with batch_size) and train the network
    def train_model(self):
        """ 
        Function to train the model on eacg step run.
        Picks the random memory events according to batch size and 
        runs it through the network to train it.
        """
        if len(self.memory) > self.batch_size:
            # Sample batch from the memory
            mini_batch = random.sample(self.memory, self.batch_size)
            # initialise two matrices - update_input and update_output
            update_input = np.zeros((self.batch_size, self.state_size))
            update_output = np.zeros((self.batch_size, self.state_size))
            actions, rewards, done = [], [], []

            # populate update_input and update_output and the lists rewards, actions, done
            for i in range(self.batch_size):
                state, action, reward, next_state, done_boolean = mini_batch[i]
                update_input[i] = env.state_encod_arch1(state)     
                actions.append(action)
                rewards.append(reward)
                update_output[i] = env.state_encod_arch1(next_state)
                done.append(done_boolean)

            # predict the target q-values from states s
            target = self.model.predict(update_input)
            # target for q-network
            target_qval = self.model.predict(update_output)


            # update the target values
            for i in range(self.batch_size):
                if done[i]:
                    target[i][actions[i]] = rewards[i]
                else: # non-terminal state
                    target[i][actions[i]] = rewards[i] + self.discount_factor * np.max(target_qval[i])
            # model fit
            self.model.fit(update_input, target, batch_size=self.batch_size, epochs=1, verbose=0)
            
    def save_tracking_states(self):
        # Use the model to predict the q_value of the state we are tacking.
        q_value = self.model.predict(self.track_state)
        
        # Grab the q_value of the action index that we are tracking.
        print("States_tracked value {0}.".format(q_value[0][2]))
        self.states_tracked.append(q_value[0][2])
        
    def save_test_states(self):
        # Use the model to predict the q_value of the state we are tacking.
        q_value = self.model.predict(self.track_state)
        
        print("states_test value {0}.".format(q_value[0][2]))
        # Grab the q_value of the action index that we are tracking.
        self.states_test.append(q_value[0][2])

    def save(self, name):
        with open(name, 'wb') as file:  
            pickle.dump(self.model, file,pickle.HIGHEST_PROTOCOL)
    
    def save_obj(model, name):
        with open(file_path + "\\" + name + '.pkl', 'wb') as f:
            pickle.dump(model, f, pickle.HIGHEST_PROTOCOL)
            
    def save_h5(self, name):
        self.model.save(name)

# %% [markdown]
# <b><h3><font color = 'green'> 3. DQN block </h3></b>

# %% [markdown]
# for episode in range(Episodes):
#
#     # Write code here
#     # Call the environment
#     # Call all the initialised variables of the environment
#
#
#     #Call the DQN agent
#
#
#     while !terminal_state:
#
#         # Write your code here
#         # 1. Pick epsilon-greedy action from possible actions for the current state
#         # 2. Evaluate your reward and next state
#         # 3. Append the experience to the memory
#         # 4. Train the model by calling function agent.train_model
#         # 5. Keep a track of rewards, Q-values, loss

# %%
episode_time = 24*30 #30 days before which car has to be recharged
n_episodes = 8000 #15000
m = 5
t = 24
d = 7
C = 5  
R = 9  

# Invoke Env class
env = CabDriver()
action_space, state_space, state = env.reset()

# Set up state and action sizes.
state_size = m+t+d
action_size = len(action_space)

# Invoke agent class
agent = DQNAgent(action_size=action_size, state_size=state_size)

# to store rewards in each episode
rewards_per_episode, episodes = [], []
# Rewards for state [0,0,0] being tracked.
rewards_init_state = []

# %% [markdown]
# <b><h3><font color = 'green'> 4. Run the episodes, build up replay buffer and train the model </h3></b>
# ### Note:
# #### The moment total episode time exceeds 720 (30 days), we ignore the most recent ride and do NOT save that experience in the replay memory
# #### The init state is randomly picked from the state space for each episode

# %%
start_time = time.time()
score_tracked = []

for episode in range(n_episodes):

    done = False
    score = 0
    track_reward = False

    # reset at the start of each episode
    env = CabDriver()
    action_space, state_space, state = env.reset()
    # Save the initial state so that reward can be tracked if initial state is [0,0,0]
    initial_state = env.state_init


    total_time = 0  # Total time driver rode in this episode
    while not done:
        # 1. Get a list of the ride requests driver got.
        possible_actions_indices, actions = env.requests(state)
        # 2. Pick epsilon-greedy action from possible actions for the current state.
        action = agent.get_action(state, possible_actions_indices, actions)

        # 3. Evaluate your reward and next state
        reward, next_state, step_time = env.step(state, env.action_space[action], Time_matrix)
        # 4. Total time driver rode in this episode
        total_time += step_time
        if (total_time > episode_time):
            # if ride does not complete in stipu;ated time skip
            # it and move to next episode.
            done = True
        else:
            # 5. Append the experience to the memory
            agent.append_sample(state, action, reward, next_state, done)
            # 6. Train the model by calling function agent.train_model
            agent.train_model()
            # 7. Keep a track of rewards, Q-values, loss
            score += reward
            state = next_state

    # store total reward obtained in this episode
    rewards_per_episode.append(score)
    episodes.append(episode)
    

    # epsilon decay
    agent.epsilon = (1 - 0.00001) * np.exp(agent.epsilon_decay * episode)

    # every 10 episodes:
    if ((episode + 1) % 10 == 0):
        print("episode {0}, reward {1}, memory_length {2}, epsilon {3} total_time {4}".format(episode,
                                                                         score,
                                                                         len(agent.memory),
                                                                         agent.epsilon, total_time))
    # Save the Q_value of the state, action pair we are tracking
    # every 5 episodes:
    if ((episode + 1) % 5 == 0):
        agent.save_tracking_states()

    # Total rewards per episode
    score_tracked.append(score)

    if(episode % 1000 == 0):
        print("Saving Model {}".format(episode))
        #agent.save_obj("model_weights")
        agent.save_h5(name="SuperCabs_car_model.h5")

        #agent._snapshotter.save_obj("model_weights")
    
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# Saving Model 0
# States_tracked value 326.1229553222656.
# episode 9, reward -144.0, memory_length 1418, epsilon 0.9955001547284723 total_time 721.0
# States_tracked value 376.0375061035156.
# States_tracked value 360.5065612792969.
# episode 19, reward -219.0, memory_length 2000, epsilon 0.9905350769930761 total_time 726.0
# States_tracked value 365.7817687988281.
# States_tracked value 414.9599304199219.
# episode 29, reward 190.0, memory_length 2000, epsilon 0.9855947626861951 total_time 731.0
# States_tracked value 336.52886962890625.
# States_tracked value 275.45452880859375.
# episode 39, reward -94.0, memory_length 2000, epsilon 0.9806790882997144 total_time 721.0
# States_tracked value 438.7414855957031.
# States_tracked value 436.0690002441406.
# episode 49, reward -121.0, memory_length 2000, epsilon 0.9757879309415182 total_time 734.0
# States_tracked value 456.94195556640625.
# States_tracked value 281.0997314453125.
# episode 59, reward -2.0, memory_length 2000, epsilon 0.9709211683324178 total_time 731.0
# States_tracked value 348.45263671875.
# States_tracked value 379.74188232421875.
# episode 69, reward -44.0, memory_length 2000, epsilon 0.9660786788030947 total_time 731.0
# States_tracked value 445.9962463378906.
# States_tracked value 406.65985107421875.
# episode 79, reward 29.0, memory_length 2000, epsilon 0.9612603412910584 total_time 721.0
# States_tracked value 372.2447204589844.
# States_tracked value 412.00732421875.
# episode 89, reward -91.0, memory_length 2000, epsilon 0.9564660353376199 total_time 724.0
# States_tracked value 412.66009521484375.
# States_tracked value 436.5085144042969.
# episode 99, reward -147.0, memory_length 2000, epsilon 0.9516956410848808 total_time 724.0
# States_tracked value 496.9903564453125.
# States_tracked value 513.6442260742188.
# episode 109, reward 54.0, memory_length 2000, epsilon 0.9469490392727365 total_time 731.0
# States_tracked value 527.35595703125.
# States_tracked value 520.8168334960938.
# episode 119, reward -40.0, memory_length 2000, epsilon 0.9422261112358942 total_time 727.0
# States_tracked value 545.1334838867188.
# States_tracked value 538.9130249023438.
# episode 129, reward -269.0, memory_length 2000, epsilon 0.9375267389009072 total_time 724.0
# States_tracked value 493.9900207519531.
# States_tracked value 465.0959167480469.
# episode 139, reward -248.0, memory_length 2000, epsilon 0.9328508047832221 total_time 721.0
# States_tracked value 541.0178833007812.
# States_tracked value 510.8511657714844.
# episode 149, reward 32.0, memory_length 2000, epsilon 0.9281981919842428 total_time 728.0
# States_tracked value 615.0038452148438.
# States_tracked value 592.3994140625.
# episode 159, reward -43.0, memory_length 2000, epsilon 0.9235687841884068 total_time 722.0
# States_tracked value 602.3706665039062.
# States_tracked value 608.1137084960938.
# episode 169, reward -120.0, memory_length 2000, epsilon 0.918962465660278 total_time 725.0
# States_tracked value 658.4722290039062.
# States_tracked value 568.4515380859375.
# episode 179, reward -57.0, memory_length 2000, epsilon 0.9143791212416534 total_time 721.0
# States_tracked value 523.96923828125.
# States_tracked value 531.786865234375.
# episode 189, reward 504.0, memory_length 2000, epsilon 0.9098186363486838 total_time 721.0
# States_tracked value 647.3272705078125.
# States_tracked value 713.180908203125.
# episode 199, reward -152.0, memory_length 2000, epsilon 0.9052808969690094 total_time 728.0
# States_tracked value 648.7005615234375.
# States_tracked value 537.8141479492188.
# episode 209, reward 78.0, memory_length 2000, epsilon 0.9007657896589091 total_time 721.0
# States_tracked value 613.2828979492188.
# States_tracked value 619.4544067382812.
# episode 219, reward 97.0, memory_length 2000, epsilon 0.8962732015404654 total_time 723.0
# States_tracked value 695.3671875.
# States_tracked value 685.1202392578125.
# episode 229, reward 87.0, memory_length 2000, epsilon 0.891803020298741 total_time 730.0
# States_tracked value 714.889404296875.
# States_tracked value 576.0838012695312.
# episode 239, reward -66.0, memory_length 2000, epsilon 0.8873551341789723 total_time 724.0
# States_tracked value 590.7064208984375.
# States_tracked value 601.6183471679688.
# episode 249, reward -84.0, memory_length 2000, epsilon 0.8829294319837746 total_time 724.0
# States_tracked value 654.1818237304688.
# States_tracked value 587.8619384765625.
# episode 259, reward -151.0, memory_length 2000, epsilon 0.8785258030703623 total_time 730.0
# States_tracked value 791.7337036132812.
# States_tracked value 731.2205200195312.
# episode 269, reward 126.0, memory_length 2000, epsilon 0.8741441373477834 total_time 722.0
# States_tracked value 670.8876342773438.
# States_tracked value 769.1128540039062.
# episode 279, reward 316.0, memory_length 2000, epsilon 0.8697843252741666 total_time 724.0
# States_tracked value 725.5762329101562.
# States_tracked value 696.1940307617188.
# episode 289, reward 635.0, memory_length 2000, epsilon 0.8654462578539829 total_time 729.0
# States_tracked value 661.5567016601562.
# States_tracked value 727.3580322265625.
# episode 299, reward 64.0, memory_length 2000, epsilon 0.8611298266353209 total_time 724.0
# States_tracked value 622.1707763671875.
# States_tracked value 600.4453735351562.
# episode 309, reward -219.0, memory_length 2000, epsilon 0.8568349237071754 total_time 729.0
# States_tracked value 612.2174072265625.
# States_tracked value 736.784423828125.
# episode 319, reward -225.0, memory_length 2000, epsilon 0.8525614416967494 total_time 721.0
# States_tracked value 681.9158325195312.
# States_tracked value 783.1952514648438.
# episode 329, reward 374.0, memory_length 2000, epsilon 0.84830927376677 total_time 728.0
# States_tracked value 734.0914916992188.
# States_tracked value 705.9830322265625.
# episode 339, reward 303.0, memory_length 2000, epsilon 0.8440783136128177 total_time 723.0
# States_tracked value 663.1378784179688.
# States_tracked value 678.7067260742188.
# episode 349, reward -184.0, memory_length 2000, epsilon 0.8398684554606681 total_time 727.0
# States_tracked value 630.8204345703125.
# States_tracked value 637.91015625.
# episode 359, reward -61.0, memory_length 2000, epsilon 0.8356795940636483 total_time 722.0
# States_tracked value 726.721923828125.
# States_tracked value 638.4061889648438.
# episode 369, reward 131.0, memory_length 2000, epsilon 0.8315116247000052 total_time 732.0
# States_tracked value 712.0538330078125.
# States_tracked value 597.74951171875.
# episode 379, reward -4.0, memory_length 2000, epsilon 0.8273644431702872 total_time 730.0
# States_tracked value 673.13818359375.
# States_tracked value 574.2649536132812.
# episode 389, reward -37.0, memory_length 2000, epsilon 0.8232379457947406 total_time 725.0
# States_tracked value 626.69189453125.
# States_tracked value 661.175537109375.
# episode 399, reward 141.0, memory_length 2000, epsilon 0.819132029410716 total_time 725.0
# States_tracked value 802.894287109375.
# States_tracked value 760.9440307617188.
# episode 409, reward 295.0, memory_length 2000, epsilon 0.8150465913700896 total_time 733.0
# States_tracked value 673.9486694335938.
# States_tracked value 638.2681274414062.
# episode 419, reward 181.0, memory_length 2000, epsilon 0.8109815295366979 total_time 722.0
# States_tracked value 614.8065185546875.
# States_tracked value 586.5609130859375.
# episode 429, reward 298.0, memory_length 2000, epsilon 0.8069367422837833 total_time 723.0
# States_tracked value 634.041259765625.
# States_tracked value 604.9862670898438.
# episode 439, reward 149.0, memory_length 2000, epsilon 0.8029121284914538 total_time 722.0
# States_tracked value 699.5280151367188.
# States_tracked value 678.8307495117188.
# episode 449, reward 201.0, memory_length 2000, epsilon 0.7989075875441549 total_time 723.0
# States_tracked value 726.24169921875.
# States_tracked value 756.3907470703125.
# episode 459, reward -20.0, memory_length 2000, epsilon 0.7949230193281545 total_time 723.0
# States_tracked value 657.4610595703125.
# States_tracked value 666.3588256835938.
# episode 469, reward 333.0, memory_length 2000, epsilon 0.7909583242290396 total_time 729.0
# States_tracked value 765.8545532226562.
# States_tracked value 764.7051391601562.
# episode 479, reward 464.0, memory_length 2000, epsilon 0.7870134031292261 total_time 731.0
# States_tracked value 810.5466918945312.
# States_tracked value 748.7003784179688.
# episode 489, reward 464.0, memory_length 2000, epsilon 0.7830881574054811 total_time 726.0
# States_tracked value 567.223388671875.
# States_tracked value 573.1968383789062.
# episode 499, reward 250.0, memory_length 2000, epsilon 0.7791824889264571 total_time 724.0
# States_tracked value 576.8902587890625.
# States_tracked value 582.3512573242188.
# episode 509, reward 141.0, memory_length 2000, epsilon 0.7752963000502389 total_time 727.0
# States_tracked value 581.0509643554688.
# States_tracked value 638.8616943359375.
# episode 519, reward -12.0, memory_length 2000, epsilon 0.7714294936219019 total_time 728.0
# States_tracked value 635.4640502929688.
# States_tracked value 641.5307006835938.
# episode 529, reward -61.0, memory_length 2000, epsilon 0.7675819729710842 total_time 721.0
# States_tracked value 654.0584716796875.
# States_tracked value 683.4830322265625.
# episode 539, reward 69.0, memory_length 2000, epsilon 0.763753641909569 total_time 725.0
# States_tracked value 644.808837890625.
# States_tracked value 633.413818359375.
# episode 549, reward 33.0, memory_length 2000, epsilon 0.7599444047288803 total_time 721.0
# States_tracked value 645.5742797851562.
# States_tracked value 678.8169555664062.
# episode 559, reward 227.0, memory_length 2000, epsilon 0.7561541661978903 total_time 722.0
# States_tracked value 629.341064453125.
# States_tracked value 605.5437622070312.
# episode 569, reward 290.0, memory_length 2000, epsilon 0.7523828315604384 total_time 724.0
# States_tracked value 591.9137573242188.
# States_tracked value 597.9474487304688.
# episode 579, reward 207.0, memory_length 2000, epsilon 0.7486303065329623 total_time 724.0
# States_tracked value 567.9547119140625.
# States_tracked value 554.2096557617188.
# episode 589, reward 183.0, memory_length 2000, epsilon 0.7448964973021404 total_time 721.0
# States_tracked value 600.146240234375.
# States_tracked value 560.6495361328125.
# episode 599, reward 342.0, memory_length 2000, epsilon 0.7411813105225479 total_time 721.0
# States_tracked value 605.8775634765625.
# States_tracked value 647.3653564453125.
# episode 609, reward 280.0, memory_length 2000, epsilon 0.7374846533143217 total_time 726.0
# States_tracked value 710.6153564453125.
# States_tracked value 725.2803955078125.
# episode 619, reward 272.0, memory_length 2000, epsilon 0.733806433260839 total_time 722.0
# States_tracked value 772.40869140625.
# States_tracked value 681.3021240234375.
# episode 629, reward 342.0, memory_length 2000, epsilon 0.7301465584064071 total_time 721.0
# States_tracked value 651.1818237304688.
# States_tracked value 685.5052490234375.
# episode 639, reward 364.0, memory_length 2000, epsilon 0.7265049372539636 total_time 723.0
# States_tracked value 723.58935546875.
# States_tracked value 615.8438720703125.
# episode 649, reward 151.0, memory_length 2000, epsilon 0.7228814787627905 total_time 721.0
# States_tracked value 667.2460327148438.
# States_tracked value 678.33203125.
# episode 659, reward 411.0, memory_length 2000, epsilon 0.7192760923462365 total_time 723.0
# States_tracked value 623.742431640625.
# States_tracked value 602.245361328125.
# episode 669, reward 456.0, memory_length 2000, epsilon 0.7156886878694535 total_time 733.0
# States_tracked value 523.8359985351562.
# States_tracked value 565.6190185546875.
# episode 679, reward 449.0, memory_length 2000, epsilon 0.7121191756471427 total_time 722.0
# States_tracked value 610.2051391601562.
# States_tracked value 579.4783325195312.
# episode 689, reward 32.0, memory_length 2000, epsilon 0.7085674664413126 total_time 728.0
# States_tracked value 597.6395263671875.
# States_tracked value 651.7028198242188.
# episode 699, reward 415.0, memory_length 2000, epsilon 0.7050334714590482 total_time 727.0
# States_tracked value 619.085693359375.
# States_tracked value 587.6455688476562.
# episode 709, reward 182.0, memory_length 2000, epsilon 0.7015171023502909 total_time 725.0
# States_tracked value 637.5501708984375.
# States_tracked value 615.2573852539062.
# episode 719, reward 216.0, memory_length 2000, epsilon 0.6980182712056295 total_time 721.0
# States_tracked value 647.6643676757812.
# States_tracked value 671.2393188476562.
# episode 729, reward 572.0, memory_length 2000, epsilon 0.6945368905541035 total_time 723.0
# States_tracked value 686.3943481445312.
# States_tracked value 613.810546875.
# episode 739, reward 209.0, memory_length 2000, epsilon 0.6910728733610152 total_time 730.0
# States_tracked value 612.5712890625.
# States_tracked value 629.7277221679688.
# episode 749, reward 257.0, memory_length 2000, epsilon 0.6876261330257543 total_time 732.0
# States_tracked value 712.7449951171875.
# States_tracked value 627.67041015625.
# episode 759, reward 195.0, memory_length 2000, epsilon 0.684196583379633 total_time 729.0
# States_tracked value 696.6361694335938.
# States_tracked value 722.8115234375.
# episode 769, reward -176.0, memory_length 2000, epsilon 0.6807841386837313 total_time 722.0
# States_tracked value 847.41015625.
# States_tracked value 678.959228515625.
# episode 779, reward -111.0, memory_length 2000, epsilon 0.6773887136267543 total_time 725.0
# States_tracked value 621.4093017578125.
# States_tracked value 667.7290649414062.
# episode 789, reward 82.0, memory_length 2000, epsilon 0.6740102233228988 total_time 724.0
# States_tracked value 738.0243530273438.
# States_tracked value 622.044921875.
# episode 799, reward 731.0, memory_length 2000, epsilon 0.670648583309731 total_time 721.0
# States_tracked value 626.2394409179688.
# States_tracked value 610.8050537109375.
# episode 809, reward 209.0, memory_length 2000, epsilon 0.6673037095460755 total_time 724.0
# States_tracked value 636.1353149414062.
# States_tracked value 582.5169677734375.
# episode 819, reward 377.0, memory_length 2000, epsilon 0.6639755184099142 total_time 723.0
# States_tracked value 590.4918823242188.
# States_tracked value 602.8955078125.
# episode 829, reward 243.0, memory_length 2000, epsilon 0.6606639266962953 total_time 722.0
# States_tracked value 552.7201538085938.
# States_tracked value 642.3944702148438.
# episode 839, reward 252.0, memory_length 2000, epsilon 0.6573688516152534 total_time 727.0
# States_tracked value 591.88232421875.
# States_tracked value 644.1162109375.
# episode 849, reward 273.0, memory_length 2000, epsilon 0.6540902107897397 total_time 725.0
# States_tracked value 601.5114135742188.
# States_tracked value 622.6875.
# episode 859, reward 227.0, memory_length 2000, epsilon 0.6508279222535631 total_time 723.0
# States_tracked value 661.1863403320312.
# States_tracked value 629.760986328125.
# episode 869, reward 371.0, memory_length 2000, epsilon 0.64758190444934 total_time 721.0
# States_tracked value 653.7905883789062.
# States_tracked value 637.6670532226562.
# episode 879, reward 609.0, memory_length 2000, epsilon 0.6443520762264566 total_time 728.0
# States_tracked value 624.2579956054688.
# States_tracked value 598.9790649414062.
# episode 889, reward 479.0, memory_length 2000, epsilon 0.6411383568390387 total_time 725.0
# States_tracked value 636.716552734375.
# States_tracked value 638.2645874023438.
# episode 899, reward 48.0, memory_length 2000, epsilon 0.6379406659439346 total_time 724.0
# States_tracked value 628.4507446289062.
# States_tracked value 591.7341918945312.
# episode 909, reward 303.0, memory_length 2000, epsilon 0.6347589235987051 total_time 727.0
# States_tracked value 658.9208374023438.
# States_tracked value 641.0698852539062.
# episode 919, reward 555.0, memory_length 2000, epsilon 0.631593050259626 total_time 722.0
# States_tracked value 655.0896606445312.
# States_tracked value 641.5112915039062.
# episode 929, reward 727.0, memory_length 2000, epsilon 0.6284429667796988 total_time 721.0
# States_tracked value 622.03515625.
# States_tracked value 687.42529296875.
# episode 939, reward 734.0, memory_length 2000, epsilon 0.6253085944066726 total_time 726.0
# States_tracked value 723.0574951171875.
# States_tracked value 601.051513671875.
# episode 949, reward 295.0, memory_length 2000, epsilon 0.6221898547810748 total_time 727.0
# States_tracked value 579.7752685546875.
# States_tracked value 644.9436645507812.
# episode 959, reward 588.0, memory_length 2000, epsilon 0.6190866699342522 total_time 722.0
# States_tracked value 645.3356323242188.
# States_tracked value 638.72265625.
# episode 969, reward 281.0, memory_length 2000, epsilon 0.6159989622864221 total_time 726.0
# States_tracked value 603.5116577148438.
# States_tracked value 561.8892211914062.
# episode 979, reward 511.0, memory_length 2000, epsilon 0.6129266546447325 total_time 723.0
# States_tracked value 617.6988525390625.
# States_tracked value 573.57177734375.
# episode 989, reward 432.0, memory_length 2000, epsilon 0.6098696702013323 total_time 721.0
# States_tracked value 560.44921875.
# States_tracked value 628.3453979492188.
# episode 999, reward 452.0, memory_length 2000, epsilon 0.6068279325314512 total_time 727.0
# States_tracked value 601.5480346679688.
# Saving Model 1000
# States_tracked value 599.9241333007812.
# episode 1009, reward 387.0, memory_length 2000, epsilon 0.6038013655914889 total_time 721.0
# States_tracked value 592.2410278320312.
# States_tracked value 598.8467407226562.
# episode 1019, reward 714.0, memory_length 2000, epsilon 0.6007898937171146 total_time 725.0
# States_tracked value 581.3233032226562.
# States_tracked value 614.8178100585938.
# episode 1029, reward 636.0, memory_length 2000, epsilon 0.5977934416213744 total_time 727.0
# States_tracked value 600.3272705078125.
# States_tracked value 598.2247314453125.
# episode 1039, reward 514.0, memory_length 2000, epsilon 0.5948119343928097 total_time 721.0
# States_tracked value 622.3265380859375.
# States_tracked value 633.2186279296875.
# episode 1049, reward 434.0, memory_length 2000, epsilon 0.5918452974935846 total_time 729.0
# States_tracked value 581.50244140625.
# States_tracked value 562.7252807617188.
# episode 1059, reward 489.0, memory_length 2000, epsilon 0.5888934567576223 total_time 721.0
# States_tracked value 611.6734008789062.
# States_tracked value 585.6611328125.
# episode 1069, reward 758.0, memory_length 2000, epsilon 0.5859563383887504 total_time 722.0
# States_tracked value 591.6836547851562.
# States_tracked value 560.9847412109375.
# episode 1079, reward 543.0, memory_length 2000, epsilon 0.5830338689588568 total_time 727.0
# States_tracked value 562.846435546875.
# States_tracked value 576.0473022460938.
# episode 1089, reward 523.0, memory_length 2000, epsilon 0.5801259754060536 total_time 725.0
# States_tracked value 568.6846313476562.
# States_tracked value 678.28271484375.
# episode 1099, reward 330.0, memory_length 2000, epsilon 0.5772325850328504 total_time 722.0
# States_tracked value 634.7659301757812.
# States_tracked value 641.2266235351562.
# episode 1109, reward 215.0, memory_length 2000, epsilon 0.5743536255043372 total_time 721.0
# States_tracked value 603.3117065429688.
# States_tracked value 595.6477661132812.
# episode 1119, reward 739.0, memory_length 2000, epsilon 0.5714890248463761 total_time 725.0
# States_tracked value 609.2040405273438.
# States_tracked value 615.2675170898438.
# episode 1129, reward 599.0, memory_length 2000, epsilon 0.5686387114438011 total_time 725.0
# States_tracked value 632.2188720703125.
# States_tracked value 655.890869140625.
# episode 1139, reward 188.0, memory_length 2000, epsilon 0.5658026140386287 total_time 723.0
# States_tracked value 657.9482421875.
# States_tracked value 825.3568115234375.
# episode 1149, reward 409.0, memory_length 2000, epsilon 0.5629806617282764 total_time 721.0
# States_tracked value 923.8510131835938.
# States_tracked value 673.7380981445312.
# episode 1159, reward 640.0, memory_length 2000, epsilon 0.5601727839637891 total_time 729.0
# States_tracked value 599.1278686523438.
# States_tracked value 624.1990966796875.
# episode 1169, reward 366.0, memory_length 2000, epsilon 0.5573789105480766 total_time 722.0
# States_tracked value 630.0014038085938.
# States_tracked value 597.8165893554688.
# episode 1179, reward 506.0, memory_length 2000, epsilon 0.5545989716341581 total_time 721.0
# States_tracked value 618.4618530273438.
# States_tracked value 581.5614624023438.
# episode 1189, reward 608.0, memory_length 2000, epsilon 0.5518328977234156 total_time 721.0
# States_tracked value 637.8102416992188.
# States_tracked value 661.75048828125.
# episode 1199, reward 604.0, memory_length 2000, epsilon 0.5490806196638577 total_time 727.0
# States_tracked value 654.2272338867188.
# States_tracked value 627.00146484375.
# episode 1209, reward 454.0, memory_length 2000, epsilon 0.5463420686483893 total_time 726.0
# States_tracked value 576.698974609375.
# States_tracked value 629.9934692382812.
# episode 1219, reward 635.0, memory_length 2000, epsilon 0.5436171762130925 total_time 727.0
# States_tracked value 567.0490112304688.
# States_tracked value 536.9863891601562.
# episode 1229, reward 399.0, memory_length 2000, epsilon 0.5409058742355145 total_time 725.0
# States_tracked value 606.1746826171875.
# States_tracked value 626.1597290039062.
# episode 1239, reward 685.0, memory_length 2000, epsilon 0.5382080949329644 total_time 722.0
# States_tracked value 601.9900512695312.
# States_tracked value 584.8575439453125.
# episode 1249, reward 603.0, memory_length 2000, epsilon 0.5355237708608195 total_time 729.0
# States_tracked value 554.086181640625.
# States_tracked value 583.2120971679688.
# episode 1259, reward 503.0, memory_length 2000, epsilon 0.5328528349108379 total_time 722.0
# States_tracked value 560.5792846679688.
# States_tracked value 586.9817504882812.
# episode 1269, reward 780.0, memory_length 2000, epsilon 0.5301952203094819 total_time 723.0
# States_tracked value 616.2202758789062.
# States_tracked value 630.949462890625.
# episode 1279, reward 536.0, memory_length 2000, epsilon 0.5275508606162479 total_time 728.0
# States_tracked value 562.5648803710938.
# States_tracked value 570.8697509765625.
# episode 1289, reward 603.0, memory_length 2000, epsilon 0.5249196897220061 total_time 728.0
# States_tracked value 590.4478759765625.
# States_tracked value 674.443359375.
# episode 1299, reward 797.0, memory_length 2000, epsilon 0.5223016418473468 total_time 723.0
# States_tracked value 641.3756103515625.
# States_tracked value 567.75048828125.
# episode 1309, reward 683.0, memory_length 2000, epsilon 0.519696651540937 total_time 721.0
# States_tracked value 684.4169311523438.
# States_tracked value 627.2276000976562.
# episode 1319, reward 649.0, memory_length 2000, epsilon 0.5171046536778833 total_time 724.0
# States_tracked value 610.7088623046875.
# States_tracked value 576.2345581054688.
# episode 1329, reward 567.0, memory_length 2000, epsilon 0.514525583458104 total_time 728.0
# States_tracked value 622.1143798828125.
# States_tracked value 616.0936279296875.
# episode 1339, reward 675.0, memory_length 2000, epsilon 0.5119593764047093 total_time 730.0
# States_tracked value 592.460205078125.
# States_tracked value 631.4385986328125.
# episode 1349, reward 857.0, memory_length 2000, epsilon 0.5094059683623896 total_time 723.0
# States_tracked value 610.4017944335938.
# States_tracked value 618.728271484375.
# episode 1359, reward 569.0, memory_length 2000, epsilon 0.5068652954958104 total_time 724.0
# States_tracked value 699.2667236328125.
# States_tracked value 663.2337646484375.
# episode 1369, reward 254.0, memory_length 2000, epsilon 0.5043372942880178 total_time 727.0
# States_tracked value 650.2461547851562.
# States_tracked value 592.1885375976562.
# episode 1379, reward 469.0, memory_length 2000, epsilon 0.50182190153885 total_time 732.0
# States_tracked value 582.0067138671875.
# States_tracked value 603.3776245117188.
# episode 1389, reward 563.0, memory_length 2000, epsilon 0.49931905436335716 total_time 728.0
# States_tracked value 600.4679565429688.
# States_tracked value 591.4633178710938.
# episode 1399, reward 287.0, memory_length 2000, epsilon 0.49682869019022974 total_time 724.0
# States_tracked value 633.9378662109375.
# States_tracked value 574.554443359375.
# episode 1409, reward 737.0, memory_length 2000, epsilon 0.49435074676023355 total_time 721.0
# States_tracked value 565.2028198242188.
# States_tracked value 579.8757934570312.
# episode 1419, reward 783.0, memory_length 2000, epsilon 0.4918851621246539 total_time 724.0
# States_tracked value 588.7206420898438.
# States_tracked value 594.9255981445312.
# episode 1429, reward 700.0, memory_length 2000, epsilon 0.4894318746437464 total_time 721.0
# States_tracked value 563.8533325195312.
# States_tracked value 549.8417358398438.
# episode 1439, reward 891.0, memory_length 2000, epsilon 0.4869908229851962 total_time 725.0
# States_tracked value 583.5469360351562.
# States_tracked value 579.7264404296875.
# episode 1449, reward 552.0, memory_length 2000, epsilon 0.48456194612258474 total_time 728.0
# States_tracked value 554.6197509765625.
# States_tracked value 630.6751098632812.
# episode 1459, reward 376.0, memory_length 2000, epsilon 0.48214518333386397 total_time 721.0
# States_tracked value 706.1871948242188.
# States_tracked value 624.3056640625.
# episode 1469, reward 319.0, memory_length 2000, epsilon 0.47974047419983834 total_time 723.0
# States_tracked value 577.0774536132812.
# States_tracked value 584.7402954101562.
# episode 1479, reward 546.0, memory_length 2000, epsilon 0.4773477586026542 total_time 726.0
# States_tracked value 576.48095703125.
# States_tracked value 591.1104736328125.
# episode 1489, reward 963.0, memory_length 2000, epsilon 0.474966976724297 total_time 726.0
# States_tracked value 608.7744750976562.
# States_tracked value 560.6041259765625.
# episode 1499, reward 658.0, memory_length 2000, epsilon 0.47259806904509577 total_time 728.0
# States_tracked value 612.2161865234375.
# States_tracked value 620.882080078125.
# episode 1509, reward 648.0, memory_length 2000, epsilon 0.4702409763422352 total_time 724.0
# States_tracked value 637.478515625.
# States_tracked value 633.8255615234375.
# episode 1519, reward 516.0, memory_length 2000, epsilon 0.4678956396882749 total_time 724.0
# States_tracked value 587.46875.
# States_tracked value 573.2214965820312.
# episode 1529, reward 558.0, memory_length 2000, epsilon 0.4655620004496764 total_time 726.0
# States_tracked value 585.3573608398438.
# States_tracked value 559.1068725585938.
# episode 1539, reward 715.0, memory_length 2000, epsilon 0.46324000028533724 total_time 721.0
# States_tracked value 546.5001831054688.
# States_tracked value 573.9252319335938.
# episode 1549, reward 932.0, memory_length 2000, epsilon 0.4609295811451323 total_time 721.0
# States_tracked value 579.0751342773438.
# States_tracked value 588.0247802734375.
# episode 1559, reward 477.0, memory_length 2000, epsilon 0.4586306852684627 total_time 722.0
# States_tracked value 607.2987670898438.
# States_tracked value 599.2897338867188.
# episode 1569, reward 676.0, memory_length 2000, epsilon 0.4563432551828119 total_time 726.0
# States_tracked value 597.1062622070312.
# States_tracked value 593.4461669921875.
# episode 1579, reward 731.0, memory_length 2000, epsilon 0.4540672337023085 total_time 723.0
# States_tracked value 616.0095825195312.
# States_tracked value 580.9293823242188.
# episode 1589, reward 870.0, memory_length 2000, epsilon 0.45180256392629703 total_time 729.0
# States_tracked value 576.4861450195312.
# States_tracked value 601.7229614257812.
# episode 1599, reward 856.0, memory_length 2000, epsilon 0.4495491892379152 total_time 723.0
# States_tracked value 598.9727172851562.
# States_tracked value 574.0219116210938.
# episode 1609, reward 405.0, memory_length 2000, epsilon 0.4473070533026783 total_time 728.0
# States_tracked value 597.197021484375.
# States_tracked value 634.1513061523438.
# episode 1619, reward 676.0, memory_length 2000, epsilon 0.4450761000670712 total_time 727.0
# States_tracked value 650.9929809570312.
# States_tracked value 613.9005737304688.
# episode 1629, reward 941.0, memory_length 2000, epsilon 0.4428562737571469 total_time 725.0
# States_tracked value 576.4631958007812.
# States_tracked value 595.2964477539062.
# episode 1639, reward 754.0, memory_length 2000, epsilon 0.44064751887713194 total_time 721.0
# States_tracked value 607.5946655273438.
# States_tracked value 613.5097045898438.
# episode 1649, reward 679.0, memory_length 2000, epsilon 0.4384497802080393 total_time 724.0
# States_tracked value 612.8807983398438.
# States_tracked value 612.4698486328125.
# episode 1659, reward 1001.0, memory_length 2000, epsilon 0.4362630028062879 total_time 721.0
# States_tracked value 607.4014282226562.
# States_tracked value 586.6887817382812.
# episode 1669, reward 867.0, memory_length 2000, epsilon 0.43408713200232857 total_time 725.0
# States_tracked value 581.6380004882812.
# States_tracked value 578.28955078125.
# episode 1679, reward 599.0, memory_length 2000, epsilon 0.43192211339927816 total_time 723.0
# States_tracked value 613.2139892578125.
# States_tracked value 572.0838012695312.
# episode 1689, reward 837.0, memory_length 2000, epsilon 0.4297678928715586 total_time 721.0
# States_tracked value 615.4182739257812.
# States_tracked value 618.77978515625.
# episode 1699, reward 711.0, memory_length 2000, epsilon 0.4276244165635446 total_time 727.0
# States_tracked value 643.8089599609375.
# States_tracked value 595.2807006835938.
# episode 1709, reward 489.0, memory_length 2000, epsilon 0.42549163088821684 total_time 724.0
# States_tracked value 602.9127807617188.
# States_tracked value 668.759521484375.
# episode 1719, reward 1040.0, memory_length 2000, epsilon 0.4233694825258223 total_time 721.0
# States_tracked value 648.153076171875.
# States_tracked value 638.7598876953125.
# episode 1729, reward 970.0, memory_length 2000, epsilon 0.4212579184225415 total_time 724.0
# States_tracked value 639.2800903320312.
# States_tracked value 685.4708862304688.
# episode 1739, reward 842.0, memory_length 2000, epsilon 0.4191568857891617 total_time 727.0
# States_tracked value 589.7797241210938.
# States_tracked value 601.5321044921875.
# episode 1749, reward 762.0, memory_length 2000, epsilon 0.4170663320997578 total_time 724.0
# States_tracked value 639.0611572265625.
# States_tracked value 605.0671997070312.
# episode 1759, reward 1011.0, memory_length 2000, epsilon 0.4149862050903786 total_time 722.0
# States_tracked value 592.7356567382812.
# States_tracked value 603.171875.
# episode 1769, reward 699.0, memory_length 2000, epsilon 0.4129164527577405 total_time 723.0
# States_tracked value 592.6619262695312.
# States_tracked value 607.6652221679688.
# episode 1779, reward 1134.0, memory_length 2000, epsilon 0.41085702335792745 total_time 726.0
# States_tracked value 663.3533325195312.
# States_tracked value 611.0556030273438.
# episode 1789, reward 1078.0, memory_length 2000, epsilon 0.40880786540509717 total_time 724.0
# States_tracked value 596.5787963867188.
# States_tracked value 565.9801025390625.
# episode 1799, reward 838.0, memory_length 2000, epsilon 0.4067689276701942 total_time 722.0
# States_tracked value 558.0526733398438.
# States_tracked value 555.1636962890625.
# episode 1809, reward 1103.0, memory_length 2000, epsilon 0.40474015917966877 total_time 723.0
# States_tracked value 552.1184692382812.
# States_tracked value 568.2504272460938.
# episode 1819, reward 881.0, memory_length 2000, epsilon 0.4027215092142031 total_time 724.0
# States_tracked value 560.4168090820312.
# States_tracked value 560.5098876953125.
# episode 1829, reward 902.0, memory_length 2000, epsilon 0.4007129273074429 total_time 727.0
# States_tracked value 581.3518676757812.
# States_tracked value 587.193115234375.
# episode 1839, reward 783.0, memory_length 2000, epsilon 0.39871436324473586 total_time 728.0
# States_tracked value 636.6456909179688.
# States_tracked value 583.9808959960938.
# episode 1849, reward 1068.0, memory_length 2000, epsilon 0.3967257670618763 total_time 731.0
# States_tracked value 602.6077880859375.
# States_tracked value 641.0073852539062.
# episode 1859, reward 722.0, memory_length 2000, epsilon 0.3947470890438561 total_time 727.0
# States_tracked value 597.599609375.
# States_tracked value 583.91552734375.
# episode 1869, reward 1170.0, memory_length 2000, epsilon 0.3927782797236218 total_time 721.0
# States_tracked value 568.1364135742188.
# States_tracked value 575.1633911132812.
# episode 1879, reward 812.0, memory_length 2000, epsilon 0.3908192898808378 total_time 721.0
# States_tracked value 560.2943115234375.
# States_tracked value 547.7217407226562.
# episode 1889, reward 1175.0, memory_length 2000, epsilon 0.388870070540656 total_time 725.0
# States_tracked value 602.9364624023438.
# States_tracked value 578.684326171875.
# episode 1899, reward 983.0, memory_length 2000, epsilon 0.38693057297249134 total_time 722.0
# States_tracked value 546.0513916015625.
# States_tracked value 546.3885498046875.
# episode 1909, reward 1002.0, memory_length 2000, epsilon 0.3850007486888037 total_time 721.0
# States_tracked value 573.5279541015625.
# States_tracked value 565.18212890625.
# episode 1919, reward 882.0, memory_length 2000, epsilon 0.3830805494438854 total_time 730.0
# States_tracked value 575.1680908203125.
# States_tracked value 582.0402221679688.
# episode 1929, reward 890.0, memory_length 2000, epsilon 0.38116992723265536 total_time 721.0
# States_tracked value 595.1280517578125.
# States_tracked value 593.365234375.
# episode 1939, reward 1008.0, memory_length 2000, epsilon 0.3792688342894587 total_time 725.0
# States_tracked value 596.3252563476562.
# States_tracked value 614.3316040039062.
# episode 1949, reward 627.0, memory_length 2000, epsilon 0.3773772230868729 total_time 727.0
# States_tracked value 634.2109985351562.
# States_tracked value 629.158447265625.
# episode 1959, reward 927.0, memory_length 2000, epsilon 0.37549504633451936 total_time 726.0
# States_tracked value 628.8338623046875.
# States_tracked value 642.69921875.
# episode 1969, reward 1095.0, memory_length 2000, epsilon 0.37362225697788115 total_time 725.0
# States_tracked value 653.657470703125.
# States_tracked value 639.737548828125.
# episode 1979, reward 1172.0, memory_length 2000, epsilon 0.37175880819712703 total_time 726.0
# States_tracked value 650.1570434570312.
# States_tracked value 590.3486328125.
# episode 1989, reward 1095.0, memory_length 2000, epsilon 0.3699046534059402 total_time 722.0
# States_tracked value 608.4826049804688.
# States_tracked value 573.55810546875.
# episode 1999, reward 591.0, memory_length 2000, epsilon 0.3680597462503545 total_time 724.0
# States_tracked value 539.0794067382812.
# Saving Model 2000
# States_tracked value 545.7842407226562.
# episode 2009, reward 758.0, memory_length 2000, epsilon 0.3662240406075948 total_time 722.0
# States_tracked value 590.8045654296875.
# States_tracked value 623.3251342773438.
# episode 2019, reward 661.0, memory_length 2000, epsilon 0.3643974905849244 total_time 727.0
# States_tracked value 605.6640625.
# States_tracked value 603.8221435546875.
# episode 2029, reward 963.0, memory_length 2000, epsilon 0.3625800505184978 total_time 721.0
# States_tracked value 604.4752197265625.
# States_tracked value 599.2310791015625.
# episode 2039, reward 567.0, memory_length 2000, epsilon 0.3607716749722184 total_time 722.0
# States_tracked value 629.7158813476562.
# States_tracked value 634.75732421875.
# episode 2049, reward 1154.0, memory_length 2000, epsilon 0.3589723187366037 total_time 721.0
# States_tracked value 642.1763305664062.
# States_tracked value 609.7865600585938.
# episode 2059, reward 941.0, memory_length 2000, epsilon 0.35718193682765376 total_time 727.0
# States_tracked value 607.893798828125.
# States_tracked value 604.4130249023438.
# episode 2069, reward 981.0, memory_length 2000, epsilon 0.3554004844857278 total_time 728.0
# States_tracked value 573.4906616210938.
# States_tracked value 619.4203491210938.
# episode 2079, reward 535.0, memory_length 2000, epsilon 0.35362791717442443 total_time 722.0
# States_tracked value 582.8987426757812.
# States_tracked value 612.9103393554688.
# episode 2089, reward 648.0, memory_length 2000, epsilon 0.35186419057946866 total_time 726.0
# States_tracked value 647.8425903320312.
# States_tracked value 572.651611328125.
# episode 2099, reward 1135.0, memory_length 2000, epsilon 0.3501092606076035 total_time 724.0
# States_tracked value 621.3150634765625.
# States_tracked value 589.1542358398438.
# episode 2109, reward 881.0, memory_length 2000, epsilon 0.3483630833854885 total_time 722.0
# States_tracked value 616.6697998046875.
# States_tracked value 599.0870971679688.
# episode 2119, reward 756.0, memory_length 2000, epsilon 0.34662561525860197 total_time 728.0
# States_tracked value 556.0591430664062.
# States_tracked value 548.7992553710938.
# episode 2129, reward 1384.0, memory_length 2000, epsilon 0.34489681279015044 total_time 725.0
# States_tracked value 581.7606201171875.
# States_tracked value 564.7610473632812.
# episode 2139, reward 1101.0, memory_length 2000, epsilon 0.34317663275998195 total_time 721.0
# States_tracked value 591.5471801757812.
# States_tracked value 564.4339599609375.
# episode 2149, reward 827.0, memory_length 2000, epsilon 0.3414650321635064 total_time 722.0
# States_tracked value 582.720703125.
# States_tracked value 595.4849853515625.
# episode 2159, reward 1162.0, memory_length 2000, epsilon 0.33976196821061944 total_time 724.0
# States_tracked value 601.1079711914062.
# States_tracked value 589.9268188476562.
# episode 2169, reward 1137.0, memory_length 2000, epsilon 0.3380673983246338 total_time 721.0
# States_tracked value 598.3547973632812.
# States_tracked value 595.2042236328125.
# episode 2179, reward 1085.0, memory_length 2000, epsilon 0.336381280141214 total_time 733.0
# States_tracked value 571.3220825195312.
# States_tracked value 582.5050659179688.
# episode 2189, reward 864.0, memory_length 2000, epsilon 0.33470357150731744 total_time 727.0
# States_tracked value 600.52685546875.
# States_tracked value 589.964111328125.
# episode 2199, reward 868.0, memory_length 2000, epsilon 0.3330342304801412 total_time 726.0
# States_tracked value 593.2164916992188.
# States_tracked value 603.6722412109375.
# episode 2209, reward 661.0, memory_length 2000, epsilon 0.33137321532607245 total_time 722.0
# States_tracked value 578.6951904296875.
# States_tracked value 591.2073364257812.
# episode 2219, reward 1014.0, memory_length 2000, epsilon 0.3297204845196459 total_time 725.0
# States_tracked value 596.7239990234375.
# States_tracked value 619.6039428710938.
# episode 2229, reward 1023.0, memory_length 2000, epsilon 0.32807599674250526 total_time 724.0
# States_tracked value 588.2594604492188.
# States_tracked value 600.724609375.
# episode 2239, reward 900.0, memory_length 2000, epsilon 0.32643971088237056 total_time 726.0
# States_tracked value 610.7030639648438.
# States_tracked value 610.8475952148438.
# episode 2249, reward 702.0, memory_length 2000, epsilon 0.32481158603200994 total_time 731.0
# States_tracked value 586.2951049804688.
# States_tracked value 564.2318115234375.
# episode 2259, reward 1134.0, memory_length 2000, epsilon 0.32319158148821747 total_time 721.0
# States_tracked value 586.8273315429688.
# States_tracked value 565.0126953125.
# episode 2269, reward 601.0, memory_length 2000, epsilon 0.3215796567507951 total_time 723.0
# States_tracked value 589.7982788085938.
# States_tracked value 587.4805297851562.
# episode 2279, reward 648.0, memory_length 2000, epsilon 0.31997577152154044 total_time 725.0
# States_tracked value 593.4828491210938.
# States_tracked value 595.1285400390625.
# episode 2289, reward 1053.0, memory_length 2000, epsilon 0.31837988570323916 total_time 724.0
# States_tracked value 573.2623291015625.
# States_tracked value 609.970947265625.
# episode 2299, reward 1017.0, memory_length 2000, epsilon 0.3167919593986629 total_time 721.0
# States_tracked value 608.0403442382812.
# States_tracked value 595.875244140625.
# episode 2309, reward 846.0, memory_length 2000, epsilon 0.3152119529095711 total_time 726.0
# States_tracked value 613.5799560546875.
# States_tracked value 600.2990112304688.
# episode 2319, reward 594.0, memory_length 2000, epsilon 0.3136398267357194 total_time 723.0
# States_tracked value 615.2564086914062.
# States_tracked value 609.244140625.
# episode 2329, reward 986.0, memory_length 2000, epsilon 0.31207554157387146 total_time 723.0
# States_tracked value 583.0617065429688.
# States_tracked value 591.4398803710938.
# episode 2339, reward 1160.0, memory_length 2000, epsilon 0.3105190583168168 total_time 721.0
# States_tracked value 577.0504760742188.
# States_tracked value 598.2091674804688.
# episode 2349, reward 1310.0, memory_length 2000, epsilon 0.30897033805239293 total_time 724.0
# States_tracked value 640.0128784179688.
# States_tracked value 615.31982421875.
# episode 2359, reward 798.0, memory_length 2000, epsilon 0.3074293420625127 total_time 723.0
# States_tracked value 652.8274536132812.
# States_tracked value 598.9443359375.
# episode 2369, reward 1289.0, memory_length 2000, epsilon 0.3058960318221959 total_time 727.0
# States_tracked value 626.9756469726562.
# States_tracked value 573.2610473632812.
# episode 2379, reward 1175.0, memory_length 2000, epsilon 0.30437036899860687 total_time 728.0
# States_tracked value 570.31787109375.
# States_tracked value 605.347900390625.
# episode 2389, reward 816.0, memory_length 2000, epsilon 0.3028523154500953 total_time 722.0
# States_tracked value 575.189208984375.
# States_tracked value 581.697509765625.
# episode 2399, reward 629.0, memory_length 2000, epsilon 0.30134183322524366 total_time 722.0
# States_tracked value 606.9954223632812.
# States_tracked value 617.406982421875.
# episode 2409, reward 893.0, memory_length 2000, epsilon 0.29983888456191743 total_time 727.0
# States_tracked value 647.0419311523438.
# States_tracked value 609.9467163085938.
# episode 2419, reward 1274.0, memory_length 2000, epsilon 0.29834343188632195 total_time 729.0
# States_tracked value 601.8468017578125.
# States_tracked value 582.6177368164062.
# episode 2429, reward 1008.0, memory_length 2000, epsilon 0.2968554378120623 total_time 730.0
# States_tracked value 578.9698486328125.
# States_tracked value 599.9963989257812.
# episode 2439, reward 1227.0, memory_length 2000, epsilon 0.2953748651392093 total_time 723.0
# States_tracked value 635.3367919921875.
# States_tracked value 611.7167358398438.
# episode 2449, reward 1087.0, memory_length 2000, epsilon 0.2939016768533689 total_time 723.0
# States_tracked value 626.0463256835938.
# States_tracked value 601.7577514648438.
# episode 2459, reward 1231.0, memory_length 2000, epsilon 0.2924358361247571 total_time 725.0
# States_tracked value 600.11669921875.
# States_tracked value 561.4486083984375.
# episode 2469, reward 1050.0, memory_length 2000, epsilon 0.2909773063072796 total_time 722.0
# States_tracked value 600.540283203125.
# States_tracked value 618.7103881835938.
# episode 2479, reward 901.0, memory_length 2000, epsilon 0.28952605093761474 total_time 724.0
# States_tracked value 605.41748046875.
# States_tracked value 578.2071533203125.
# episode 2489, reward 969.0, memory_length 2000, epsilon 0.28808203373430286 total_time 729.0
# States_tracked value 613.7900390625.
# States_tracked value 606.53759765625.
# episode 2499, reward 967.0, memory_length 2000, epsilon 0.28664521859683867 total_time 721.0
# States_tracked value 600.8865966796875.
# States_tracked value 635.9326171875.
# episode 2509, reward 1034.0, memory_length 2000, epsilon 0.2852155696047688 total_time 722.0
# States_tracked value 605.4488525390625.
# States_tracked value 624.0508422851562.
# episode 2519, reward 1323.0, memory_length 2000, epsilon 0.28379305101679403 total_time 725.0
# States_tracked value 612.5723266601562.
# States_tracked value 620.0146484375.
# episode 2529, reward 1266.0, memory_length 2000, epsilon 0.28237762726987564 total_time 723.0
# States_tracked value 624.1906127929688.
# States_tracked value 626.339111328125.
# episode 2539, reward 747.0, memory_length 2000, epsilon 0.28096926297834607 total_time 727.0
# States_tracked value 621.7833251953125.
# States_tracked value 600.6826171875.
# episode 2549, reward 981.0, memory_length 2000, epsilon 0.2795679229330249 total_time 728.0
# States_tracked value 601.8829345703125.
# States_tracked value 604.9290771484375.
# episode 2559, reward 876.0, memory_length 2000, epsilon 0.27817357210033783 total_time 727.0
# States_tracked value 587.225341796875.
# States_tracked value 577.3626708984375.
# episode 2569, reward 1207.0, memory_length 2000, epsilon 0.27678617562144153 total_time 724.0
# States_tracked value 593.5538330078125.
# States_tracked value 619.1399536132812.
# episode 2579, reward 1169.0, memory_length 2000, epsilon 0.2754056988113517 total_time 722.0
# States_tracked value 606.0401000976562.
# States_tracked value 571.1812133789062.
# episode 2589, reward 1024.0, memory_length 2000, epsilon 0.27403210715807624 total_time 733.0
# States_tracked value 616.8421020507812.
# States_tracked value 598.6233520507812.
# episode 2599, reward 771.0, memory_length 2000, epsilon 0.2726653663217522 total_time 721.0
# States_tracked value 624.4440307617188.
# States_tracked value 602.8145751953125.
# episode 2609, reward 1225.0, memory_length 2000, epsilon 0.27130544213378754 total_time 731.0
# States_tracked value 560.5424194335938.
# States_tracked value 559.7861938476562.
# episode 2619, reward 828.0, memory_length 2000, epsilon 0.2699523005960067 total_time 724.0
# States_tracked value 606.1007690429688.
# States_tracked value 567.6087646484375.
# episode 2629, reward 1133.0, memory_length 2000, epsilon 0.26860590787980093 total_time 722.0
# States_tracked value 584.2130737304688.
# States_tracked value 587.3868408203125.
# episode 2639, reward 1194.0, memory_length 2000, epsilon 0.26726623032528185 total_time 727.0
# States_tracked value 634.09375.
# States_tracked value 589.1954345703125.
# episode 2649, reward 1134.0, memory_length 2000, epsilon 0.2659332344404412 total_time 721.0
# States_tracked value 617.7298583984375.
# States_tracked value 577.868408203125.
# episode 2659, reward 1132.0, memory_length 2000, epsilon 0.2646068869003122 total_time 725.0
# States_tracked value 584.6365356445312.
# States_tracked value 587.9476318359375.
# episode 2669, reward 1413.0, memory_length 2000, epsilon 0.2632871545461373 total_time 725.0
# States_tracked value 575.2239990234375.
# States_tracked value 598.322021484375.
# episode 2679, reward 1190.0, memory_length 2000, epsilon 0.261974004384539 total_time 722.0
# States_tracked value 598.9265747070312.
# States_tracked value 617.7989501953125.
# episode 2689, reward 918.0, memory_length 2000, epsilon 0.26066740358669477 total_time 730.0
# States_tracked value 597.1007690429688.
# States_tracked value 600.158935546875.
# episode 2699, reward 933.0, memory_length 2000, epsilon 0.25936731948751673 total_time 725.0
# States_tracked value 609.9021606445312.
# States_tracked value 638.6353759765625.
# episode 2709, reward 1252.0, memory_length 2000, epsilon 0.2580737195848345 total_time 724.0
# States_tracked value 575.24658203125.
# States_tracked value 590.7774047851562.
# episode 2719, reward 834.0, memory_length 2000, epsilon 0.25678657153858325 total_time 725.0
# States_tracked value 549.9114379882812.
# States_tracked value 563.57177734375.
# episode 2729, reward 1107.0, memory_length 2000, epsilon 0.2555058431699948 total_time 730.0
# States_tracked value 568.4835205078125.
# States_tracked value 564.2124633789062.
# episode 2739, reward 813.0, memory_length 2000, epsilon 0.25423150246079323 total_time 725.0
# States_tracked value 548.099609375.
# States_tracked value 581.9618530273438.
# episode 2749, reward 1426.0, memory_length 2000, epsilon 0.2529635175523944 total_time 725.0
# States_tracked value 568.5897216796875.
# States_tracked value 601.736572265625.
# episode 2759, reward 876.0, memory_length 2000, epsilon 0.25170185674510953 total_time 723.0
# States_tracked value 597.4690551757812.
# States_tracked value 579.2621459960938.
# episode 2769, reward 1262.0, memory_length 2000, epsilon 0.25044648849735274 total_time 722.0
# States_tracked value 614.458251953125.
# States_tracked value 592.4197387695312.
# episode 2779, reward 1251.0, memory_length 2000, epsilon 0.2491973814248526 total_time 724.0
# States_tracked value 570.6387939453125.
# States_tracked value 583.4092407226562.
# episode 2789, reward 1230.0, memory_length 2000, epsilon 0.24795450429986704 total_time 721.0
# States_tracked value 570.22509765625.
# States_tracked value 597.0628051757812.
# episode 2799, reward 1409.0, memory_length 2000, epsilon 0.24671782605040335 total_time 725.0
# States_tracked value 594.7506713867188.
# States_tracked value 592.6962890625.
# ...
# States_tracked value 621.8040771484375.
# episode 7089, reward 1638.0, memory_length 2000, epsilon 0.02888277159951494 total_time 729.0
# States_tracked value 576.553466796875.
# States_tracked value 604.4147338867188.
# episode 7099, reward 1549.0, memory_length 2000, epsilon 0.028738718175189356 total_time 727.0
# States_tracked value 596.03564453125.
# States_tracked value 606.2156982421875.
# episode 7109, reward 1062.0, memory_length 2000, epsilon 0.028595383220314963 total_time 725.0
# States_tracked value 585.9916381835938.
# States_tracked value 583.3569946289062.
# episode 7119, reward 1665.0, memory_length 2000, epsilon 0.02845276315151042 total_time 722.0
# States_tracked value 593.292724609375.
# States_tracked value 618.1394653320312.
# episode 7129, reward 1413.0, memory_length 2000, epsilon 0.028310854403266573 total_time 728.0
# States_tracked value 640.4714965820312.
# States_tracked value 623.1943969726562.
# episode 7139, reward 1350.0, memory_length 2000, epsilon 0.028169653427857343 total_time 723.0
# States_tracked value 623.5308837890625.
# States_tracked value 620.4486694335938.
# episode 7149, reward 1406.0, memory_length 2000, epsilon 0.028029156695250978 total_time 722.0
# States_tracked value 613.8936157226562.
# States_tracked value 594.5065307617188.
# episode 7159, reward 1447.0, memory_length 2000, epsilon 0.027889360693021847 total_time 722.0
# States_tracked value 599.87646484375.
# States_tracked value 599.49609375.
# episode 7169, reward 1407.0, memory_length 2000, epsilon 0.027750261926262603 total_time 723.0
# States_tracked value 614.0180053710938.
# States_tracked value 605.2579345703125.
# episode 7179, reward 1683.0, memory_length 2000, epsilon 0.027611856917496857 total_time 727.0
# States_tracked value 609.1434326171875.
# States_tracked value 624.7386474609375.
# episode 7189, reward 1348.0, memory_length 2000, epsilon 0.027474142206592167 total_time 721.0
# States_tracked value 640.7702026367188.
# States_tracked value 628.47314453125.
# episode 7199, reward 1505.0, memory_length 2000, epsilon 0.027337114350673587 total_time 721.0
# States_tracked value 633.5430297851562.
# States_tracked value 626.0606079101562.
# episode 7209, reward 1433.0, memory_length 2000, epsilon 0.02720076992403757 total_time 727.0
# States_tracked value 629.6680297851562.
# States_tracked value 608.683349609375.
# episode 7219, reward 1320.0, memory_length 2000, epsilon 0.027065105518066374 total_time 723.0
# States_tracked value 603.4880981445312.
# States_tracked value 624.4854125976562.
# episode 7229, reward 860.0, memory_length 2000, epsilon 0.026930117741142772 total_time 721.0
# States_tracked value 600.8779296875.
# States_tracked value 630.651123046875.
# episode 7239, reward 1464.0, memory_length 2000, epsilon 0.026795803218565308 total_time 726.0
# States_tracked value 629.2824096679688.
# States_tracked value 613.1896362304688.
# episode 7249, reward 1691.0, memory_length 2000, epsilon 0.026662158592463917 total_time 723.0
# States_tracked value 649.143798828125.
# States_tracked value 613.0386352539062.
# episode 7259, reward 1476.0, memory_length 2000, epsilon 0.026529180521716 total_time 726.0
# States_tracked value 617.0492553710938.
# States_tracked value 646.062255859375.
# episode 7269, reward 1611.0, memory_length 2000, epsilon 0.02639686568186286 total_time 724.0
# States_tracked value 613.32470703125.
# States_tracked value 628.2538452148438.
# episode 7279, reward 1550.0, memory_length 2000, epsilon 0.026265210765026602 total_time 728.0
# States_tracked value 620.2239990234375.
# States_tracked value 597.6878662109375.
# episode 7289, reward 1811.0, memory_length 2000, epsilon 0.02613421247982744 total_time 721.0
# States_tracked value 598.8975219726562.
# States_tracked value 606.8506469726562.
# episode 7299, reward 1395.0, memory_length 2000, epsilon 0.02600386755130144 total_time 725.0
# States_tracked value 625.5271606445312.
# States_tracked value 610.0582885742188.
# episode 7309, reward 1538.0, memory_length 2000, epsilon 0.02587417272081859 total_time 726.0
# States_tracked value 598.4046020507812.
# States_tracked value 617.0864868164062.
# episode 7319, reward 1393.0, memory_length 2000, epsilon 0.02574512474600138 total_time 722.0
# States_tracked value 614.9895629882812.
# States_tracked value 631.4823608398438.
# episode 7329, reward 1052.0, memory_length 2000, epsilon 0.02561672040064371 total_time 727.0
# States_tracked value 593.0584106445312.
# States_tracked value 595.9779052734375.
# episode 7339, reward 1647.0, memory_length 2000, epsilon 0.025488956474630255 total_time 723.0
# States_tracked value 596.2649536132812.
# States_tracked value 594.4080200195312.
# episode 7349, reward 1616.0, memory_length 2000, epsilon 0.025361829773856225 total_time 721.0
# States_tracked value 600.5400390625.
# States_tracked value 628.913818359375.
# episode 7359, reward 1206.0, memory_length 2000, epsilon 0.02523533712014747 total_time 724.0
# States_tracked value 609.4797973632812.
# States_tracked value 613.9591064453125.
# episode 7369, reward 1222.0, memory_length 2000, epsilon 0.02510947535118106 total_time 723.0
# States_tracked value 642.640380859375.
# States_tracked value 614.9070434570312.
# episode 7379, reward 1414.0, memory_length 2000, epsilon 0.024984241320406206 total_time 726.0
# States_tracked value 609.10595703125.
# States_tracked value 604.0904541015625.
# episode 7389, reward 1125.0, memory_length 2000, epsilon 0.024859631896965637 total_time 723.0
# States_tracked value 602.1805419921875.
# States_tracked value 564.5408935546875.
# episode 7399, reward 1342.0, memory_length 2000, epsilon 0.02473564396561726 total_time 725.0
# States_tracked value 575.7257690429688.
# States_tracked value 579.5748291015625.
# episode 7409, reward 1617.0, memory_length 2000, epsilon 0.024612274426656346 total_time 724.0
# States_tracked value 642.42431640625.
# States_tracked value 607.0001220703125.
# episode 7419, reward 1427.0, memory_length 2000, epsilon 0.02448952019583798 total_time 729.0
# States_tracked value 616.9826049804688.
# States_tracked value 614.2739868164062.
# episode 7429, reward 1308.0, memory_length 2000, epsilon 0.024367378204300013 total_time 722.0
# States_tracked value 605.0503540039062.
# States_tracked value 602.6660766601562.
# episode 7439, reward 1524.0, memory_length 2000, epsilon 0.024245845398486288 total_time 724.0
# States_tracked value 599.7049560546875.
# States_tracked value 567.2408447265625.
# episode 7449, reward 1234.0, memory_length 2000, epsilon 0.024124918740070334 total_time 721.0
# States_tracked value 566.26611328125.
# States_tracked value 579.7237548828125.
# episode 7459, reward 1296.0, memory_length 2000, epsilon 0.024004595205879373 total_time 732.0
# States_tracked value 572.708740234375.
# States_tracked value 584.0320434570312.
# episode 7469, reward 1323.0, memory_length 2000, epsilon 0.023884871787818816 total_time 721.0
# States_tracked value 600.3626708984375.
# States_tracked value 592.4799194335938.
# episode 7479, reward 1406.0, memory_length 2000, epsilon 0.023765745492796957 total_time 724.0
# States_tracked value 592.2589111328125.
# States_tracked value 605.2611083984375.
# episode 7489, reward 1355.0, memory_length 2000, epsilon 0.023647213342650217 total_time 728.0
# States_tracked value 591.43896484375.
# States_tracked value 578.807861328125.
# episode 7499, reward 1293.0, memory_length 2000, epsilon 0.023529272374068662 total_time 724.0
# States_tracked value 569.8955688476562.
# States_tracked value 607.0011596679688.
# episode 7509, reward 1650.0, memory_length 2000, epsilon 0.02341191963852195 total_time 721.0
# States_tracked value 620.6279296875.
# States_tracked value 623.232421875.
# episode 7519, reward 1807.0, memory_length 2000, epsilon 0.023295152202185577 total_time 723.0
# States_tracked value 615.2110595703125.
# States_tracked value 604.987548828125.
# episode 7529, reward 1810.0, memory_length 2000, epsilon 0.023178967145867545 total_time 725.0
# States_tracked value 587.5833129882812.
# States_tracked value 586.3729248046875.
# episode 7539, reward 1623.0, memory_length 2000, epsilon 0.02306336156493539 total_time 722.0
# States_tracked value 571.3707275390625.
# States_tracked value 593.2022094726562.
# episode 7549, reward 1580.0, memory_length 2000, epsilon 0.022948332569243588 total_time 727.0
# States_tracked value 593.2257080078125.
# States_tracked value 594.0012817382812.
# episode 7559, reward 1609.0, memory_length 2000, epsilon 0.02283387728306124 total_time 723.0
# States_tracked value 579.6085815429688.
# States_tracked value 584.64404296875.
# episode 7569, reward 1218.0, memory_length 2000, epsilon 0.022719992845000238 total_time 725.0
# States_tracked value 582.8325805664062.
# States_tracked value 572.99462890625.
# episode 7579, reward 1598.0, memory_length 2000, epsilon 0.022606676407943692 total_time 726.0
# States_tracked value 591.8030395507812.
# States_tracked value 618.5855102539062.
# episode 7589, reward 1456.0, memory_length 2000, epsilon 0.022493925138974767 total_time 721.0
# States_tracked value 593.1421508789062.
# States_tracked value 639.557861328125.
# episode 7599, reward 1454.0, memory_length 2000, epsilon 0.022381736219305885 total_time 726.0
# States_tracked value 620.27978515625.
# States_tracked value 651.2396850585938.
# episode 7609, reward 1516.0, memory_length 2000, epsilon 0.022270106844208205 total_time 722.0
# States_tracked value 631.2697143554688.
# States_tracked value 630.3131713867188.
# episode 7619, reward 1086.0, memory_length 2000, epsilon 0.02215903422294153 total_time 722.0
# States_tracked value 612.0030517578125.
# States_tracked value 623.311767578125.
# episode 7629, reward 1665.0, memory_length 2000, epsilon 0.022048515578684535 total_time 721.0
# States_tracked value 636.0547485351562.
# States_tracked value 652.5750732421875.
# episode 7639, reward 946.0, memory_length 2000, epsilon 0.021938548148465385 total_time 721.0
# States_tracked value 643.5658569335938.
# States_tracked value 632.098876953125.
# episode 7649, reward 1283.0, memory_length 2000, epsilon 0.02182912918309257 total_time 732.0
# States_tracked value 601.45166015625.
# States_tracked value 621.7119750976562.
# episode 7659, reward 1678.0, memory_length 2000, epsilon 0.021720255947086275 total_time 721.0
# States_tracked value 625.6821899414062.
# States_tracked value 635.2380981445312.
# episode 7669, reward 971.0, memory_length 2000, epsilon 0.02161192571860991 total_time 721.0
# States_tracked value 640.6358642578125.
# States_tracked value 645.3519897460938.
# episode 7679, reward 1530.0, memory_length 2000, epsilon 0.02150413578940214 total_time 726.0
# States_tracked value 634.5444946289062.
# States_tracked value 638.361572265625.
# episode 7689, reward 1557.0, memory_length 2000, epsilon 0.021396883464709117 total_time 728.0
# States_tracked value 639.94189453125.
# States_tracked value 633.4874267578125.
# episode 7699, reward 1584.0, memory_length 2000, epsilon 0.02129016606321713 total_time 721.0
# States_tracked value 618.7180786132812.
# States_tracked value 604.5304565429688.
# episode 7709, reward 905.0, memory_length 2000, epsilon 0.02118398091698558 total_time 727.0
# States_tracked value 609.759033203125.
# States_tracked value 639.6060180664062.
# episode 7719, reward 1499.0, memory_length 2000, epsilon 0.021078325371380293 total_time 733.0
# States_tracked value 642.183349609375.
# States_tracked value 605.193603515625.
# episode 7729, reward 1643.0, memory_length 2000, epsilon 0.020973196785007125 total_time 730.0
# States_tracked value 607.0164184570312.
# States_tracked value 606.4244995117188.
# episode 7739, reward 1344.0, memory_length 2000, epsilon 0.020868592529645933 total_time 725.0
# States_tracked value 601.6299438476562.
# States_tracked value 626.2098388671875.
# episode 7749, reward 1425.0, memory_length 2000, epsilon 0.020764509990184882 total_time 726.0
# States_tracked value 620.8261108398438.
# States_tracked value 645.0086059570312.
# episode 7759, reward 1824.0, memory_length 2000, epsilon 0.020660946564555086 total_time 728.0
# States_tracked value 641.2085571289062.
# States_tracked value 636.8969116210938.
# episode 7769, reward 1033.0, memory_length 2000, epsilon 0.020557899663665488 total_time 726.0
# States_tracked value 618.4524536132812.
# States_tracked value 603.863037109375.
# episode 7779, reward 1512.0, memory_length 2000, epsilon 0.02045536671133821 total_time 735.0
# States_tracked value 600.8255615234375.
# States_tracked value 615.1132202148438.
# episode 7789, reward 1614.0, memory_length 2000, epsilon 0.020353345144244087 total_time 723.0
# States_tracked value 597.653564453125.
# States_tracked value 594.7164306640625.
# episode 7799, reward 1769.0, memory_length 2000, epsilon 0.020251832411838658 total_time 728.0
# States_tracked value 605.6890869140625.
# States_tracked value 608.1605224609375.
# episode 7809, reward 1288.0, memory_length 2000, epsilon 0.0201508259762983 total_time 726.0
# States_tracked value 615.50146484375.
# States_tracked value 600.87060546875.
# episode 7819, reward 1557.0, memory_length 2000, epsilon 0.020050323312456878 total_time 730.0
# States_tracked value 613.241455078125.
# States_tracked value 613.7060546875.
# episode 7829, reward 1521.0, memory_length 2000, epsilon 0.019950321907742555 total_time 728.0
# States_tracked value 624.19091796875.
# States_tracked value 640.2656860351562.
# episode 7839, reward 1719.0, memory_length 2000, epsilon 0.019850819262114995 total_time 723.0
# States_tracked value 607.7145385742188.
# States_tracked value 609.2265625.
# episode 7849, reward 1916.0, memory_length 2000, epsilon 0.019751812888002897 total_time 721.0
# States_tracked value 607.7857055664062.
# States_tracked value 621.6317138671875.
# episode 7859, reward 1735.0, memory_length 2000, epsilon 0.019653300310241737 total_time 722.0
# States_tracked value 632.0974731445312.
# States_tracked value 633.1138916015625.
# episode 7869, reward 1275.0, memory_length 2000, epsilon 0.019555279066011948 total_time 721.0
# States_tracked value 624.1526489257812.
# States_tracked value 624.3153076171875.
# episode 7879, reward 1980.0, memory_length 2000, epsilon 0.0194577467047773 total_time 730.0
# States_tracked value 621.5663452148438.
# States_tracked value 609.00634765625.
# episode 7889, reward 1545.0, memory_length 2000, epsilon 0.01936070078822371 total_time 722.0
# States_tracked value 588.2716064453125.
# States_tracked value 616.7717895507812.
# episode 7899, reward 1588.0, memory_length 2000, epsilon 0.019264138890198193 total_time 721.0
# States_tracked value 628.1876831054688.
# States_tracked value 623.1633911132812.
# episode 7909, reward 1168.0, memory_length 2000, epsilon 0.019168058596648274 total_time 726.0
# States_tracked value 640.8981323242188.
# States_tracked value 623.7788696289062.
# episode 7919, reward 1771.0, memory_length 2000, epsilon 0.0190724575055616 total_time 723.0
# States_tracked value 600.9337768554688.
# States_tracked value 615.2261962890625.
# episode 7929, reward 1048.0, memory_length 2000, epsilon 0.018977333226905934 total_time 724.0
# States_tracked value 601.1915283203125.
# States_tracked value 593.6454467773438.
# episode 7939, reward 1467.0, memory_length 2000, epsilon 0.018882683382569338 total_time 730.0
# States_tracked value 573.9988403320312.
# States_tracked value 577.340087890625.
# episode 7949, reward 1883.0, memory_length 2000, epsilon 0.018788505606300788 total_time 724.0
# States_tracked value 595.6735229492188.
# States_tracked value 630.58203125.
# episode 7959, reward 1332.0, memory_length 2000, epsilon 0.01869479754365095 total_time 728.0
# States_tracked value 632.358154296875.
# States_tracked value 630.7532958984375.
# episode 7969, reward 1900.0, memory_length 2000, epsilon 0.0186015568519134 total_time 728.0
# States_tracked value 619.4833374023438.
# States_tracked value 606.849853515625.
# episode 7979, reward 1391.0, memory_length 2000, epsilon 0.018508781200065983 total_time 731.0
# States_tracked value 619.1469116210938.
# States_tracked value 625.0741577148438.
# episode 7989, reward 1663.0, memory_length 2000, epsilon 0.018416468268712564 total_time 724.0
# States_tracked value 621.4348754882812.
# States_tracked value 627.5350952148438.
# episode 7999, reward 1557.0, memory_length 2000, epsilon 0.018324615750025048 total_time 727.0
# States_tracked value 608.4293823242188.
# 5626.204123497009

# %%
agent.states_tracked
# Out:
# [326.12296,
#  376.0375,
#  360.50656,
#  365.78177,
#  414.95993,
#  336.52887,
#  275.45453,
#  438.7415,
#  436.069,
#  456.94196,
#  281.09973,
#  348.45264,
#  379.74188,
#  445.99625,
#  406.65985,
#  372.24472,
#  412.00732,
#  412.6601,
#  436.5085,
#  496.99036,
#  513.6442,
#  527.35596,
#  520.81683,
#  545.1335,
#  538.913,
#  493.99002,
#  465.09592,
#  541.0179,
#  510.85117,
#  615.00385,
#  592.3994,
#  602.37067,
#  608.1137,
#  658.4722,
#  568.45154,
#  523.96924,
#  531.78687,
#  647.3273,
#  713.1809,
#  648.70056,
#  537.81415,
#  613.2829,
#  619.4544,
#  695.3672,
#  685.12024,
#  714.8894,
#  576.0838,
#  590.7064,
#  601.61835,
#  654.1818,
#  587.86194,
#  791.7337,
#  731.2205,
#  670.88763,
#  769.11285,
#  725.57623,
#  696.19403,
#  661.5567,
#  727.35803,
#  622.1708,
#  600.4454,
#  612.2174,
#  736.7844,
#  681.91583,
#  783.19525,
#  734.0915,
#  705.98303,
#  663.1379,
#  678.7067,
#  630.82043,
#  637.91016,
#  726.7219,
#  638.4062,
#  712.05383,
#  597.7495,
#  673.1382,
#  574.26495,
#  626.6919,
#  661.17554,
#  802.8943,
#  760.94403,
#  673.94867,
#  638.2681,
#  614.8065,
#  586.5609,
#  634.04126,
#  604.98627,
#  699.528,
#  678.83075,
#  726.2417,
#  756.39075,
#  657.46106,
#  666.3588,
#  765.85455,
#  764.70514,
#  810.5467,
#  748.7004,
#  567.2234,
#  573.19684,
#  576.89026,
#  582.35126,
#  581.05096,
#  638.8617,
#  635.46405,
#  641.5307,
#  654.0585,
#  683.48303,
#  644.80884,
#  633.4138,
#  645.5743,
#  678.81696,
#  629.34106,
#  605.54376,
#  591.91376,
#  597.94745,
#  567.9547,
#  554.20966,
#  600.14624,
#  560.64954,
#  605.87756,
#  647.36536,
#  710.61536,
#  725.2804,
#  772.4087,
#  681.3021,
#  651.1818,
#  685.50525,
#  723.58936,
#  615.8439,
#  667.24603,
#  678.33203,
#  623.74243,
#  602.24536,
#  523.836,
#  565.619,
#  610.20514,
#  579.47833,
#  597.6395,
#  651.7028,
#  619.0857,
#  587.64557,
#  637.5502,
#  615.2574,
#  647.66437,
#  671.2393,
#  686.39435,
#  613.81055,
#  612.5713,
#  629.7277,
#  712.745,
#  627.6704,
#  696.63617,
#  722.8115,
#  847.41016,
#  678.9592,
#  621.4093,
#  667.72906,
#  738.02435,
#  622.0449,
#  626.23944,
#  610.80505,
#  636.1353,
#  582.51697,
#  590.4919,
#  602.8955,
#  552.72015,
#  642.3945,
#  591.8823,
#  644.1162,
#  601.5114,
#  622.6875,
#  661.18634,
#  629.761,
#  653.7906,
#  637.66705,
#  624.258,
#  598.97906,
#  636.71655,
#  638.2646,
#  628.45074,
#  591.7342,
#  658.92084,
#  641.0699,
#  655.08966,
#  641.5113,
#  622.03516,
#  687.4253,
#  723.0575,
#  601.0515,
#  579.77527,
#  644.94366,
#  645.33563,
#  638.72266,
#  603.51166,
#  561.8892,
#  617.69885,
#  573.5718,
#  560.4492,
#  628.3454,
#  601.54803,
#  599.92413,
#  592.241,
#  598.84674,
#  581.3233,
#  614.8178,
#  600.3273,
#  598.22473,
#  622.32654,
#  633.2186,
#  581.50244,
#  562.7253,
#  611.6734,
#  585.66113,
#  591.68365,
#  560.98474,
#  562.84644,
#  576.0473,
#  568.68463,
#  678.2827,
#  634.7659,
#  641.2266,
#  603.3117,
#  595.64777,
#  609.20404,
#  615.2675,
#  632.2189,
#  655.89087,
#  657.94824,
#  825.3568,
#  923.851,
#  673.7381,
#  599.12787,
#  624.1991,
#  630.0014,
#  597.8166,
#  618.46185,
#  581.56146,
#  637.81024,
#  661.7505,
#  654.22723,
#  627.00146,
#  576.699,
#  629.99347,
#  567.049,
#  536.9864,
#  606.1747,
#  626.1597,
#  601.99005,
#  584.85754,
#  554.0862,
#  583.2121,
#  560.5793,
#  586.98175,
#  616.2203,
#  630.94946,
#  562.5649,
#  570.86975,
#  590.4479,
#  674.44336,
#  641.3756,
#  567.7505,
#  684.41693,
#  627.2276,
#  610.70886,
#  576.23456,
#  622.1144,
#  616.0936,
#  592.4602,
#  631.4386,
#  610.4018,
#  618.7283,
#  699.2667,
#  663.23376,
#  650.24615,
#  592.18854,
#  582.0067,
#  603.3776,
#  600.46796,
#  591.4633,
#  633.93787,
#  574.55444,
#  565.2028,
#  579.8758,
#  588.72064,
#  594.9256,
#  563.85333,
#  549.84174,
#  583.54694,
#  579.72644,
#  554.61975,
#  630.6751,
#  706.1872,
#  624.30566,
#  577.07745,
#  584.7403,
#  576.48096,
#  591.1105,
#  608.7745,
#  560.6041,
#  612.2162,
#  620.8821,
#  637.4785,
#  633.82556,
#  587.46875,
#  573.2215,
#  585.35736,
#  559.1069,
#  546.5002,
#  573.92523,
#  579.07513,
#  588.0248,
#  607.29877,
#  599.28973,
#  597.10626,
#  593.44617,
#  616.0096,
#  580.9294,
#  576.48615,
#  601.72296,
#  598.9727,
#  574.0219,
#  597.197,
#  634.1513,
#  650.993,
#  613.9006,
#  576.4632,
#  595.29645,
#  607.59467,
#  613.5097,
#  612.8808,
#  612.46985,
#  607.4014,
#  586.6888,
#  581.638,
#  578.28955,
#  613.214,
#  572.0838,
#  615.4183,
#  618.7798,
#  643.80896,
#  595.2807,
#  602.9128,
#  668.7595,
#  648.1531,
#  638.7599,
#  639.2801,
#  685.4709,
#  589.7797,
#  601.5321,
#  639.06116,
#  605.0672,
#  592.73566,
#  603.1719,
#  592.6619,
#  607.6652,
#  663.35333,
#  611.0556,
#  596.5788,
#  565.9801,
#  558.0527,
#  555.1637,
#  552.11847,
#  568.2504,
#  560.4168,
#  560.5099,
#  581.35187,
#  587.1931,
#  636.6457,
#  583.9809,
#  602.6078,
#  641.0074,
#  597.5996,
#  583.9155,
#  568.1364,
#  575.1634,
#  560.2943,
#  547.72174,
#  602.93646,
#  578.6843,
#  546.0514,
#  546.38855,
#  573.52795,
#  565.1821,
#  575.1681,
#  582.0402,
#  595.12805,
#  593.36523,
#  596.32526,
#  614.3316,
#  634.211,
#  629.15845,
#  628.83386,
#  642.6992,
#  653.6575,
#  639.73755,
#  650.15704,
#  590.34863,
#  608.4826,
#  573.5581,
#  539.0794,
#  545.78424,
#  590.80457,
#  623.32513,
#  605.66406,
#  603.82214,
#  604.4752,
#  599.2311,
#  629.7159,
#  634.7573,
#  642.17633,
#  609.78656,
#  607.8938,
#  604.413,
#  573.49066,
#  619.42035,
#  582.89874,
#  612.91034,
#  647.8426,
#  572.6516,
#  621.31506,
#  589.15424,
#  616.6698,
#  599.0871,
#  556.05914,
#  548.79926,
#  581.7606,
#  564.76105,
#  591.5472,
#  564.43396,
#  582.7207,
#  595.485,
#  601.108,
#  589.9268,
#  598.3548,
#  595.2042,
#  571.3221,
#  582.50507,
#  600.52686,
#  589.9641,
#  593.2165,
#  603.67224,
#  578.6952,
#  591.20734,
#  596.724,
#  619.60394,
#  588.25946,
#  600.7246,
#  610.70306,
#  610.8476,
#  586.2951,
#  564.2318,
#  586.82733,
#  565.0127,
#  589.7983,
#  587.4805,
#  593.48285,
#  595.12854,
#  573.2623,
#  609.97095,
#  608.04034,
#  595.87524,
#  613.57996,
#  600.299,
#  615.2564,
#  609.24414,
#  583.0617,
#  591.4399,
#  577.0505,
#  598.20917,
#  640.0129,
#  615.3198,
#  652.82745,
#  598.94434,
#  626.97565,
#  573.26105,
#  570.3179,
#  605.3479,
#  575.1892,
#  581.6975,
#  606.9954,
#  617.407,
#  647.04193,
#  609.9467,
#  601.8468,
#  582.61774,
#  578.96985,
#  599.9964,
#  635.3368,
#  611.71674,
#  626.0463,
#  601.75775,
#  600.1167,
#  561.4486,
#  600.5403,
#  618.7104,
#  605.4175,
#  578.20715,
#  613.79004,
#  606.5376,
#  600.8866,
#  635.9326,
#  605.44885,
#  624.05084,
#  612.5723,
#  620.01465,
#  624.1906,
#  626.3391,
#  621.7833,
#  600.6826,
#  601.88293,
#  604.9291,
#  587.22534,
#  577.3627,
#  593.55383,
#  619.13995,
#  606.0401,
#  571.1812,
#  616.8421,
#  598.62335,
#  624.44403,
#  602.8146,
#  560.5424,
#  559.7862,
#  606.10077,
#  567.60876,
#  584.2131,
#  587.38684,
#  634.09375,
#  589.19543,
#  617.72986,
#  577.8684,
#  584.63654,
#  587.94763,
#  575.224,
#  598.322,
#  598.9266,
#  617.79895,
#  597.10077,
#  600.15894,
#  609.90216,
#  638.6354,
#  575.2466,
#  590.7774,
#  549.91144,
#  563.5718,
#  568.4835,
#  564.21246,
#  548.0996,
#  581.96185,
#  568.5897,
#  601.7366,
#  597.46906,
#  579.26215,
#  614.45825,
#  592.41974,
#  570.6388,
#  583.40924,
#  570.2251,
#  597.0628,
#  594.7507,
#  592.6963,
#  632.99567,
#  612.5642,
#  623.5105,
#  631.1972,
#  604.9164,
#  621.5941,
#  607.1245,
#  599.89,
#  591.2552,
#  600.8257,
#  603.0031,
#  627.7522,
#  613.35815,
#  615.59546,
#  620.429,
#  599.6282,
#  561.0762,
#  580.333,
#  595.8784,
#  602.80176,
#  555.0266,
#  577.78723,
#  614.753,
#  619.95966,
#  609.39746,
#  601.6527,
#  575.13434,
#  605.2381,
#  605.1132,
#  595.6719,
#  609.01013,
#  618.8741,
#  588.3552,
#  586.69666,
#  596.2952,
#  614.18665,
#  607.4847,
#  605.9739,
#  590.2394,
#  612.8267,
#  622.0728,
#  591.4871,
#  615.573,
#  623.6114,
#  603.8081,
#  683.22314,
#  651.1616,
#  697.16705,
#  641.5017,
#  607.51746,
#  595.85724,
#  582.6067,
#  614.8042,
#  615.4341,
#  614.6665,
#  637.7069,
#  639.4392,
#  604.97656,
#  598.32355,
#  604.5796,
#  596.7241,
#  594.9919,
#  586.6866,
#  600.9553,
#  606.42664,
#  640.9549,
#  633.20844,
#  651.2801,
#  650.57776,
#  637.9453,
#  627.88434,
#  625.5658,
#  626.4047,
#  617.1338,
#  637.88727,
#  636.02246,
#  637.8599,
#  632.3739,
#  631.8764,
#  608.7621,
#  567.604,
#  548.03906,
#  568.21277,
#  601.3798,
#  586.20105,
#  613.2491,
#  608.7494,
#  624.4774,
#  624.1722,
#  654.2246,
#  630.41644,
#  649.68976,
#  613.769,
#  615.5211,
#  632.0322,
#  625.73737,
#  617.5836,
#  575.0416,
#  619.57605,
#  652.6423,
#  626.9127,
#  596.4887,
#  600.50165,
#  597.80115,
#  615.05505,
#  615.3819,
#  602.50604,
#  595.3985,
#  611.53455,
#  598.53577,
#  602.6059,
#  550.93726,
#  589.3291,
#  594.0499,
#  618.82446,
#  615.9429,
#  631.5286,
#  605.7209,
#  602.2866,
#  571.3009,
#  566.0058,
#  590.91705,
#  604.7257,
#  608.0198,
#  605.49786,
#  604.38617,
#  600.246,
#  580.3204,
#  569.60223,
#  597.8807,
#  609.8647,
#  614.9878,
#  609.99054,
#  589.3779,
#  593.3578,
#  620.9675,
#  637.1555,
#  611.9091,
#  602.1059,
#  588.6244,
#  579.06226,
#  577.70123,
#  585.16815,
#  556.68066,
#  560.7299,
#  565.7672,
#  567.4058,
#  566.92,
#  585.7981,
#  586.7778,
#  626.1063,
#  595.3107,
#  593.07666,
#  631.2218,
#  616.73663,
#  620.1173,
#  616.24164,
#  600.9449,
#  620.103,
#  601.37445,
#  600.54224,
#  609.02594,
#  587.7407,
#  606.9785,
#  590.29114,
#  594.68665,
#  600.76575,
#  607.0521,
#  595.0727,
#  583.63116,
#  621.72327,
#  613.6655,
#  590.6876,
#  601.05304,
#  602.8265,
#  602.9425,
#  607.86725,
#  599.22736,
#  588.3653,
#  603.081,
#  593.2569,
#  600.8697,
#  602.4134,
#  569.9723,
#  576.74554,
#  568.82806,
#  590.78534,
#  550.1052,
#  603.1062,
#  597.3926,
#  594.18665,
#  582.4419,
#  594.55426,
#  620.0945,
#  599.68195,
#  589.35114,
#  576.22736,
#  608.84015,
#  631.9289,
#  589.80566,
#  594.3702,
#  552.2588,
#  566.04895,
#  573.57294,
#  616.6825,
#  597.1498,
#  592.1925,
#  562.9937,
#  573.02155,
#  563.17267,
#  566.845,
#  593.8886,
#  582.5699,
#  573.85754,
#  572.4448,
#  594.76355,
#  564.64734,
#  592.6853,
#  596.45197,
#  607.6808,
#  615.22565,
#  630.03406,
#  636.76697,
#  614.23395,
#  608.63354,
#  596.48755,
#  629.2379,
#  607.70605,
#  598.4249,
#  609.0546,
#  614.5501,
#  590.3356,
#  578.2509,
#  614.64185,
#  565.5818,
#  588.84515,
#  580.14526,
#  601.3322,
#  603.2601,
#  585.45996,
#  595.6497,
#  612.0864,
#  624.1896,
#  610.4274,
#  624.0721,
#  607.4277,
#  601.7269,
#  619.3341,
#  601.4064,
#  592.3931,
#  583.12,
#  559.83527,
#  569.9361,
#  582.6199,
#  585.57324,
#  618.5618,
#  604.0903,
#  600.6266,
#  655.9713,
#  619.7153,
#  609.4652,
#  592.7324,
#  595.69885,
#  579.50226,
#  574.06714,
#  574.895,
#  571.5234,
#  560.6397,
#  562.3941,
#  581.5551,
#  583.03174,
#  595.27,
#  605.87555,
#  623.3446,
#  618.703,
#  616.232,
#  584.8837,
#  590.7653,
#  601.8705,
#  595.9608,
#  578.13367,
#  587.00964,
#  587.9241,
#  592.9235,
#  593.0939,
#  615.8507,
#  625.2506,
#  603.3746,
#  609.0431,
#  638.75977,
#  640.6488,
#  606.63745,
#  582.37036,
#  586.97015,
#  585.2832,
#  591.7978,
#  582.49506,
#  611.86505,
#  594.94574,
#  567.9068,
#  549.18506,
#  540.80396,
#  557.08307,
#  576.7706,
#  568.8803,
#  615.1367,
#  600.2684,
#  595.4245,
#  600.234,
#  619.07404,
#  625.31476,
#  618.6516,
#  566.2148,
#  566.55273,
#  606.86774,
#  607.3755,
#  623.0132,
#  630.02155,
#  608.54266,
#  628.15485,
#  594.51843,
#  596.2912,
#  605.40173,
#  584.463,
#  582.52057,
#  590.5278,
#  600.23303,
#  607.61414,
#  598.4543,
#  612.0414,
#  630.83856,
#  613.7945,
#  603.70886,
#  585.3547,
#  566.21466,
#  607.17126,
#  597.19696,
#  605.84656,
#  604.51465,
#  578.5832,
#  594.18774,
#  596.5546,
#  591.32043,
#  574.42145,
#  585.5731,
#  583.50024,
#  585.8346,
#  577.06305,
#  611.89655,
#  611.22003,
#  598.2335,
#  557.07275,
#  598.74133,
#  587.85284,
#  579.59686,
#  559.96063,
#  579.87683,
#  590.4685,
#  581.47,
#  612.258,
#  579.6459,
#  594.89594,
#  606.95044,
#  603.2602,
#  597.8818,
#  597.23706,
#  577.95416,
#  592.27216,
#  602.0033,
#  595.83417,
#  575.2686,
#  587.81274,
#  593.397,
#  618.75464,
#  615.0389,
#  598.4288,
#  611.55225,
#  591.2438,
#  608.0817,
#  622.325,
#  615.20953,
#  608.9859,
#  604.3069,
#  618.85205,
#  613.9546,
#  601.1369,
#  598.5375,
#  584.9266,
#  580.9133,
#  613.89026,
#  610.5536,
#  586.4457,
#  601.16974,
#  556.70483,
#  611.80304,
#  580.5787,
#  612.49805,
#  628.46704,
#  621.4581,
#  604.8741,
#  617.43115,
#  575.46497,
#  577.2198,
#  581.5674,
#  569.9688,
#  564.1872,
#  577.90247,
#  576.89685,
#  550.49585,
#  568.8755,
#  557.47925,
#  605.7447,
#  591.9642,
#  555.59766,
#  551.2905,
#  552.9698,
#  580.8311,
#  578.1746,
#  542.425,
#  541.9971,
#  575.17566,
#  567.1888,
#  575.7104,
#  608.9635,
#  598.0033,
#  606.62317,
#  604.28845,
#  603.388,
#  607.52277,
#  613.54816,
#  619.8828,
#  580.11523,
#  590.5741,
#  601.43884,
#  598.53375,
#  594.89185,
#  556.1829,
#  547.5852,
#  579.3827,
#  ...]

# %% [markdown]
# ### The 'total_time' above includes the 'last ride' time also in each episode. Although it exceeds 24*30 = 720, our code drops the last ride from the replay buffer. So the total ride time per episode is limited to < 720

# %%
# saved file available in (r'D:\Assignment')
def save_obj(model, name):
    with open(file_path+"\\"+ name + '.pkl', 'wb') as f:
        pickle.dump(model, f, pickle.HIGHEST_PROTOCOL)

# %%
save_obj(agent.states_tracked, "SuperCabs_model_weights")

# %% [markdown]
# ### Tracking Convergence

# %%
agent.states_tracked
# Out:
# [326.12296,
#  376.0375,
#  360.50656,
#  365.78177,
#  414.95993,
#  336.52887,
#  275.45453,
#  438.7415,
#  436.069,
#  456.94196,
#  281.09973,
#  348.45264,
#  379.74188,
#  445.99625,
#  406.65985,
#  372.24472,
#  412.00732,
#  412.6601,
#  436.5085,
#  496.99036,
#  513.6442,
#  527.35596,
#  520.81683,
#  545.1335,
#  538.913,
#  493.99002,
#  465.09592,
#  541.0179,
#  510.85117,
#  615.00385,
#  592.3994,
#  602.37067,
#  608.1137,
#  658.4722,
#  568.45154,
#  523.96924,
#  531.78687,
#  647.3273,
#  713.1809,
#  648.70056,
#  537.81415,
#  613.2829,
#  619.4544,
#  695.3672,
#  685.12024,
#  714.8894,
#  576.0838,
#  590.7064,
#  601.61835,
#  654.1818,
#  587.86194,
#  791.7337,
#  731.2205,
#  670.88763,
#  769.11285,
#  725.57623,
#  696.19403,
#  661.5567,
#  727.35803,
#  622.1708,
#  600.4454,
#  612.2174,
#  736.7844,
#  681.91583,
#  783.19525,
#  734.0915,
#  705.98303,
#  663.1379,
#  678.7067,
#  630.82043,
#  637.91016,
#  726.7219,
#  638.4062,
#  712.05383,
#  597.7495,
#  673.1382,
#  574.26495,
#  626.6919,
#  661.17554,
#  802.8943,
#  760.94403,
#  673.94867,
#  638.2681,
#  614.8065,
#  586.5609,
#  634.04126,
#  604.98627,
#  699.528,
#  678.83075,
#  726.2417,
#  756.39075,
#  657.46106,
#  666.3588,
#  765.85455,
#  764.70514,
#  810.5467,
#  748.7004,
#  567.2234,
#  573.19684,
#  576.89026,
#  582.35126,
#  581.05096,
#  638.8617,
#  635.46405,
#  641.5307,
#  654.0585,
#  683.48303,
#  644.80884,
#  633.4138,
#  645.5743,
#  678.81696,
#  629.34106,
#  605.54376,
#  591.91376,
#  597.94745,
#  567.9547,
#  554.20966,
#  600.14624,
#  560.64954,
#  605.87756,
#  647.36536,
#  710.61536,
#  725.2804,
#  772.4087,
#  681.3021,
#  651.1818,
#  685.50525,
#  723.58936,
#  615.8439,
#  667.24603,
#  678.33203,
#  623.74243,
#  602.24536,
#  523.836,
#  565.619,
#  610.20514,
#  579.47833,
#  597.6395,
#  651.7028,
#  619.0857,
#  587.64557,
#  637.5502,
#  615.2574,
#  647.66437,
#  671.2393,
#  686.39435,
#  613.81055,
#  612.5713,
#  629.7277,
#  712.745,
#  627.6704,
#  696.63617,
#  722.8115,
#  847.41016,
#  678.9592,
#  621.4093,
#  667.72906,
#  738.02435,
#  622.0449,
#  626.23944,
#  610.80505,
#  636.1353,
#  582.51697,
#  590.4919,
#  602.8955,
#  552.72015,
#  642.3945,
#  591.8823,
#  644.1162,
#  601.5114,
#  622.6875,
#  661.18634,
#  629.761,
#  653.7906,
#  637.66705,
#  624.258,
#  598.97906,
#  636.71655,
#  638.2646,
#  628.45074,
#  591.7342,
#  658.92084,
#  641.0699,
#  655.08966,
#  641.5113,
#  622.03516,
#  687.4253,
#  723.0575,
#  601.0515,
#  579.77527,
#  644.94366,
#  645.33563,
#  638.72266,
#  603.51166,
#  561.8892,
#  617.69885,
#  573.5718,
#  560.4492,
#  628.3454,
#  601.54803,
#  599.92413,
#  592.241,
#  598.84674,
#  581.3233,
#  614.8178,
#  600.3273,
#  598.22473,
#  622.32654,
#  633.2186,
#  581.50244,
#  562.7253,
#  611.6734,
#  585.66113,
#  591.68365,
#  560.98474,
#  562.84644,
#  576.0473,
#  568.68463,
#  678.2827,
#  634.7659,
#  641.2266,
#  603.3117,
#  595.64777,
#  609.20404,
#  615.2675,
#  632.2189,
#  655.89087,
#  657.94824,
#  825.3568,
#  923.851,
#  673.7381,
#  599.12787,
#  624.1991,
#  630.0014,
#  597.8166,
#  618.46185,
#  581.56146,
#  637.81024,
#  661.7505,
#  654.22723,
#  627.00146,
#  576.699,
#  629.99347,
#  567.049,
#  536.9864,
#  606.1747,
#  626.1597,
#  601.99005,
#  584.85754,
#  554.0862,
#  583.2121,
#  560.5793,
#  586.98175,
#  616.2203,
#  630.94946,
#  562.5649,
#  570.86975,
#  590.4479,
#  674.44336,
#  641.3756,
#  567.7505,
#  684.41693,
#  627.2276,
#  610.70886,
#  576.23456,
#  622.1144,
#  616.0936,
#  592.4602,
#  631.4386,
#  610.4018,
#  618.7283,
#  699.2667,
#  663.23376,
#  650.24615,
#  592.18854,
#  582.0067,
#  603.3776,
#  600.46796,
#  591.4633,
#  633.93787,
#  574.55444,
#  565.2028,
#  579.8758,
#  588.72064,
#  594.9256,
#  563.85333,
#  549.84174,
#  583.54694,
#  579.72644,
#  554.61975,
#  630.6751,
#  706.1872,
#  624.30566,
#  577.07745,
#  584.7403,
#  576.48096,
#  591.1105,
#  608.7745,
#  560.6041,
#  612.2162,
#  620.8821,
#  637.4785,
#  633.82556,
#  587.46875,
#  573.2215,
#  585.35736,
#  559.1069,
#  546.5002,
#  573.92523,
#  579.07513,
#  588.0248,
#  607.29877,
#  599.28973,
#  597.10626,
#  593.44617,
#  616.0096,
#  580.9294,
#  576.48615,
#  601.72296,
#  598.9727,
#  574.0219,
#  597.197,
#  634.1513,
#  650.993,
#  613.9006,
#  576.4632,
#  595.29645,
#  607.59467,
#  613.5097,
#  612.8808,
#  612.46985,
#  607.4014,
#  586.6888,
#  581.638,
#  578.28955,
#  613.214,
#  572.0838,
#  615.4183,
#  618.7798,
#  643.80896,
#  595.2807,
#  602.9128,
#  668.7595,
#  648.1531,
#  638.7599,
#  639.2801,
#  685.4709,
#  589.7797,
#  601.5321,
#  639.06116,
#  605.0672,
#  592.73566,
#  603.1719,
#  592.6619,
#  607.6652,
#  663.35333,
#  611.0556,
#  596.5788,
#  565.9801,
#  558.0527,
#  555.1637,
#  552.11847,
#  568.2504,
#  560.4168,
#  560.5099,
#  581.35187,
#  587.1931,
#  636.6457,
#  583.9809,
#  602.6078,
#  641.0074,
#  597.5996,
#  583.9155,
#  568.1364,
#  575.1634,
#  560.2943,
#  547.72174,
#  602.93646,
#  578.6843,
#  546.0514,
#  546.38855,
#  573.52795,
#  565.1821,
#  575.1681,
#  582.0402,
#  595.12805,
#  593.36523,
#  596.32526,
#  614.3316,
#  634.211,
#  629.15845,
#  628.83386,
#  642.6992,
#  653.6575,
#  639.73755,
#  650.15704,
#  590.34863,
#  608.4826,
#  573.5581,
#  539.0794,
#  545.78424,
#  590.80457,
#  623.32513,
#  605.66406,
#  603.82214,
#  604.4752,
#  599.2311,
#  629.7159,
#  634.7573,
#  642.17633,
#  609.78656,
#  607.8938,
#  604.413,
#  573.49066,
#  619.42035,
#  582.89874,
#  612.91034,
#  647.8426,
#  572.6516,
#  621.31506,
#  589.15424,
#  616.6698,
#  599.0871,
#  556.05914,
#  548.79926,
#  581.7606,
#  564.76105,
#  591.5472,
#  564.43396,
#  582.7207,
#  595.485,
#  601.108,
#  589.9268,
#  598.3548,
#  595.2042,
#  571.3221,
#  582.50507,
#  600.52686,
#  589.9641,
#  593.2165,
#  603.67224,
#  578.6952,
#  591.20734,
#  596.724,
#  619.60394,
#  588.25946,
#  600.7246,
#  610.70306,
#  610.8476,
#  586.2951,
#  564.2318,
#  586.82733,
#  565.0127,
#  589.7983,
#  587.4805,
#  593.48285,
#  595.12854,
#  573.2623,
#  609.97095,
#  608.04034,
#  595.87524,
#  613.57996,
#  600.299,
#  615.2564,
#  609.24414,
#  583.0617,
#  591.4399,
#  577.0505,
#  598.20917,
#  640.0129,
#  615.3198,
#  652.82745,
#  598.94434,
#  626.97565,
#  573.26105,
#  570.3179,
#  605.3479,
#  575.1892,
#  581.6975,
#  606.9954,
#  617.407,
#  647.04193,
#  609.9467,
#  601.8468,
#  582.61774,
#  578.96985,
#  599.9964,
#  635.3368,
#  611.71674,
#  626.0463,
#  601.75775,
#  600.1167,
#  561.4486,
#  600.5403,
#  618.7104,
#  605.4175,
#  578.20715,
#  613.79004,
#  606.5376,
#  600.8866,
#  635.9326,
#  605.44885,
#  624.05084,
#  612.5723,
#  620.01465,
#  624.1906,
#  626.3391,
#  621.7833,
#  600.6826,
#  601.88293,
#  604.9291,
#  587.22534,
#  577.3627,
#  593.55383,
#  619.13995,
#  606.0401,
#  571.1812,
#  616.8421,
#  598.62335,
#  624.44403,
#  602.8146,
#  560.5424,
#  559.7862,
#  606.10077,
#  567.60876,
#  584.2131,
#  587.38684,
#  634.09375,
#  589.19543,
#  617.72986,
#  577.8684,
#  584.63654,
#  587.94763,
#  575.224,
#  598.322,
#  598.9266,
#  617.79895,
#  597.10077,
#  600.15894,
#  609.90216,
#  638.6354,
#  575.2466,
#  590.7774,
#  549.91144,
#  563.5718,
#  568.4835,
#  564.21246,
#  548.0996,
#  581.96185,
#  568.5897,
#  601.7366,
#  597.46906,
#  579.26215,
#  614.45825,
#  592.41974,
#  570.6388,
#  583.40924,
#  570.2251,
#  597.0628,
#  594.7507,
#  592.6963,
#  632.99567,
#  612.5642,
#  623.5105,
#  631.1972,
#  604.9164,
#  621.5941,
#  607.1245,
#  599.89,
#  591.2552,
#  600.8257,
#  603.0031,
#  627.7522,
#  613.35815,
#  615.59546,
#  620.429,
#  599.6282,
#  561.0762,
#  580.333,
#  595.8784,
#  602.80176,
#  555.0266,
#  577.78723,
#  614.753,
#  619.95966,
#  609.39746,
#  601.6527,
#  575.13434,
#  605.2381,
#  605.1132,
#  595.6719,
#  609.01013,
#  618.8741,
#  588.3552,
#  586.69666,
#  596.2952,
#  614.18665,
#  607.4847,
#  605.9739,
#  590.2394,
#  612.8267,
#  622.0728,
#  591.4871,
#  615.573,
#  623.6114,
#  603.8081,
#  683.22314,
#  651.1616,
#  697.16705,
#  641.5017,
#  607.51746,
#  595.85724,
#  582.6067,
#  614.8042,
#  615.4341,
#  614.6665,
#  637.7069,
#  639.4392,
#  604.97656,
#  598.32355,
#  604.5796,
#  596.7241,
#  594.9919,
#  586.6866,
#  600.9553,
#  606.42664,
#  640.9549,
#  633.20844,
#  651.2801,
#  650.57776,
#  637.9453,
#  627.88434,
#  625.5658,
#  626.4047,
#  617.1338,
#  637.88727,
#  636.02246,
#  637.8599,
#  632.3739,
#  631.8764,
#  608.7621,
#  567.604,
#  548.03906,
#  568.21277,
#  601.3798,
#  586.20105,
#  613.2491,
#  608.7494,
#  624.4774,
#  624.1722,
#  654.2246,
#  630.41644,
#  649.68976,
#  613.769,
#  615.5211,
#  632.0322,
#  625.73737,
#  617.5836,
#  575.0416,
#  619.57605,
#  652.6423,
#  626.9127,
#  596.4887,
#  600.50165,
#  597.80115,
#  615.05505,
#  615.3819,
#  602.50604,
#  595.3985,
#  611.53455,
#  598.53577,
#  602.6059,
#  550.93726,
#  589.3291,
#  594.0499,
#  618.82446,
#  615.9429,
#  631.5286,
#  605.7209,
#  602.2866,
#  571.3009,
#  566.0058,
#  590.91705,
#  604.7257,
#  608.0198,
#  605.49786,
#  604.38617,
#  600.246,
#  580.3204,
#  569.60223,
#  597.8807,
#  609.8647,
#  614.9878,
#  609.99054,
#  589.3779,
#  593.3578,
#  620.9675,
#  637.1555,
#  611.9091,
#  602.1059,
#  588.6244,
#  579.06226,
#  577.70123,
#  585.16815,
#  556.68066,
#  560.7299,
#  565.7672,
#  567.4058,
#  566.92,
#  585.7981,
#  586.7778,
#  626.1063,
#  595.3107,
#  593.07666,
#  631.2218,
#  616.73663,
#  620.1173,
#  616.24164,
#  600.9449,
#  620.103,
#  601.37445,
#  600.54224,
#  609.02594,
#  587.7407,
#  606.9785,
#  590.29114,
#  594.68665,
#  600.76575,
#  607.0521,
#  595.0727,
#  583.63116,
#  621.72327,
#  613.6655,
#  590.6876,
#  601.05304,
#  602.8265,
#  602.9425,
#  607.86725,
#  599.22736,
#  588.3653,
#  603.081,
#  593.2569,
#  600.8697,
#  602.4134,
#  569.9723,
#  576.74554,
#  568.82806,
#  590.78534,
#  550.1052,
#  603.1062,
#  597.3926,
#  594.18665,
#  582.4419,
#  594.55426,
#  620.0945,
#  599.68195,
#  589.35114,
#  576.22736,
#  608.84015,
#  631.9289,
#  589.80566,
#  594.3702,
#  552.2588,
#  566.04895,
#  573.57294,
#  616.6825,
#  597.1498,
#  592.1925,
#  562.9937,
#  573.02155,
#  563.17267,
#  566.845,
#  593.8886,
#  582.5699,
#  573.85754,
#  572.4448,
#  594.76355,
#  564.64734,
#  592.6853,
#  596.45197,
#  607.6808,
#  615.22565,
#  630.03406,
#  636.76697,
#  614.23395,
#  608.63354,
#  596.48755,
#  629.2379,
#  607.70605,
#  598.4249,
#  609.0546,
#  614.5501,
#  590.3356,
#  578.2509,
#  614.64185,
#  565.5818,
#  588.84515,
#  580.14526,
#  601.3322,
#  603.2601,
#  585.45996,
#  595.6497,
#  612.0864,
#  624.1896,
#  610.4274,
#  624.0721,
#  607.4277,
#  601.7269,
#  619.3341,
#  601.4064,
#  592.3931,
#  583.12,
#  559.83527,
#  569.9361,
#  582.6199,
#  585.57324,
#  618.5618,
#  604.0903,
#  600.6266,
#  655.9713,
#  619.7153,
#  609.4652,
#  592.7324,
#  595.69885,
#  579.50226,
#  574.06714,
#  574.895,
#  571.5234,
#  560.6397,
#  562.3941,
#  581.5551,
#  583.03174,
#  595.27,
#  605.87555,
#  623.3446,
#  618.703,
#  616.232,
#  584.8837,
#  590.7653,
#  601.8705,
#  595.9608,
#  578.13367,
#  587.00964,
#  587.9241,
#  592.9235,
#  593.0939,
#  615.8507,
#  625.2506,
#  603.3746,
#  609.0431,
#  638.75977,
#  640.6488,
#  606.63745,
#  582.37036,
#  586.97015,
#  585.2832,
#  591.7978,
#  582.49506,
#  611.86505,
#  594.94574,
#  567.9068,
#  549.18506,
#  540.80396,
#  557.08307,
#  576.7706,
#  568.8803,
#  615.1367,
#  600.2684,
#  595.4245,
#  600.234,
#  619.07404,
#  625.31476,
#  618.6516,
#  566.2148,
#  566.55273,
#  606.86774,
#  607.3755,
#  623.0132,
#  630.02155,
#  608.54266,
#  628.15485,
#  594.51843,
#  596.2912,
#  605.40173,
#  584.463,
#  582.52057,
#  590.5278,
#  600.23303,
#  607.61414,
#  598.4543,
#  612.0414,
#  630.83856,
#  613.7945,
#  603.70886,
#  585.3547,
#  566.21466,
#  607.17126,
#  597.19696,
#  605.84656,
#  604.51465,
#  578.5832,
#  594.18774,
#  596.5546,
#  591.32043,
#  574.42145,
#  585.5731,
#  583.50024,
#  585.8346,
#  577.06305,
#  611.89655,
#  611.22003,
#  598.2335,
#  557.07275,
#  598.74133,
#  587.85284,
#  579.59686,
#  559.96063,
#  579.87683,
#  590.4685,
#  581.47,
#  612.258,
#  579.6459,
#  594.89594,
#  606.95044,
#  603.2602,
#  597.8818,
#  597.23706,
#  577.95416,
#  592.27216,
#  602.0033,
#  595.83417,
#  575.2686,
#  587.81274,
#  593.397,
#  618.75464,
#  615.0389,
#  598.4288,
#  611.55225,
#  591.2438,
#  608.0817,
#  622.325,
#  615.20953,
#  608.9859,
#  604.3069,
#  618.85205,
#  613.9546,
#  601.1369,
#  598.5375,
#  584.9266,
#  580.9133,
#  613.89026,
#  610.5536,
#  586.4457,
#  601.16974,
#  556.70483,
#  611.80304,
#  580.5787,
#  612.49805,
#  628.46704,
#  621.4581,
#  604.8741,
#  617.43115,
#  575.46497,
#  577.2198,
#  581.5674,
#  569.9688,
#  564.1872,
#  577.90247,
#  576.89685,
#  550.49585,
#  568.8755,
#  557.47925,
#  605.7447,
#  591.9642,
#  555.59766,
#  551.2905,
#  552.9698,
#  580.8311,
#  578.1746,
#  542.425,
#  541.9971,
#  575.17566,
#  567.1888,
#  575.7104,
#  608.9635,
#  598.0033,
#  606.62317,
#  604.28845,
#  603.388,
#  607.52277,
#  613.54816,
#  619.8828,
#  580.11523,
#  590.5741,
#  601.43884,
#  598.53375,
#  594.89185,
#  556.1829,
#  547.5852,
#  579.3827,
#  ...]

# %%
state_tracked_sample = [agent.states_tracked[i] for i in range(len(agent.states_tracked)) if agent.states_tracked[i] < 1000]

# %% [markdown]
# <b><h3><font color = 'green'> 5. Plot the Q-Value convergence for state action pairs </h3></b>

# %%
plt.figure(0, figsize=(16,7))
plt.title('Q_value for state [0,0,0]  action (0,2)')
xaxis = np.asarray(range(0, len(agent.states_tracked)))
plt.semilogy(xaxis,np.asarray(agent.states_tracked))
plt.show()

# %% [markdown]
# #### We are using log scale because the initial q_values are way to high compared to the steady state value (around 700)

# %% [markdown]
# <b><h3><font color = 'green'> 6. Track rewards per episode </h3></b>

# %%
score_tracked_sample = [score_tracked[i] for i in range(len(score_tracked)) if (i % 4 == 0)]

# %%
plt.figure(0, figsize=(16,7))
plt.title('Rewards per episode')
xaxis = np.asarray(range(0, len(score_tracked_sample)))
plt.plot(xaxis,np.asarray(score_tracked_sample))
plt.show()

# %% [markdown]
# ### We can see from the above plot that the rewards converge at around 1400. Since the initial state is picked to be random for each episode, some initial states may be less rewarding than others inherently regardless of the model quality.

# %% [markdown]
# #### Epsilon-decay sample function

# %% [markdown]
# <div class="alert alert-block alert-info">
# Try building a similar epsilon-decay function for your model.
# </div>

# %%
import numpy as np
time = np.arange(0,15000)
epsilon = []
for i in range(0,15000):
    epsilon.append((1 - 0.00001) * np.exp(-0.0005 * i))

# %%
import matplotlib.pyplot as plt
plt.plot(time, epsilon)
plt.show()
