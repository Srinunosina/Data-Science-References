# %%
#data frame manipulation
import pandas as pd

# numeric operations
import numpy as np
import scipy.stats as stats

#plotting 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
       # print(os.path.join(dirname, filename))

# %%
# stacked bars top on each othter
#df_plot = df.groupby(['class', 'survived']).size().reset_index().pivot(columns='class', index='survived', values=0)

# %%
df = pd.read_csv(r"D:\Srinu Docs\DS\DataSets\AB_NYC_2019.csv")
df
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
sns.boxplot(y= df.price)

# %%
sns.distplot(df.price)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(df.price)

# %%
log_price = np.log1p(df.price)
sns.boxplot(y= log_price)

# %%
sns.distplot(log_price)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(log_price)

# %%
Q1 = df.price.quantile(0.25)
Q3 = df.price.quantile(0.75)
IQR = Q3-Q1

lower_limit = Q1 - (1.5)* IQR
upper_limit = Q3 + (1.5)* IQR

lower_10_percent = df.price.quantile(0.10)
upper_95_percent = df.price.quantile(0.95)

print("Q1"," : ", Q1)
print("Q3"," : ", Q3)
print("IQR"," : ", IQR)
print("lower_limit"," : ", lower_limit)
print("lower_10_percent"," : ", lower_10_percent)
print("upper_limit"," : ", upper_limit)
print("upper_95_percent"," : ", upper_95_percent)
# Out:
# Q1  :  69.0
# Q3  :  175.0
# IQR  :  106.0
# lower_limit  :  -90.0
# lower_10_percent  :  49.0
# upper_limit  :  334.0
# upper_95_percent  :  355.0

# %%
df.price.skew()
# Out:
# 19.118938995046033

# %%
log_price.skew()
# Out:
# 0.5531045462041445

# %%
z_scores = np.abs(stats.zscore(log_price))
z_scores
# Out:
# array([0.39369473, 0.98319249, 0.40325059, ..., 0.02402501, 1.02329207,
#        0.32505842])

# %%
np.where(z_scores > 3)
# Out:
# (array([  496,   762,   946,  1105,  1414,  1480,  1862,  1899,  2018,
#          2155,  2215,  2236,  2355,  2386,  2520,  2523,  2698,  2772,
#          2860,  2896,  3131,  3306,  3333,  3345,  3420,  3537,  3598,
#          3622,  3636,  3637,  3684,  3689,  3695,  3700,  3702,  3720,
#          3721,  3723,  3727,  3730,  3731,  3732,  3755,  3758,  3761,
#          3774,  3782,  3784,  3785,  3788,  3793,  3804,  3812,  3817,
#          4127,  4345,  4376,  4377,  4482,  4730,  5432,  5499,  5801,
#          5839,  5861,  5942,  5956,  6277,  6333,  6501,  6511,  6530,
#          6620,  6715,  6987,  7088,  7096,  7190,  7477,  7485,  7513,
#          7541,  7846,  7982,  8530,  8727,  8915,  9092,  9151,  9603,
#          9883, 10333, 10341, 10431, 10520, 11021, 11239, 11264, 11339,
#         11369, 11394, 12329, 12342, 12740, 12800, 12846, 12878, 13724,
#         13788, 13930, 14166, 14380, 14385, 14459, 14573, 14574, 14629,
# ...

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[ (df.price <= upper_95_percent) & (df.price > lower_10_percent)]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
#The rooms that customers choose the most
labels = df['room_type'].value_counts().index
sizes = df['room_type'].value_counts().values
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors = ['#009999','#007399','#20B2AA'] )
plt.title("Rooms that are most favourable for customer", color = 'black',fontsize = 15);

# %%
#city with price
f, ax = plt.subplots(figsize=(10, 6))

sns.boxplot(data=df[df['price']<300],y='neighbourhood_group',x='price',width=.6,palette='GnBu_d')
#sns.stripplot(data=airbnb[airbnb['price']<300],y="neighbourhood_group", x="price", size=2, color=".4", linewidth=0)

ax.xaxis.grid(True)
ax.set(ylabel="");

# %%
# Airbnb dataset groupby room_type with 'availability_365'-mean
ngroup = df.groupby('room_type', as_index=False)[['availability_365']].mean()

plt.figure(figsize=(10,6))
sns.barplot(data=ngroup, x=ngroup['room_type'], y=ngroup['availability_365'], palette='GnBu_d');

# %%
ngroup1 = df.groupby('room_type', as_index=False)[['availability_365']].mean()
ngroup1
# Out:
#          room_type  availability_365
# 0  Entire home/apt        111.920304
# 1     Private room        111.203933
# 2      Shared room        162.000862

# %%
for key in ngroup1:
    print(key, "Key :", "\n")
    #print(valu)
# Out:
# room_type Key :
#
# availability_365 Key :

# %%
df
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
cat_lst = []

for x in df.columns:
    if df[x].dtype == 'object':
         cat_lst.append(x)
            
cat_lst
# Out:
# ['name',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'room_type',
#  'last_review']

# %%
cat_columns = [x for x in df.columns if df[x].dtype == 'object']
cat_columns
# Out:
# ['name',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'room_type',
#  'last_review']
