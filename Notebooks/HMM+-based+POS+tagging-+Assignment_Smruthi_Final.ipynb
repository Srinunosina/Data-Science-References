# %% [markdown]
# <font color = "purple"><h2><b><center> POS tagging using modified Viterbi </center></b></h2></font>

# %%
#Importing libraries

import nltk
import re
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import random
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split

# %% [markdown]
# <font color = "green"><h3><b> Reading the Treebank tagged sentences </b></h3></font>

# %%
test_file_path = r'E:\Upgrad\NLP\Assignment\Test_sentences.txt'

# %%
# reading the Treebank tagged sentences
# nltk.download('universal_tagset')
treebank_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))
print(treebank_data[0])
# Out:
# [('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')]

# %% [markdown]
# <font color = "green"><h3><b> Data Preparation </b></h3></font>

# %%
# Splitting Treebank tagged set into train and test

random.seed(1000)
train_set, test_set = train_test_split(treebank_data, test_size=0.05)

print("Training Set Length: ", len(train_set))
print("Training Set Length: ", len(test_set))
print("=" * 127)
print("Training Data Glimpse: \r\n")
print(train_set[0])
print("")
print(train_set[1])
# Out:
# Training Set Length:  3718
# Training Set Length:  196
# ===============================================================================================================================
# Training Data Glimpse:
#
# [('In', 'ADP'), ('part', 'NOUN'), (',', '.'), ('this', 'DET'), ('may', 'VERB'), ('reflect', 'VERB'), ('the', 'DET'), ('fact', 'NOUN'), ('that', 'ADP'), ('`', '.'), ('she', 'PRON'), ('speaks', 'VERB'), ('a', 'DET'), ('more', 'ADJ'), ('progressive', 'ADJ'), ('language', 'NOUN'), ("'", '.'), ('than', 'ADP'), ('her', 'PRON'), ('husband', 'NOUN'), ('*?*', 'X'), (',', '.'), ('as', 'ADP'), ('Columbia', 'NOUN'), ("'s", 'PRT'), ('Prof', 'NOUN'), ('.', '.'), ('-LCB-', '.'), ('Ethel', 'NOUN'), ('-RCB-', '.'), ('Klein', 'NOUN'), ('puts', 'VERB'), ('it', 'PRON'), ('.', '.')]
#
# [('LANDOR', 'NOUN'), ('ASSOCIATES', 'NOUN'), (':', '.')]

# %%
# Getting list of tagged words

train_set_tagged_words = [tup for sent in train_set for tup in sent]
print("Total tagged words: ", len(train_set_tagged_words))
# Out:
# Total tagged words:  95760

# %%
# Retrieve words and POS

words = []
POS = []

for items in train_set_tagged_words:
    words.append(items[0])
    POS.append(items[1])

# %%
train_unique_words = set(words)
train_unique_POS = set(POS)

total_words = len(train_unique_words)
total_POS = len(train_unique_POS)

print("Total unique words: ", total_words)
print("Total unique POS: ", total_POS)
# Out:
# Total unique words:  12086
# Total unique POS:  12

# %% [markdown]
# <font color = "green"><h3><b> Emission and Transition Probabilities </b></h3></font>

# %%
# compute word given tag: Emission Probability

def word_given_tag(word, tag, train_bag = train_set_tagged_words):
    
    count_tag = 0
    count_w_given_tag = 0
    
    for pair in train_bag:
        
        if pair[1]==tag:
            count_tag += 1
            
            if pair[0]==word:
                count_w_given_tag += 1
    
    return (count_w_given_tag, count_tag)

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_set_tagged_words):

    index = 0
    count_t1 = 0
    count_t2_t1 = 0
    previous_tag = ''
    
    for pair in train_bag:
        
        current_tag = pair[1]
        
        if current_tag == t1:
            count_t1 += 1
            
        if current_tag == t2 and previous_tag == t1:
            count_t2_t1 += 1
        
        previous_tag = current_tag
        
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((total_POS, total_POS), dtype='float32')
for i, t1 in enumerate(list(train_unique_POS)):
    for j, t2 in enumerate(list(train_unique_POS)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# convert the matrix to a data frame for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(train_unique_POS), index=list(train_unique_POS))

# dataset glimpse
tags_df
# Out:
#           PRON       NUM         X       DET      CONJ      NOUN      VERB  \
# PRON  0.007316  0.007316  0.093955  0.009626  0.005006  0.206007  0.485560
# NUM   0.001492  0.184069  0.211814  0.002685  0.014320  0.348449  0.018795
# X     0.055723  0.002858  0.074933  0.054929  0.010478  0.061756  0.202572
# DET   0.003739  0.021828  0.043777  0.005548  0.000482  0.640376  0.039797
# CONJ  0.058770  0.041781  0.007805  0.118457  0.000459  0.350321  0.155188
# NOUN  0.004885  0.009333  0.029421  0.013125  0.043166  0.264173  0.147800
# VERB  0.035247  0.022775  0.218065  0.134712  0.005423  0.109846  0.169417
# PRT   0.017332  0.058208  0.013734  0.098757  0.001962  0.246893  0.402878
# .     0.065609  0.080308  0.027068  0.172717  0.058618  0.222730  0.087748
# ADJ   0.000655  0.020963  0.020963  0.004913  0.016869  0.697019  0.012119
# ADV   0.014876  0.031405  0.023802  0.071074  0.006942  0.031405  0.342149
# ADP   0.068391  0.061872  0.034943  0.324321  0.000855  0.321543  0.008549
#
#            PRT         .       ADJ       ADV       ADP
# PRON  0.013092  0.040431  0.073931  0.034655  0.023104
# NUM   0.028043  0.119332  0.033115  0.002685  0.035203
# X     0.185426  0.164629  0.017146  0.026195  0.143356
# DET   0.000241  0.017969  0.204414  0.012663  0.009165
# CONJ  0.005051  0.035354  0.118457  0.055096  0.053260
# NOUN  0.043531  0.239637  0.012104  0.016989  0.175836
# VERB  0.030909  0.034859  0.065303  0.081803  0.091641
# PRT   0.001635  0.043165  0.084369  0.010137  0.020929
# .     0.002510  0.094111  0.044456  0.053061  0.090974
# ADJ   0.011300  0.064854  0.067147  0.004913  0.078284
# ADV   0.013554  0.137851  0.131240  0.077025  0.118678
# ADP   0.001389  0.039645  0.107502  0.013678  0.017311

# %% [markdown]
# <font color = "green"><h3><b> Exploratory Data Analysis </b></h3></font>

# %%
# heatmap of tags matrix

plt.figure(figsize=(14, 8))
sns.heatmap(tags_df, annot = True)
plt.show()

# %%
# frequent tags
# filter the df to get P(t2, t1) > 0.5

tags_frequent = tags_df[tags_df>0.5]
plt.figure(figsize=(14, 8))
sns.heatmap(tags_frequent, annot = True)
plt.show()

# %% [markdown]
# <font color = "green"><h3><b> Build the vanilla Viterbi based POS tagger </b></h3></font>

# %%
# Viterbi Heuristic

def Vanilla_Viterbi(words, train_bag = train_set_tagged_words):
    
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    
    return list(zip(words, state))

# %%
random.seed(1234)

# list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]

# list of untagged words
test_tagged_words = [tup[0] for sent in test_set for tup in sent]

# %%
# tagging the test sentences

tagged_seq = Vanilla_Viterbi(test_tagged_words)

# %%
# Checking the accuracy of the vanilla viterbi algorithm

check = [i for i, j in zip(tagged_seq, test_run_base) if i == j]

vanilla_viterbi_accuracy = len(check)/len(tagged_seq)

print("The accuracy of the Vanilla Viterbi Algorithm is: ", vanilla_viterbi_accuracy)
# Out:
# The accuracy of the Vanilla Viterbi Algorithm is:  0.9041903986981286

# %%
# Let's have a look at the incorrect tagged cases

incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
print("Total incorrect tags: ", len(incorrect_tagged_cases))
incorrect_tagged_cases
# Out:
# Total incorrect tags:  471
# [[('.', '.'), (('Institutions', 'PRON'), ('Institutions', 'NOUN'))],
#  [('the', 'DET'), (('sidelines', 'PRON'), ('sidelines', 'NOUN'))],
#  [('a', 'DET'), (('spread', 'VERB'), ('spread', 'NOUN'))],
#  [('%', 'NOUN'), (('bellwether', 'PRON'), ('bellwether', 'NOUN'))],
#  [('of', 'ADP'), (('New', 'NOUN'), ('New', 'ADJ'))],
#  [('New', 'ADJ'), (('York-based', 'NOUN'), ('York-based', 'ADJ'))],
#  [('and', 'CONJ'), (('Broken', 'PRON'), ('Broken', 'NOUN'))],
#  [('Hill', 'NOUN'), (('Pty.', 'PRON'), ('Pty.', 'NOUN'))],
#  [('minimum', 'ADJ'), (('five-cent', 'PRON'), ('five-cent', 'ADJ'))],
#  [('five-cent', 'ADJ'), (('change', 'VERB'), ('change', 'NOUN'))],
#  [('have', 'VERB'), (('difficulty', 'PRON'), ('difficulty', 'NOUN'))],
#  [('*-2', 'X'), (('shoring', 'PRON'), ('shoring', 'VERB'))],
#  [('shoring', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [(',', '.'), (('U.S.-Japanese', 'PRON'), ('U.S.-Japanese', 'ADJ'))],
#  [('economic', 'ADJ'), (('behemoth', 'PRON'), ('behemoth', 'NOUN'))],
#  [('power', 'NOUN'), (('struggle', 'PRON'), ('struggle', 'NOUN'))],
#  [('in', 'ADP'), (('ascendency', 'PRON'), ('ascendency', 'NOUN'))],
#  [('--', '.'), (('consisting', 'PRON'), ('consisting', 'VERB'))],
#  [('computer', 'NOUN'), (('wizards', 'PRON'), ('wizards', 'NOUN'))],
#  [('with', 'ADP'), (('immense', 'PRON'), ('immense', 'NOUN'))],
#  [('immense', 'NOUN'), (('pools', 'PRON'), ('pools', 'NOUN'))],
#  [('P.', 'NOUN'), (('Smaby', 'PRON'), ('Smaby', 'NOUN'))],
#  [('of', 'ADP'), (('Smaby', 'PRON'), ('Smaby', 'NOUN'))],
#  [('has', 'VERB'), (('looked', 'PRON'), ('looked', 'VERB'))],
#  [('private', 'ADJ'), (('Dodger', 'PRON'), ('Dodger', 'NOUN'))],
#  [('brought', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('took', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('At', 'ADP'), (('Christie', 'PRON'), ('Christie', 'NOUN'))],
#  [('Christie', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [('a', 'DET'), (('folio', 'PRON'), ('folio', 'NOUN'))],
#  [('``', '.'), (('Equivalents', 'PRON'), ('Equivalents', 'NOUN'))],
#  [('$', '.'), (('396,000', 'PRON'), ('396,000', 'NUM'))],
#  [('a', 'DET'), (('single-lot', 'PRON'), ('single-lot', 'ADJ'))],
#  [('the', 'DET'), (('Midwestern', 'ADJ'), ('Midwestern', 'NOUN'))],
#  [('made', 'VERB'), (('clear', 'ADJ'), ('clear', 'ADV'))],
#  [('an', 'DET'), (('unofficial', 'PRON'), ('unofficial', 'ADJ'))],
#  [('unofficial', 'ADJ'), (('envoy', 'PRON'), ('envoy', 'NOUN'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('was', 'VERB'), (('outraged', 'PRON'), ('outraged', 'ADJ'))],
#  [('Many', 'ADJ'), (('arbs', 'PRON'), ('arbs', 'NOUN'))],
#  [('``', '.'), (('overleveraged', 'PRON'), ('overleveraged', 'ADJ'))],
#  [('fall', 'VERB'), (('apart', 'PRON'), ('apart', 'ADV'))],
#  [('a', 'DET'), (('subject', 'ADJ'), ('subject', 'NOUN'))],
#  [('the', 'DET'), (('shudders', 'PRON'), ('shudders', 'NOUN'))],
#  [('.', '.'), (('ENERGY', 'PRON'), ('ENERGY', 'NOUN'))],
#  [('but', 'CONJ'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('The', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('wants', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('a', 'DET'), (('strain', 'PRON'), ('strain', 'NOUN'))],
#  [('.', '.'), (('Garret', 'PRON'), ('Garret', 'NOUN'))],
#  [('*T*-11', 'X'), (('teaches', 'PRON'), ('teaches', 'VERB'))],
#  [('at', 'ADP'), (('Earlham', 'PRON'), ('Earlham', 'NOUN'))],
#  [('an', 'DET'), (('ugly', 'PRON'), ('ugly', 'ADJ'))],
#  [('one', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-1', 'X'), (('blocks', 'NOUN'), ('blocks', 'VERB'))],
#  [('corporate', 'ADJ'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('until', 'ADP'), (('midyear', 'PRON'), ('midyear', 'NOUN'))],
#  [('*', 'X'), (('Choose', 'PRON'), ('Choose', 'VERB'))],
#  [('them', 'PRON'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('be', 'VERB'), (('deprived', 'PRON'), ('deprived', 'VERB'))],
#  [('deprived', 'VERB'), (('*-24', 'PRON'), ('*-24', 'X'))],
#  [(',', '.'), (('families', 'PRON'), ('families', 'NOUN'))],
#  [('a', 'DET'), (('planned', 'ADJ'), ('planned', 'VERB'))],
#  [('initial', 'ADJ'), (('public', 'NOUN'), ('public', 'ADJ'))],
#  [('bill', 'NOUN'), (('draws', 'PRON'), ('draws', 'VERB'))],
#  [('California', 'NOUN'), (('airplane', 'PRON'), ('airplane', 'NOUN'))],
#  [('but', 'CONJ'), (('intriguing', 'PRON'), ('intriguing', 'ADJ'))],
#  [('intriguing', 'ADJ'), (('struggle', 'PRON'), ('struggle', 'NOUN'))],
#  [('$', '.'), (('737.5', 'PRON'), ('737.5', 'NUM'))],
#  [('$', '.'), (('3.01', 'PRON'), ('3.01', 'NUM'))],
#  [('which', 'DET'), (('*T*-236', 'PRON'), ('*T*-236', 'X'))],
#  [('systems', 'NOUN'), (('any', 'DET'), ('any', 'ADV'))],
#  [('large', 'ADJ'), (('integrated', 'ADJ'), ('integrated', 'VERB'))],
#  [('%', 'NOUN'), (('unconsolidated', 'PRON'), ('unconsolidated', 'ADJ'))],
#  [('unconsolidated', 'ADJ'), (('gain', 'VERB'), ('gain', 'NOUN'))],
#  [('The', 'DET'), (('U.S.S.R.', 'PRON'), ('U.S.S.R.', 'NOUN'))],
#  [('Public', 'NOUN'), (('Works', 'PRON'), ('Works', 'NOUN'))],
#  [('Department', 'NOUN'), (('up', 'PRT'), ('up', 'ADP'))],
#  [('who', 'PRON'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('.', '.'), (('Workers', 'PRON'), ('Workers', 'NOUN'))],
#  [('``', '.'), (('clouds', 'PRON'), ('clouds', 'NOUN'))],
#  [('blue', 'ADJ'), (('dust', 'PRON'), ('dust', 'NOUN'))],
#  [('*T*-1', 'X'), (('hung', 'PRON'), ('hung', 'VERB'))],
#  [('though', 'ADP'), (('exhaust', 'VERB'), ('exhaust', 'NOUN'))],
#  [('fans', 'NOUN'), (('ventilated', 'PRON'), ('ventilated', 'VERB'))],
#  [('Peter', 'NOUN'), (('Holland', 'PRON'), ('Holland', 'NOUN'))],
#  [(',', '.'), (('deputy', 'NOUN'), ('deputy', 'ADJ'))],
#  [('at', 'ADP'), (('mid-afternoon', 'PRON'), ('mid-afternoon', 'ADJ'))],
#  [('at', 'ADP'), (('260', 'PRON'), ('260', 'NUM'))],
#  [('its', 'PRON'), (('Fax', 'PRON'), ('Fax', 'NOUN'))],
#  [('to', 'PRT'), (('Ogilvy', 'PRON'), ('Ogilvy', 'NOUN'))],
#  [('&', 'CONJ'), (('Mather', 'PRON'), ('Mather', 'NOUN'))],
#  [('a', 'DET'), (('WPP', 'PRON'), ('WPP', 'NOUN'))],
#  [('.', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('a', 'DET'), (('Hawaiian', 'PRON'), ('Hawaiian', 'ADJ'))],
#  [('of', 'ADP'), (('5.6', 'PRON'), ('5.6', 'NUM'))],
#  [('goes', 'VERB'), (('ex-dividend', 'PRON'), ('ex-dividend', 'ADJ'))],
#  [('a', 'DET'), (('hostile', 'NOUN'), ('hostile', 'ADJ'))],
#  [('.', '.'), (('MERRILL', 'PRON'), ('MERRILL', 'NOUN'))],
#  [('MERRILL', 'NOUN'), (('LYNCH', 'PRON'), ('LYNCH', 'NOUN'))],
#  [('LYNCH', 'NOUN'), (('READY', 'PRON'), ('READY', 'NOUN'))],
#  [('READY', 'NOUN'), (('ASSETS', 'PRON'), ('ASSETS', 'NOUN'))],
#  [('ASSETS', 'NOUN'), (('TRUST', 'PRON'), ('TRUST', 'NOUN'))],
#  [(':', '.'), (('8.64', 'PRON'), ('8.64', 'NUM'))],
#  [('to', 'PRT'), (('repay', 'PRON'), ('repay', 'VERB'))],
#  [('financier', 'NOUN'), (('Saul', 'PRON'), ('Saul', 'NOUN'))],
#  [('buy', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('The', 'DET'), (('restaurant', 'PRON'), ('restaurant', 'NOUN'))],
#  [('The', 'DET'), (('downgrading', 'PRON'), ('downgrading', 'NOUN'))],
#  [('sent', 'VERB'), (('shivers', 'PRON'), ('shivers', 'NOUN'))],
#  [('its', 'PRON'), (('finance', 'VERB'), ('finance', 'NOUN'))],
#  [('any', 'DET'), (('onslaught', 'PRON'), ('onslaught', 'NOUN'))],
#  [('to', 'PRT'), (('shrug', 'PRON'), ('shrug', 'VERB'))],
#  [('disappointed', 'VERB'), (('*-112', 'PRON'), ('*-112', 'X'))],
#  [('for', 'ADP'), (('Great', 'NOUN'), ('Great', 'ADJ'))],
#  [('Nekoosa', 'NOUN'), (('evaporated', 'PRON'), ('evaporated', 'VERB'))],
#  [('.', '.'), (('NEW', 'PRON'), ('NEW', 'NOUN'))],
#  [('NEW', 'NOUN'), (('ACCOUNT', 'PRON'), ('ACCOUNT', 'NOUN'))],
#  [('The', 'DET'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [('That', 'DET'), (('attracts', 'PRON'), ('attracts', 'VERB'))],
#  [('*-1', 'X'), (('attending', 'PRON'), ('attending', 'VERB'))],
#  [('students', 'NOUN'), (('adequately', 'PRON'), ('adequately', 'ADV'))],
#  [(',', '.'), (('Social', 'PRON'), ('Social', 'NOUN'))],
#  [(',', '.'), (('passport', 'PRON'), ('passport', 'NOUN'))],
#  [('.', '.'), (('Composer', 'PRON'), ('Composer', 'NOUN'))],
#  [('Composer', 'NOUN'), (('Marc', 'PRON'), ('Marc', 'NOUN'))],
#  [('Marc', 'NOUN'), (('Marder', 'PRON'), ('Marder', 'NOUN'))],
#  [('his', 'PRON'), (('living', 'VERB'), ('living', 'NOUN'))],
#  [('the', 'DET'), (('double', 'VERB'), ('double', 'ADJ'))],
#  [('double', 'ADJ'), (('bass', 'PRON'), ('bass', 'NOUN'))],
#  [('in', 'ADP'), (('classical', 'PRON'), ('classical', 'ADJ'))],
#  [('music', 'NOUN'), (('ensembles', 'PRON'), ('ensembles', 'NOUN'))],
#  [('an', 'DET'), (('exciting', 'PRON'), ('exciting', 'ADJ'))],
#  [(',', '.'), (('eclectic', 'PRON'), ('eclectic', 'ADJ'))],
#  [('score', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-67', 'PRON'), ('*T*-67', 'X'))],
#  [('the', 'DET'), (('characters', 'PRON'), ('characters', 'NOUN'))],
#  [('far', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('than', 'ADP'), (('intertitles', 'PRON'), ('intertitles', 'NOUN'))],
#  [('an', 'DET'), (('unstinting', 'PRON'), ('unstinting', 'ADJ'))],
#  [('won', 'VERB'), (('laurels', 'PRON'), ('laurels', 'NOUN'))],
#  [('That', 'DET'), (('sounds', 'NOUN'), ('sounds', 'VERB'))],
#  [('sounds', 'VERB'), (('neat', 'PRON'), ('neat', 'ADJ'))],
#  [('--', '.'), (('propagandizes', 'PRON'), ('propagandizes', 'VERB'))],
#  [('.', '.'), (('Proper', 'PRON'), ('Proper', 'ADJ'))],
#  [('Proper', 'ADJ'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('``', '.'), (('rounds', 'PRON'), ('rounds', 'NOUN'))],
#  [('the', 'DET'), (('highest-pitched', 'PRON'), ('highest-pitched', 'ADJ'))],
#  [('simple', 'ADJ'), (('descending', 'PRON'), ('descending', 'VERB'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('The', 'DET'), (('Nicaraguan', 'PRON'), ('Nicaraguan', 'ADJ'))],
#  [('the', 'DET'), (('U.S.-backed', 'PRON'), ('U.S.-backed', 'ADJ'))],
#  [('U.S.-backed', 'ADJ'), (('rebels', 'PRON'), ('rebels', 'NOUN'))],
#  [('a', 'DET'), (('19-month-old', 'PRON'), ('19-month-old', 'ADJ'))],
#  [('19-month-old', 'ADJ'), (('cease-fire', 'PRON'), ('cease-fire', 'NOUN'))],
#  [('proposal', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('far', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('more', 'ADV'), (('limited', 'ADJ'), ('limited', 'VERB'))],
#  [('limited', 'VERB'), (('applicability', 'PRON'), ('applicability', 'NOUN'))],
#  [('their', 'PRON'), (('biannual', 'PRON'), ('biannual', 'ADJ'))],
#  [('biannual', 'ADJ'), (('powwow', 'PRON'), ('powwow', 'NOUN'))],
#  [('manufacturing', 'VERB'), (('titans', 'PRON'), ('titans', 'NOUN'))],
#  [('typically', 'ADV'), (('jet', 'NOUN'), ('jet', 'VERB'))],
#  [('the', 'DET'), (('sunny', 'PRON'), ('sunny', 'ADJ'))],
#  [('sunny', 'ADJ'), (('confines', 'PRON'), ('confines', 'NOUN'))],
#  [('and', 'CONJ'), (('Hot', 'ADJ'), ('Hot', 'NOUN'))],
#  [("'s", 'PRT'), (('firm', 'NOUN'), ('firm', 'ADJ'))],
#  [('steady', 'ADJ'), (('opening', 'VERB'), ('opening', 'NOUN'))],
#  [('also', 'ADV'), (('tempted', 'PRON'), ('tempted', 'VERB'))],
#  [('point', 'NOUN'), (('off', 'PRT'), ('off', 'ADP'))],
#  [("'s", 'PRT'), (('advertised', 'PRON'), ('advertised', 'VERB'))],
#  [('advertised', 'VERB'), (('finance', 'VERB'), ('finance', 'NOUN'))],
#  [('at', 'ADP'), (('6.9', 'PRON'), ('6.9', 'NUM'))],
#  [('The', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('bill', 'NOUN'), (('funding', 'NOUN'), ('funding', 'VERB'))],
#  [('Commerce', 'NOUN'), (('departments', 'PRON'), ('departments', 'NOUN'))],
#  [('reached', 'VERB'), (('*-24', 'PRON'), ('*-24', 'X'))],
#  [('$', '.'), (('93.9', 'PRON'), ('93.9', 'NUM'))],
#  [('$', '.'), (('1.19', 'PRON'), ('1.19', 'NUM'))],
#  [('$', '.'), (('92.9', 'PRON'), ('92.9', 'NUM'))],
#  [('$', '.'), (('1.18', 'PRON'), ('1.18', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('to', 'PRT'), (('total', 'ADJ'), ('total', 'VERB'))],
#  [('Candela', 'NOUN'), (('laser', 'PRON'), ('laser', 'NOUN'))],
#  [('one', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-189', 'PRON'), ('*T*-189', 'X'))],
#  [('breaks', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('up', 'PRT'), (('kidney', 'PRON'), ('kidney', 'NOUN'))],
#  [('kidney', 'NOUN'), (('stones', 'PRON'), ('stones', 'NOUN'))],
#  [('another', 'DET'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-190', 'PRON'), ('*T*-190', 'X'))],
#  [('*T*-190', 'X'), (('treats', 'PRON'), ('treats', 'VERB'))],
#  [('skin', 'NOUN'), (('lesions', 'PRON'), ('lesions', 'NOUN'))],
#  [('*-1', 'X'), (('Bucking', 'PRON'), ('Bucking', 'VERB'))],
#  [('apparently', 'ADV'), (('drew', 'PRON'), ('drew', 'VERB'))],
#  [('$', '.'), (('490', 'PRON'), ('490', 'NUM'))],
#  [('the', 'DET'), (('buy-back', 'ADJ'), ('buy-back', 'NOUN'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('$', '.'), (('6.4', 'PRON'), ('6.4', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('a', 'DET'), (('vitriolic', 'PRON'), ('vitriolic', 'ADJ'))],
#  [('temporarily', 'ADV'), (('mollified', 'PRON'), ('mollified', 'VERB'))],
#  [('asbestos', 'NOUN'), (('fiber', 'PRON'), ('fiber', 'NOUN'))],
#  [('unusually', 'ADV'), (('resilient', 'PRON'), ('resilient', 'ADJ'))],
#  [('resilient', 'ADJ'), (('once', 'ADV'), ('once', 'ADP'))],
#  [('the', 'DET'), (('lungs', 'PRON'), ('lungs', 'NOUN'))],
#  [('causing', 'VERB'), (('symptoms', 'PRON'), ('symptoms', 'NOUN'))],
#  [('symptoms', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('show', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('the', 'DET'), (('Underwoods', 'PRON'), ('Underwoods', 'NOUN'))],
#  [('at', 'ADP'), (('closing', 'ADJ'), ('closing', 'NOUN'))],
#  [("'s", 'PRT'), (('beleaguered', 'PRON'), ('beleaguered', 'VERB'))],
#  [('joining', 'VERB'), (('forces', 'VERB'), ('forces', 'NOUN'))],
#  [('*', 'X'), (('boosting', 'PRON'), ('boosting', 'VERB'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('to', 'PRT'), (('augment', 'PRON'), ('augment', 'VERB'))],
#  [('James', 'NOUN'), (('Rill', 'PRON'), ('Rill', 'NOUN'))],
#  [("'s", 'PRT'), (('quarterly', 'ADJ'), ('quarterly', 'ADV'))],
#  [('the', 'DET'), (('upbeat', 'PRON'), ('upbeat', 'ADJ'))],
#  [('upbeat', 'ADJ'), (('mood', 'PRON'), ('mood', 'NOUN'))],
#  [('default', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('described', 'VERB'), (('*-101', 'PRON'), ('*-101', 'X'))],
#  [('.', '.'), (('Lead', 'PRON'), ('Lead', 'ADJ'))],
#  [('are', 'VERB'), (('Scotia', 'PRON'), ('Scotia', 'NOUN'))],
#  [('Scotia', 'NOUN'), (('McLeod', 'PRON'), ('McLeod', 'NOUN'))],
#  [('and', 'CONJ'), (('RBC', 'PRON'), ('RBC', 'NOUN'))],
#  [('RBC', 'NOUN'), (('Dominion', 'PRON'), ('Dominion', 'NOUN'))],
#  [("'s", 'PRT'),
#   (('school-improvement', 'PRON'), ('school-improvement', 'ADJ'))],
#  [('once', 'ADV'), (('male-dominated', 'PRON'), ('male-dominated', 'ADJ'))],
#  [(';', '.'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('regulated', 'VERB'), (('*-134', 'PRON'), ('*-134', 'X'))],
#  [('which', 'DET'), (('*T*-218', 'PRON'), ('*T*-218', 'X'))],
#  [('*T*-218', 'X'), (('reports', 'NOUN'), ('reports', 'VERB'))],
#  [('Agriculture', 'NOUN'), (('committees', 'PRON'), ('committees', 'NOUN'))],
#  [('.', '.'), (('Hours', 'PRON'), ('Hours', 'NOUN'))],
#  [(',', '.'), (('representatives', 'PRON'), ('representatives', 'NOUN'))],
#  [('*-1', 'X'), (('recruiting', 'PRON'), ('recruiting', 'VERB'))],
#  [('.', '.'), (('ENERGY', 'PRON'), ('ENERGY', 'NOUN'))],
#  [('*', 'X'), (('rebounding', 'PRON'), ('rebounding', 'VERB'))],
#  [('slump', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('might', 'VERB'), (('gyrate', 'PRON'), ('gyrate', 'VERB'))],
#  [('exporters', 'NOUN'), (('scrounge', 'PRON'), ('scrounge', 'VERB'))],
#  [('totaled', 'VERB'), (('11,390,000', 'PRON'), ('11,390,000', 'NUM'))],
#  [(',', '.'), (('advertised', 'PRON'), ('advertised', 'VERB'))],
#  [("'s", 'PRT'), (('editions', 'PRON'), ('editions', 'NOUN'))],
#  [('too', 'ADV'), (('hard', 'ADJ'), ('hard', 'ADV'))],
#  [('under', 'ADP'), (('cultivation', 'PRON'), ('cultivation', 'NOUN'))],
#  [(',', '.'), (('soybeans', 'PRON'), ('soybeans', 'NOUN'))],
#  [('prices', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('partly', 'ADV'), (('cushioned', 'PRON'), ('cushioned', 'VERB'))],
#  [('grain', 'NOUN'), (('buying', 'VERB'), ('buying', 'NOUN'))],
#  [('Mr.', 'NOUN'), (('Bowman', 'PRON'), ('Bowman', 'NOUN'))],
#  [('the', 'DET'), (('Anti-Deficiency', 'PRON'), ('Anti-Deficiency', 'NOUN'))],
#  [('prohibits', 'VERB'), (('voluntary', 'PRON'), ('voluntary', 'ADJ'))],
#  [('fields', 'NOUN'), (('total', 'NOUN'), ('total', 'VERB'))],
#  [('to', 'PRT'), (('implant', 'PRON'), ('implant', 'VERB'))],
#  [('the', 'DET'), (('brain', 'PRON'), ('brain', 'NOUN'))],
#  [('a', 'DET'), (('patient', 'PRON'), ('patient', 'NOUN'))],
#  [(',', '.'), (('Old-House', 'PRON'), ('Old-House', 'NOUN'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('all', 'DET'), (('126,000', 'PRON'), ('126,000', 'NUM'))],
#  [('to', 'PRT'), (('7.63', 'PRON'), ('7.63', 'NUM'))],
#  [('from', 'ADP'), (('5.82', 'PRON'), ('5.82', 'NUM'))],
#  [('It', 'PRON'), (('invests', 'PRON'), ('invests', 'VERB'))],
#  [('currently', 'ADV'), (('waiving', 'PRON'), ('waiving', 'VERB'))],
#  [('its', 'PRON'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('telephone', 'NOUN'), (('call', 'VERB'), ('call', 'NOUN'))],
#  [('$', '.'), (('5.8', 'PRON'), ('5.8', 'NUM'))],
#  [('.', '.'), (('More', 'ADV'), ('More', 'ADJ'))],
#  [('a', 'DET'), (('raise', 'VERB'), ('raise', 'NOUN'))],
#  [('the', 'DET'), (('Fantasy', 'PRON'), ('Fantasy', 'NOUN'))],
#  [('a', 'DET'), (('2,050-passenger', 'PRON'), ('2,050-passenger', 'ADJ'))],
#  [('2,050-passenger', 'ADJ'), (('ship', 'VERB'), ('ship', 'NOUN'))],
#  [('ship', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('was', 'VERB'), (('slated', 'PRON'), ('slated', 'VERB'))],
#  [("''", '.'), (('rating', 'NOUN'), ('rating', 'VERB'))],
#  [('to', 'PRT'), (('nominees', 'PRON'), ('nominees', 'NOUN'))],
#  [('``', '.'), (('satisfactorily', 'PRON'), ('satisfactorily', 'ADV'))],
#  [('the', 'DET'), (('bench', 'PRON'), ('bench', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-249', 'PRON'), ('*T*-249', 'X'))],
#  [('reached', 'VERB'), (('*-155', 'PRON'), ('*-155', 'X'))],
#  [('the', 'DET'), (('petulant', 'PRON'), ('petulant', 'ADJ'))],
#  [('an', 'DET'), (('impudent', 'PRON'), ('impudent', 'ADJ'))],
#  [('impudent', 'ADJ'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('Sony', 'NOUN'), (('hosted', 'PRON'), ('hosted', 'VERB'))],
#  [('a', 'DET'), (('Luce', 'PRON'), ('Luce', 'NOUN'))],
#  [('Luce', 'NOUN'), (('Fellowship', 'PRON'), ('Fellowship', 'NOUN'))],
#  [('--', '.'), (('to', 'PRT'), ('to', 'ADP'))],
#  [('.', '.'), (('CERTIFICATES', 'PRON'), ('CERTIFICATES', 'NOUN'))],
#  [('OF', 'ADP'), (('DEPOSIT', 'PRON'), ('DEPOSIT', 'NOUN'))],
#  [(';', '.'), (('8.06', 'PRON'), ('8.06', 'NUM'))],
#  [('What', 'PRON'), (('*T*-67', 'PRON'), ('*T*-67', 'X'))],
#  [("'s", 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('getting', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('they', 'PRON'), (('waited', 'PRON'), ('waited', 'VERB'))],
#  [('then', 'ADV'), (('sneaked', 'PRON'), ('sneaked', 'VERB'))],
#  [('``', '.'), (('enraged', 'PRON'), ('enraged', 'VERB'))],
#  [('a', 'DET'), (('longtime', 'PRON'), ('longtime', 'NOUN'))],
#  [('9', 'NUM'), (('page-one', 'ADJ'), ('page-one', 'NOUN'))],
#  [('``', '.'), (('Barbara', 'PRON'), ('Barbara', 'NOUN'))],
#  [('Bush', 'NOUN'), (('Earns', 'PRON'), ('Earns', 'VERB'))],
#  [('Higher', 'ADJ'), (('Ratings', 'PRON'), ('Ratings', 'NOUN'))],
#  [('Ratings', 'NOUN'), (('Than', 'PRON'), ('Than', 'ADP'))],
#  [('is', 'VERB'), (('regrettable', 'PRON'), ('regrettable', 'ADJ'))],
#  [('our', 'PRON'), (('negatives', 'PRON'), ('negatives', 'NOUN'))],
#  [('Among', 'ADP'), (('liberals', 'PRON'), ('liberals', 'NOUN'))],
#  [('.', '.'), (('Elisa', 'PRON'), ('Elisa', 'NOUN'))],
#  [('Elisa', 'NOUN'), (('Hollis', 'PRON'), ('Hollis', 'NOUN'))],
#  [('Steel', 'NOUN'), (('Tube', 'PRON'), ('Tube', 'NOUN'))],
#  [('union', 'NOUN'), (('expired', 'PRON'), ('expired', 'VERB'))],
#  [('Cosby', 'NOUN'), (('Show', 'PRON'), ('Show', 'NOUN'))],
#  [('turned', 'VERB'), (('around', 'ADP'), ('around', 'PRT'))],
#  [('the', 'DET'), (('Huxtable', 'PRON'), ('Huxtable', 'NOUN'))],
#  [('of', 'ADP'), (('viewers', 'PRON'), ('viewers', 'NOUN'))],
#  [('followed', 'VERB'), (('year-to-year', 'PRON'), ('year-to-year', 'ADJ'))],
#  [('year-to-year', 'ADJ'), (('increases', 'VERB'), ('increases', 'NOUN'))],
#  [('``', '.'), (('The', 'DET'), ('The', 'NOUN'))],
#  [('Ill', 'NOUN'), (('Homeless', 'ADJ'), ('Homeless', 'NOUN'))],
#  [('colleagues', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('Miami', 'NOUN'), (('Dolphins', 'PRON'), ('Dolphins', 'NOUN'))],
#  [('Robbie', 'NOUN'), (('disagrees', 'PRON'), ('disagrees', 'VERB'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [("'", 'PRT'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('by', 'ADP'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('the', 'DET'), (('back', 'ADV'), ('back', 'NOUN'))],
#  [('the', 'DET'), (('shirts', 'PRON'), ('shirts', 'NOUN'))],
#  [('an', 'DET'), (('avid', 'PRON'), ('avid', 'ADJ'))],
#  [('avid', 'ADJ'), (('fan', 'PRON'), ('fan', 'NOUN'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('legislation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Foreigners', 'PRON'), ('Foreigners', 'NOUN'))],
#  [('Foreigners', 'NOUN'), (('complain', 'PRON'), ('complain', 'VERB'))],
#  [('have', 'VERB'), (('limited', 'VERB'), ('limited', 'ADJ'))],
#  [('government', 'NOUN'), (('procurement', 'PRON'), ('procurement', 'NOUN'))],
#  [('unfairly', 'ADV'), (('undercut', 'PRON'), ('undercut', 'VERB'))],
#  [('the', 'DET'), (('Environmental', 'PRON'), ('Environmental', 'NOUN'))],
#  [('Environmental', 'NOUN'), (('Protection', 'PRON'), ('Protection', 'NOUN'))],
#  [('a', 'DET'), (('gradual', 'PRON'), ('gradual', 'ADJ'))],
#  [('gradual', 'ADJ'), (('ban', 'VERB'), ('ban', 'NOUN'))],
#  [('The', 'DET'), (('morbidity', 'PRON'), ('morbidity', 'NOUN'))],
#  [('totaled', 'VERB'), (('154.2', 'PRON'), ('154.2', 'NUM'))],
#  [('to', 'PRT'), (('demobilize', 'PRON'), ('demobilize', 'VERB'))],
#  [('the', 'DET'), (('rebels', 'PRON'), ('rebels', 'NOUN'))],
#  [('scores', 'NOUN'), (('so', 'ADP'), ('so', 'ADV'))],
#  [('so', 'ADV'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('advertising', 'NOUN'), (('standpoint', 'PRON'), ('standpoint', 'NOUN'))],
#  [('folks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-153', 'PRON'), ('*T*-153', 'X'))],
#  [('.', '.'), (('Separately', 'ADV'), ('Separately', 'NOUN'))],
#  [('market', 'NOUN'), (('emergencies', 'PRON'), ('emergencies', 'NOUN'))],
#  [('benefit', 'VERB'), (('agriculture', 'PRON'), ('agriculture', 'NOUN'))],
#  [('a', 'DET'), (('ministry', 'PRON'), ('ministry', 'NOUN'))],
#  [('--', '.'), (('unlike', 'ADP'), ('unlike', 'ADJ'))],
#  [('earlier', 'ADJ'), (('built-from-kit', 'PRON'), ('built-from-kit', 'ADJ'))],
#  [('the', 'DET'), (('Altair', 'PRON'), ('Altair', 'NOUN'))],
#  [(',', '.'), (('Sol', 'PRON'), ('Sol', 'NOUN'))],
#  [('and', 'CONJ'), (('IMSAI', 'PRON'), ('IMSAI', 'NOUN'))],
#  [('had', 'VERB'), (('keyboards', 'PRON'), ('keyboards', 'NOUN'))],
#  [('could', 'VERB'), (('store', 'NOUN'), ('store', 'VERB'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('which', 'DET'), (('*T*-259', 'PRON'), ('*T*-259', 'X'))],
#  [('first', 'ADJ'), (('lifting', 'PRON'), ('lifting', 'NOUN'))],
#  [('a', 'DET'), (('four-year', 'PRON'), ('four-year', 'ADJ'))],
#  [('enacted', 'VERB'), (('*-163', 'PRON'), ('*-163', 'X'))],
#  [(',', '.'), (('*-163', 'PRON'), ('*-163', 'X'))],
#  [('$', '.'), (('2.65', 'PRON'), ('2.65', 'NUM'))],
#  [('payouts', 'NOUN'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('.', '.'), (('Average', 'NOUN'), ('Average', 'ADJ'))],
#  [(':', '.'), (('83,206', 'PRON'), ('83,206', 'NUM'))],
#  [('recent', 'ADJ'), (('disarray', 'PRON'), ('disarray', 'NOUN'))],
#  [('face', 'VERB'), (('long', 'ADV'), ('long', 'ADJ'))],
#  [('money', 'NOUN'), (('back', 'PRT'), ('back', 'ADV'))],
#  [('Jeffrey', 'NOUN'), (('Bowman', 'PRON'), ('Bowman', 'NOUN'))],
#  [('a', 'DET'), (('warning', 'NOUN'), ('warning', 'VERB'))],
#  [('it', 'PRON'), (('downgraded', 'PRON'), ('downgraded', 'VERB'))],
#  [('was', 'VERB'), (('singled', 'PRON'), ('singled', 'VERB'))],
#  [('its', 'PRON'), (('operating', 'VERB'), ('operating', 'NOUN'))],
#  [('jump', 'VERB'), (('79', 'PRON'), ('79', 'NUM'))],
#  [('$', '.'), (('42.1', 'PRON'), ('42.1', 'NUM'))],
#  [('$', '.'), (('62.625', 'PRON'), ('62.625', 'NUM'))],
#  [('$', '.'), (('576', 'PRON'), ('576', 'NUM'))],
#  [('already', 'ADV'), (('own', 'ADJ'), ('own', 'VERB'))],
#  [('were', 'VERB'), (('garden-variety', 'PRON'), ('garden-variety', 'NOUN'))],
#  [('low', 'ADJ'), (('lifes', 'PRON'), ('lifes', 'NOUN'))],
#  [(',', '.'), (('Mercedes', 'PRON'), ('Mercedes', 'NOUN'))],
#  [('expensive', 'ADJ'), (('clothes', 'PRON'), ('clothes', 'NOUN'))],
#  [('.', '.'), (('Workers', 'PRON'), ('Workers', 'NOUN'))],
#  [('large', 'ADJ'), (('burlap', 'PRON'), ('burlap', 'NOUN'))],
#  [('burlap', 'NOUN'), (('sacks', 'PRON'), ('sacks', 'NOUN'))],
#  [('huge', 'ADJ'), (('bin', 'PRON'), ('bin', 'NOUN'))],
#  [(',', '.'), (('poured', 'PRON'), ('poured', 'VERB'))],
#  [('poured', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('in', 'PRT'), (('cotton', 'PRON'), ('cotton', 'NOUN'))],
#  [('and', 'CONJ'), (('acetate', 'PRON'), ('acetate', 'NOUN'))],
#  [('and', 'CONJ'), (('mechanically', 'PRON'), ('mechanically', 'ADV'))],
#  [('largely', 'ADV'), (('hugging', 'PRON'), ('hugging', 'VERB'))],
#  [('the', 'DET'), (('sidelines', 'PRON'), ('sidelines', 'NOUN'))],
#  [('very', 'ADV'), (('alarmed', 'PRON'), ('alarmed', 'VERB'))],
#  [('rich', 'ADJ'), (('valuations', 'PRON'), ('valuations', 'NOUN'))],
#  [('.', '.'), (('Wilbur', 'PRON'), ('Wilbur', 'NOUN'))],
#  [('of', 'ADP'), (('Rothschild', 'PRON'), ('Rothschild', 'NOUN'))],
#  [('might', 'VERB'), (('speed', 'NOUN'), ('speed', 'VERB'))],
#  [('been', 'VERB'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('to', 'PRT'), (('bounce', 'PRON'), ('bounce', 'VERB'))],
#  [('bills', 'NOUN'), (('back', 'PRT'), ('back', 'ADV'))],
#  [('he', 'PRON'), (('argues', 'PRON'), ('argues', 'VERB'))],
#  [('Structural', 'NOUN'), (('Dynamics', 'PRON'), ('Dynamics', 'NOUN'))],
#  [('which', 'DET'), (('*T*-143', 'PRON'), ('*T*-143', 'X'))],
#  [('makes', 'VERB'), (('computer-aided', 'PRON'), ('computer-aided', 'ADJ'))],
#  [('design', 'NOUN'), (('automation', 'PRON'), ('automation', 'NOUN'))],
#  [('automation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-144', 'PRON'), ('*T*-144', 'X'))],
#  [('engineering', 'NOUN'),
#   (('productivity', 'PRON'), ('productivity', 'NOUN'))],
#  [('*', 'X'), (('Eliminate', 'PRON'), ('Eliminate', 'VERB'))],
#  [('creating', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('could', 'VERB'), (('compel', 'PRON'), ('compel', 'VERB'))],
#  [('small', 'ADJ'), (('video-viewing', 'PRON'), ('video-viewing', 'ADJ'))],
#  [('video-viewing', 'ADJ'), (('parlors', 'PRON'), ('parlors', 'NOUN'))],
#  [('is', 'VERB'), (('cause', 'VERB'), ('cause', 'NOUN'))],
#  [('it', 'PRON'), (('bid', 'NOUN'), ('bid', 'VERB'))],
#  [('separate', 'ADJ'), (('public', 'NOUN'), ('public', 'ADJ'))],
#  [('.', '.'), (('Shorter', 'PRON'), ('Shorter', 'ADJ'))],
#  [("'s", 'PRT'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('.', '.'), (('Skilled', 'PRON'), ('Skilled', 'ADJ'))],
#  [('their', 'PRON'), (('wrists', 'PRON'), ('wrists', 'NOUN'))],
#  [('to', 'PRT'), (('advance', 'NOUN'), ('advance', 'VERB'))],
#  [('or', 'CONJ'), (('retard', 'PRON'), ('retard', 'VERB'))],
#  [('can', 'VERB'), (('swap', 'NOUN'), ('swap', 'VERB'))],
#  [('the', 'DET'), (('following', 'NOUN'), ('following', 'ADJ'))],
#  [('GAF', 'NOUN'), (('TRIAL', 'PRON'), ('TRIAL', 'NOUN'))],
#  [('and', 'CONJ'), (('moons', 'PRON'), ('moons', 'NOUN'))],
#  [('the', 'DET'), (('renovated', 'PRON'), ('renovated', 'VERB'))],
#  [('Indiana', 'NOUN'), (('Roof', 'PRON'), ('Roof', 'NOUN'))],
#  [('Roof', 'NOUN'), (('ballroom', 'PRON'), ('ballroom', 'NOUN'))],
#  [('the', 'DET'), (('hottest', 'PRON'), ('hottest', 'ADJ'))],
#  [('Indiana', 'NOUN'), (('duckling', 'PRON'), ('duckling', 'NOUN'))],
#  [('duckling', 'NOUN'), (('mousseline', 'PRON'), ('mousseline', 'NOUN'))],
#  [(',', '.'), (('lobster', 'PRON'), ('lobster', 'NOUN'))],
#  [('lobster', 'NOUN'), (('consomme', 'PRON'), ('consomme', 'NOUN'))],
#  [(',', '.'), (('veal', 'PRON'), ('veal', 'NOUN'))],
#  [('veal', 'NOUN'), (('mignon', 'PRON'), ('mignon', 'NOUN'))],
#  [('and', 'CONJ'), (('chocolate', 'PRON'), ('chocolate', 'ADJ'))],
#  [('chocolate', 'ADJ'), (('terrine', 'PRON'), ('terrine', 'NOUN'))],
#  [('a', 'DET'), (('raspberry', 'PRON'), ('raspberry', 'NOUN'))],
#  [('raspberry', 'NOUN'), (('sauce', 'PRON'), ('sauce', 'NOUN'))],
#  [('how', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('.', '.'), (('Groups', 'PRON'), ('Groups', 'NOUN'))],
#  [('*', 'X'), (('advocating', 'PRON'), ('advocating', 'VERB'))],
#  [('policies', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('ignoring', 'VERB'),
#   (('discrimination', 'PRON'), ('discrimination', 'NOUN'))],
#  [('go', 'VERB'), (('through', 'ADP'), ('through', 'PRT'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [("'s", 'PRT'), (('offerings', 'PRON'), ('offerings', 'NOUN'))],
#  [('and', 'CONJ'), (('pricings', 'PRON'), ('pricings', 'NOUN'))],
#  [('and', 'CONJ'), (('non-U.S.', 'PRON'), ('non-U.S.', 'NOUN'))],
#  [('and', 'CONJ'), (('syndicate', 'PRON'), ('syndicate', 'NOUN'))],
#  [('often', 'ADV'), (('buys', 'PRON'), ('buys', 'VERB'))],
#  [('U.S.', 'NOUN'), (('grains', 'PRON'), ('grains', 'NOUN'))],
#  [('is', 'VERB'), (('overpriced', 'PRON'), ('overpriced', 'VERB'))],
#  [('overpriced', 'VERB'), (('*-99', 'PRON'), ('*-99', 'X'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('and', 'CONJ'), (('shopped', 'PRON'), ('shopped', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('3', 'NUM'), ('3', 'X'))],
#  [('*', 'X'), (('Send', 'PRON'), ('Send', 'VERB'))],
#  [('the', 'DET'), (('Antitrust', 'PRON'), ('Antitrust', 'NOUN'))],
#  [('Antitrust', 'NOUN'), (('Division', 'PRON'), ('Division', 'NOUN'))],
#  [('produce', 'VERB'), (('6.9', 'PRON'), ('6.9', 'NUM'))],
#  [('in', 'ADP'), (('1988-89', 'PRON'), ('1988-89', 'NUM'))]]

# %% [markdown]
# #### Before proceeding for dealing with unknown words, lets first see how many unknown words we have.
# #### Unknows words would be those words that are present in the test set but not in the train set.
# #### Those words the algorithm has not seen before.

# %%
# Unknown words 

test_vocabulary_set = set([t for t in test_tagged_words])

unknown_words = list(test_vocabulary_set - train_unique_words)
print("Total Unknown words: ", len(unknown_words))
print("\n")
print("Unknown Words: ", unknown_words)
# Out:
# Total Unknown words:  322
#
#
# Unknown Words:  ['parlors', 'discrimination', 'impudent', 'propagandizes', 'disarray', 'resilient', 'TRUST', 'lifes', 'shivers', 'alarmed', 'U.S.S.R.', 'sacks', 'sidelines', 'IMSAI', 'highest-pitched', 'evaporated', 'repay', 'Mather', 'built-from-kit', 'adequately', 'Choose', 'fiber', '*T*-190', 'disagrees', 'ministry', 'intertitles', '62.625', '8.64', 'valuations', 'cotton', 'invests', 'beleaguered', 'garden-variety', 'families', 'committees', 'Hollis', 'rebounding', 'Dynamics', '5.82', 'midyear', '154.2', 'Earns', 'fan', 'Bowman', '*-134', 'unstinting', 'compel', 'voluntary', 'pricings', 'lesions', 'keyboards', 'duckling', '83,206', 'non-U.S.', 'draws', 'outraged', 'Huxtable', 'bellwether', 'Marder', 'negatives', 'sneaked', 'CERTIFICATES', 'bench', 'shudders', 'wrists', '3.01', 'onslaught', 'folio', '11,390,000', 'raspberry', 'laser', 'Environmental', '1.18', 'argues', 'standpoint', 'singled', 'unofficial', 'school-improvement', '576', 'RBC', 'chocolate', 'Workers', 'Than', 'difficulty', 'Saul', 'Luce', 'Old-House', 'syndicate', 'Mercedes', 'READY', 'regrettable', 'procurement', 'hugging', '490', '2,050-passenger', '92.9', 'mousseline', 'Rill', 'rebels', 'stones', 'Works', 'Sol', 'Tube', 'Show', 'Dominion', 'eclectic', 'teaches', 'Eliminate', 'Bucking', 'scrounge', 'applicability', 'ensembles', '2.65', 'Fax', 'Foreigners', 'slated', 'consomme', 'mollified', 'complain', 'waiving', 'Hours', 'Protection', 'representatives', 'consisting', 'burlap', 'Division', 'confines', 'retard', 'Marc', 'shoring', 'emergencies', 'single-lot', 'drew', 'longtime', '737.5', 'treats', 'advocating', '7.63', 'patient', 'arbs', 'Shorter', 'mid-afternoon', 'poured', 'nominees', 'Holland', 'DEPOSIT', 'pools', 'boosting', 'TRIAL', 'productivity', 'downgraded', 'enraged', 'Social', 'upbeat', 'undercut', 'grains', 'attending', 'Underwoods', 'ventilated', '*T*-218', 'Proper', 'five-cent', 'Send', 'kidney', 'Dolphins', 'acetate', '*T*-153', 'McLeod', 'neat', 'Pty.', 'Composer', 'strain', '*T*-259', 'mechanically', 'Fellowship', 'Rothschild', 'moons', 'waited', '*-101', 'ugly', '5.6', '5.8', 'looked', 'Ogilvy', 'implant', '*T*-144', 'bass', 'LYNCH', 'petulant', 'passport', '*T*-249', 'Institutions', '260', 'video-viewing', 'Nicaraguan', 'wizards', 'behemoth', 'terrine', '*T*-236', 'advertised', 'sunny', 'overpriced', 'unconsolidated', 'departments', 'U.S.-backed', '126,000', 'offerings', 'hosted', 'Altair', 'NEW', 'shrug', 'renovated', 'symptoms', 'Garret', 'cease-fire', 'Fantasy', 'ex-dividend', 'gyrate', 'augment', '19-month-old', 'Lead', 'hottest', '93.9', 'overleveraged', 'lobster', 'Elisa', 'Groups', 'clouds', 'veal', 'cultivation', 'demobilize', 'classical', '*T*-189', 'ascendency', '1.19', 'shopped', '42.1', 'Anti-Deficiency', 'rounds', 'Roof', '*T*-67', 'struggle', 'immense', 'Skilled', 'bin', 'brain', 'characters', 'Ratings', 'mood', 'bounce', 'lungs', 'sauce', 'editions', 'envoy', 'avid', 'Christie', 'biannual', 'year-to-year', 'buys', '6.4', '396,000', 'apart', 'Antitrust', 'powwow', 'tempted', 'dust', '*-112', 'mignon', '6.9', 'ASSETS', '*-24', 'Scotia', 'viewers', 'attracts', 'Barbara', 'intriguing', 'hung', '1988-89', 'Earlham', 'soybeans', 'WPP', 'airplane', 'MERRILL', 'lifting', 'restaurant', 'ballroom', 'expired', 'exciting', 'Broken', 'recruiting', '*-155', 'computer-aided', 'agriculture', '*-163', 'U.S.-Japanese', 'descending', 'liberals', 'gradual', 'clothes', 'shirts', 'cushioned', 'morbidity', 'deprived', 'Smaby', '79', 'Dodger', 'ENERGY', '*-99', 'titans', '*T*-143', 'vitriolic', 'automation', 'ACCOUNT', 'satisfactorily', 'Hawaiian', 'laurels', 'downgrading', 'male-dominated', '8.06', 'Wilbur', 'four-year', 'Equivalents']

# %% [markdown]
# <font color = "green"><h3><b> Solve the problem of unknown words </b></h3></font>
# <font color = "green"><h3><b> Method 1 </b></h3></font>
#
#
# The default Vanilla viterbi algorithm achieved an accuracy of about 90.4%. This approx. 9% loss of accuracy was majorly due to the fact that when the algorithm encountered an unknown word (i.e. not present in the training set, such as 'Twitter'), it assigned an incorrect tag arbitrarily. This is because, for unknown words, the emission probabilities for all candidate tags are 0, so the algorithm arbitrarily chooses (the first) tag.
#
# Now lets see how we can minimize this loss by modifying the vanilla viterbi.
#
# If a word is not present in the training vocabulary (unknown word), its emission probability will be **ZERO**. In that case the state probability will inturn be zero. Thus in cases where the algorithm encounters a word which it has not see previously, we can omit the emission probability and only consider the transition probability.
#
# The algorithm can be modified to deal the case as below -
#
#
#
# <font color = "brown"><h4><b> If word in unknown then: --> consider only the transition_p (emission probability being 0) </b></h4></font>
# <font color = "brown"><h4><b> else: --> consider both the emission and transition probability.</b></h4></font>

# %%
# Modified Viterbi Heuristic
def Vanilla_Viterbi_for_Unknown_Words(words, train_bag = train_set_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            
            # modification to the original vanilla viterbi algorithm 
            # to consider unknown words
            if word not in train_unique_words:
                state_probability = transition_p
            else:
                state_probability = emission_p * transition_p
                
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
        
    return list(zip(words, state))

# %%
# tagging the test sentences
unknown_word_tagged_seq = Vanilla_Viterbi_for_Unknown_Words(test_tagged_words)

# accuracy
unknown_word_check = [i for i, j in zip(unknown_word_tagged_seq, test_run_base) if i == j]

optimized_viterbi_accuracy = len(unknown_word_check)/len(unknown_word_tagged_seq)

print("The accuracy of the Vanilla Viterbi Algorithm after modification to handle unknown words is: ", optimized_viterbi_accuracy)
# Out:
# The accuracy of the Vanilla Viterbi Algorithm after modification to handle unknown words is - 0.9408055329536208

# %% [markdown]
# We see the modified viterbi algorithm **performs better** than the original vanilla viterbi algorithm. The modified viterbi achieves an accuracy of (approx.) **94.44%** comapred to **90.4%** of the vanilla viterbi.
#
# Still there is a loss of approx. 6%.
#
# Now lets see if we can in reduce this loss further.
#
# <font color = "green"><h3><b> Lexicon and Rule-Based Models for POS Tagging </b></h3></font>
#
# <font color = "brown"><h3><b> Unigram Tagger </b></h3></font>

# %%
# Unigram Tagger

unigram_tagger = nltk.UnigramTagger(train_set)
unigram_tagger_accuracy = unigram_tagger.evaluate(test_set)
print("The accuracy of the Unigram Tagger is: ", unigram_tagger_accuracy)
# Out:
# The accuracy of the Unigram Tagger is:  0.9023596419853539

# %%
# patterns for tagging using a rule based regex tagger -

patterns = [
    (r'^[aA-zZ].*[0-9]+','NOUN'),      # Alpha Numeric
    (r'.*s$', 'NOUN'),                 # plural nouns
    (r'.*', 'NOUN'),                   # noun
    (r'.*\'s$', 'NOUN'),               # possessive nouns
    (r'.*ness$', 'NOUN'),
    (r'[aA-zZ]+(ed|ing|es)$', 'VERB'), # past tense, gerund, verb
    (r'.*ly$', 'ADV'),                 # adverb
    (r'^(0|([*|-|$].*))','X'),         # Any special character combination
    (r'.*ould$', 'X'),                 # modals
    (r'(The|the|A|a|An|an)$', 'DET'),  # determinant
    (r'^([0-9]|[aA-zZ])+\-[aA-zZ]*$','ADJ'),
    (r'.*able$', 'ADJ'),               # adjective like 100-megabytes 237-Seats
    (r'[0-9].?[,\/]?[0-9]*','NUM')     # Numbers 
    ]

# %%
# rule based RegexpTagger

rule_based_tagger = nltk.RegexpTagger(patterns)

# unigram tagger backed up by the rule-based tagger
rule_based_unigram_tagger = nltk.UnigramTagger(train_set, backoff = rule_based_tagger)

rule_based_unigram_tagger_accuracy = rule_based_unigram_tagger.evaluate(test_set)

print("Unigram Tagger backed up by the RegexpTagger accuracy: ", rule_based_unigram_tagger_accuracy)
# Out:
# Unigram Tagger backed up by the RegexpTagger accuracy:  0.9377542717656632

# %%
# Bigram tagger

bigram_tagger = nltk.BigramTagger(train_set, backoff = rule_based_unigram_tagger)
bigram_tagger.evaluate(test_set)
bigram_tagger_accuracy = bigram_tagger.evaluate(test_set)
print("Bigram Tagger backed up by the rule_based_unigram_tagger accuracy: ", bigram_tagger_accuracy)
# Out:
# Bigram Tagger backed up by the rule_based_unigram_tagger accuracy:  0.9399918633034988

# %%
# trigram tagger

trigram_tagger = nltk.TrigramTagger(train_set, backoff = bigram_tagger)
trigram_tagger.evaluate(test_set)
trigram_tagger_accuracy = trigram_tagger.evaluate(test_set)
print("Trigram Tagger backed up by the bigram_tagger accuracy: ", trigram_tagger_accuracy)
# Out:
# Trigram Tagger backed up by the bigram_tagger accuracy:  0.9391781936533767

# %% [markdown]
# <font color = "green"><h3><b> Method 2 </b></h3></font>
#
# We see that the Trigram Tagger backed up by the bigram tagger gives an accuracy of about 94%. Let's now try to modify the viterbi algorithm to use this trigram tagger as a back-off.
#
# When the viterbi algorithm is not able to tag an unknown word, it uses the rule-based tagger.

# %%
# A trigram tagger backed off by a rule based tagger.

def custom_trigram_tagger(word, train_set = train_set):
    
    patterns = [
    (r'[aA-zZ]+(ed|ing|es)$', 'VERB'), # past tense, gerun and verb

    (r'.*ly$', 'ADV'),                 # adverb
        
    (r'^([0-9]|[aA-zZ])+\-[aA-zZ]*$','ADJ'),  # adjective
    (r'.*ful$', 'ADJ'),                # adjective
    (r'.*able$', 'ADJ'),               # adjective
    (r'.*ous$', 'ADJ'),                # adjective
        
    (r'^[aA-zZ].*[0-9]+','NOUN'),     # Alpha Numeric
    (r'.*ness$', 'NOUN'),             # noun
    (r'.*\'s$', 'NOUN'),              # possessive nouns - words ending with 's
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'.*ment$', 'NOUN'),             # noun
    (r'.*ers$', 'NOUN'),              # noun
    (r'.*town$', 'NOUN'),             # noun
        
    (r'^(0|([*|-|$].*))','X'), # Any special character combination
    (r'.*ould$', 'X'),
        
    (r'(The|the|A|a|An|an|That|that|This|this|Those|those|These|these)$', 'DET'), # That/this/these/those belong to the category of Demonstrative determiners
    (r'[0-9].?[,\/]?[0-9]*','NUM'), # Numbers 
        
    (r'.*', 'NOUN')
    ]

    regex_based_tagger = nltk.RegexpTagger(patterns)

    # trigram backed up by the regex tagger
    trigram_regex_tagger = nltk.TrigramTagger(train_set, backoff = regex_based_tagger)
    
    return trigram_regex_tagger.tag_sents([[(word)]])

# %%
def viterbi_backedup_by_trigram_tagger(words, train_bag = train_set_tagged_words):
    state = []
    tag_set = list(set([pair[1] for pair in train_bag]))
    
    # use the trigram tagger backed up by the rule based tagger
    # for unknown words.
    for key, word in enumerate(words):
        if word not in train_unique_words:
            unknown_word_tag = custom_trigram_tagger(word)
            for sent in unknown_word_tag:
                for tup in sent:
                    state.append(tup[1])
        else:            
            p = [] 
            for tag in tag_set:
                if key == 0:
                    transition_p = tags_df.loc['.', tag]
                else:
                    transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
                emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
                state_probability = emission_p * transition_p    
                p.append(state_probability)
            
            pmax = max(p)
            # getting state for which probability is maximum
            state_max = tag_set[p.index(pmax)] 
            state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# <font color = "green"><h3><b> Evaluating tagging accuracy </b></h3></font>

# %%
# tagging the test sentences
viterbi_trigram_tagged_seq = viterbi_backedup_by_trigram_tagger(test_tagged_words)

# accuracy
viterbi_trigram_word_check = [i for i, j in zip(viterbi_trigram_tagged_seq, test_run_base) if i == j]

viterbi_trigram_accuracy = len(viterbi_trigram_word_check)/len(viterbi_trigram_tagged_seq)

print("Viterbi_backedup_by_trigram_tagger accuracy: ", viterbi_trigram_accuracy)
# Out:
# Viterbi_backedup_by_trigram_tagger accuracy:  0.9562652563059398

# %% [markdown]
# <font color = "green"><h3><b> Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm </b></h3></font>
#
# <font color = "brown"><h3><b> 1. Checking accuracy on test_train_split treebank dataset</b></h3></font>

# %%
acccuracy_data = [['Vanilla Viterbi', vanilla_viterbi_accuracy*100], 
                  ['Optimized Vanilla Viterbi', optimized_viterbi_accuracy*100], 
                  ['Unigram Tagger', unigram_tagger_accuracy*100],
                  ['Unigram + RegexpTagger', rule_based_unigram_tagger_accuracy*100],
                  ['Bigram Tagger + Unigram_tagger', bigram_tagger_accuracy*100],
                  ['Trigram Tagger + Bigram_tagger', trigram_tagger_accuracy*100],
                  ['Viterbi + Trigram_tagger', viterbi_trigram_accuracy*100]]

acccuracy_data_df = pd.DataFrame(acccuracy_data, columns = ['Tagging_Algorithm', 'Tagging_Accuracy'])

acccuracy_data_df.set_index('Tagging_Algorithm', drop = True, inplace = True)

acccuracy_data_df
# Out:
#                                 Tagging_Accuracy
# Tagging_Algorithm
# Vanilla Viterbi                        90.419040
# Optimized Vanilla Viterbi              94.080553
# Unigram Tagger                         90.235964
# Unigram + RegexpTagger                 93.775427
# Bigram Tagger + Unigram_tagger         93.999186
# Trigram Tagger + Bigram_tagger         93.917819
# Viterbi + Trigram_tagger               95.626526

# %%
acccuracy_data_df.plot.line(rot = 90, legend = False)

# %% [markdown]
# <font color = "brown"><h3><b> 2.  Next, lets check the tagging accuracies for the algorithm on the sample test sentences provided </b></h3></font>

# %%
sample_test_sentences = []
test_file = open(test_file_path, 'r')

for line in test_file:
    sample_test_sentences.append(line)
test_file.close()

# %%
sample_test_tokenized_sents = [word_tokenize(sent) for sent in sample_test_sentences]
sample_test_corpus_pos_tags = nltk.pos_tag_sents(sample_test_tokenized_sents, tagset = 'universal')
sample_test_corpus_pos_tags
# Out:
# [[('Android', 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('mobile', 'ADJ'),
#   ('operating', 'NOUN'),
#   ('system', 'NOUN'),
#   ('developed', 'VERB'),
#   ('by', 'ADP'),
#   ('Google', 'NOUN'),
#   ('.', '.')],
#  [('Android', 'NOUN'),
#   ('has', 'VERB'),
#   ('been', 'VERB'),
#   ('the', 'DET'),
#   ('best-selling', 'ADJ'),
#   ('OS', 'NOUN'),
#   ('worldwide', 'NOUN'),
#   ('on', 'ADP'),
#   ('smartphones', 'NOUN'),
#   ('since', 'ADP'),
#   ('2011', 'NUM'),
#   ('and', 'CONJ'),
#   ('on', 'ADP'),
#   ('tablets', 'NOUN'),
#   ('since', 'ADP'),
#   ('2013', 'NUM'),
#   ('.', '.')],
#  [('Google', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Twitter', 'NOUN'),
#   ('made', 'VERB'),
#   ('a', 'DET'),
#   ('deal', 'NOUN'),
#   ('in', 'ADP'),
#   ('2015', 'NUM'),
#   ('that', 'DET'),
#   ('gave', 'VERB'),
#   ('Google', 'NOUN'),
#   ('access', 'NOUN'),
#   ('to', 'PRT'),
#   ('Twitter', 'NOUN'),
#   ("'s", 'PRT'),
#   ('firehose', 'NOUN'),
#   ('.', '.')],
#  [('Twitter', 'NOUN'),
#   ('is', 'VERB'),
#   ('an', 'DET'),
#   ('online', 'ADJ'),
#   ('news', 'NOUN'),
#   ('and', 'CONJ'),
#   ('social', 'ADJ'),
#   ('networking', 'NOUN'),
#   ('service', 'NOUN'),
#   ('on', 'ADP'),
#   ('which', 'DET'),
#   ('users', 'NOUN'),
#   ('post', 'NOUN'),
#   ('and', 'CONJ'),
#   ('interact', 'NOUN'),
#   ('with', 'ADP'),
#   ('messages', 'NOUN'),
#   ('known', 'VERB'),
#   ('as', 'ADP'),
#   ('tweets', 'NOUN'),
#   ('.', '.')],
#  [('Before', 'ADP'),
#   ('entering', 'VERB'),
#   ('politics', 'NOUN'),
#   (',', '.'),
#   ('Donald', 'NOUN'),
#   ('Trump', 'NOUN'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('domineering', 'ADJ'),
#   ('businessman', 'NOUN'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('television', 'NOUN'),
#   ('personality', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('2018', 'NUM'),
#   ('FIFA', 'NOUN'),
#   ('World', 'NOUN'),
#   ('Cup', 'NOUN'),
#   ('is', 'VERB'),
#   ('the', 'DET'),
#   ('21st', 'NUM'),
#   ('FIFA', 'NOUN'),
#   ('World', 'NOUN'),
#   ('Cup', 'NOUN'),
#   (',', '.'),
#   ('an', 'DET'),
#   ('international', 'ADJ'),
#   ('football', 'NOUN'),
#   ('tournament', 'NOUN'),
#   ('contested', 'VERB'),
#   ('once', 'ADV'),
#   ('every', 'DET'),
#   ('four', 'NUM'),
#   ('years', 'NOUN'),
#   ('.', '.')],
#  [('This', 'DET'),
#   ('is', 'VERB'),
#   ('the', 'DET'),
#   ('first', 'ADJ'),
#   ('World', 'NOUN'),
#   ('Cup', 'NOUN'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('held', 'VERB'),
#   ('in', 'ADP'),
#   ('Eastern', 'NOUN'),
#   ('Europe', 'NOUN'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('11th', 'NUM'),
#   ('time', 'NOUN'),
#   ('that', 'ADP'),
#   ('it', 'PRON'),
#   ('has', 'VERB'),
#   ('been', 'VERB'),
#   ('held', 'VERB'),
#   ('in', 'ADP'),
#   ('Europe', 'NOUN'),
#   ('.', '.')],
#  [('Show', 'VERB'),
#   ('me', 'PRON'),
#   ('the', 'DET'),
#   ('cheapest', 'ADJ'),
#   ('round', 'NOUN'),
#   ('trips', 'NOUN'),
#   ('from', 'ADP'),
#   ('Dallas', 'NOUN'),
#   ('to', 'PRT'),
#   ('Atlanta', 'VERB')],
#  [('I', 'PRON'),
#   ('would', 'VERB'),
#   ('like', 'VERB'),
#   ('to', 'PRT'),
#   ('see', 'VERB'),
#   ('flights', 'NOUN'),
#   ('from', 'ADP'),
#   ('Denver', 'NOUN'),
#   ('to', 'PRT'),
#   ('Philadelphia', 'NOUN'),
#   ('.', '.')],
#  [('Show', 'VERB'),
#   ('me', 'PRON'),
#   ('the', 'DET'),
#   ('price', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('flights', 'NOUN'),
#   ('leaving', 'VERB'),
#   ('Atlanta', 'NOUN'),
#   ('at', 'ADP'),
#   ('about', 'ADV'),
#   ('3', 'NUM'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('afternoon', 'NOUN'),
#   ('and', 'CONJ'),
#   ('arriving', 'NOUN'),
#   ('in', 'ADP'),
#   ('San', 'NOUN'),
#   ('Francisco', 'NOUN'),
#   ('.', '.')],
#  [('NASA', 'NOUN'),
#   ('invited', 'VERB'),
#   ('social', 'ADJ'),
#   ('media', 'NOUN'),
#   ('users', 'NOUN'),
#   ('to', 'PRT'),
#   ('experience', 'VERB'),
#   ('the', 'DET'),
#   ('launch', 'NOUN'),
#   ('of', 'ADP'),
#   ('ICESAT-2', 'NOUN'),
#   ('Satellite', 'NOUN'),
#   ('.', '.')]]

# %%
# list of untagged words from the sample test data provided
sample_test_tagged_words = [tup[0] for sent in sample_test_corpus_pos_tags for tup in sent]


# list of tagged words
sample_test_test_run_base = [tup for sent in sample_test_corpus_pos_tags for tup in sent]

# %%
sample_test_tagged_words
# Out:
# ['Android',
#  'is',
#  'a',
#  'mobile',
#  'operating',
#  'system',
#  'developed',
#  'by',
#  'Google',
#  '.',
#  'Android',
#  'has',
#  'been',
#  'the',
#  'best-selling',
#  'OS',
#  'worldwide',
#  'on',
#  'smartphones',
#  'since',
#  '2011',
#  'and',
#  'on',
#  'tablets',
#  'since',
#  '2013',
#  '.',
#  'Google',
#  'and',
#  'Twitter',
#  'made',
#  'a',
#  'deal',
#  'in',
#  '2015',
#  'that',
#  'gave',
#  'Google',
#  'access',
#  'to',
#  'Twitter',
#  "'s",
#  'firehose',
#  '.',
#  'Twitter',
#  'is',
#  'an',
#  'online',
#  'news',
#  'and',
#  'social',
#  'networking',
#  'service',
#  'on',
#  'which',
#  'users',
#  'post',
#  'and',
#  'interact',
#  'with',
#  'messages',
#  'known',
#  'as',
#  'tweets',
#  '.',
#  'Before',
#  'entering',
#  'politics',
#  ',',
#  'Donald',
#  'Trump',
#  'was',
#  'a',
#  'domineering',
#  'businessman',
#  'and',
#  'a',
#  'television',
#  'personality',
#  '.',
#  'The',
#  '2018',
#  'FIFA',
#  'World',
#  'Cup',
#  'is',
#  'the',
#  '21st',
#  'FIFA',
#  'World',
#  'Cup',
#  ',',
#  'an',
#  'international',
#  'football',
#  'tournament',
#  'contested',
#  'once',
#  'every',
#  'four',
#  'years',
#  '.',
#  'This',
#  'is',
#  'the',
#  'first',
#  'World',
#  'Cup',
#  'to',
#  'be',
#  'held',
#  'in',
#  'Eastern',
#  'Europe',
#  'and',
#  'the',
#  '11th',
#  'time',
#  'that',
#  'it',
#  'has',
#  'been',
#  'held',
#  'in',
#  'Europe',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'cheapest',
#  'round',
#  'trips',
#  'from',
#  'Dallas',
#  'to',
#  'Atlanta',
#  'I',
#  'would',
#  'like',
#  'to',
#  'see',
#  'flights',
#  'from',
#  'Denver',
#  'to',
#  'Philadelphia',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'price',
#  'of',
#  'the',
#  'flights',
#  'leaving',
#  'Atlanta',
#  'at',
#  'about',
#  '3',
#  'in',
#  'the',
#  'afternoon',
#  'and',
#  'arriving',
#  'in',
#  'San',
#  'Francisco',
#  '.',
#  'NASA',
#  'invited',
#  'social',
#  'media',
#  'users',
#  'to',
#  'experience',
#  'the',
#  'launch',
#  'of',
#  'ICESAT-2',
#  'Satellite',
#  '.']

# %% [markdown]
# <font color = "green"><h3><b> 1. Testing the accuracy of Vanilla Viterbi on sample test data </b></h3></font>

# %%
# tagging the test sentences
sample_test_tagged_seq = Vanilla_Viterbi(sample_test_tagged_words)

# Let's check the accuracy of the vanilla viterbi algorithm
sample_test_check = [i for i, j in zip(sample_test_tagged_seq, sample_test_test_run_base) if i == j]

vanilla_viterbi_accuracy_on_sample_test_data = len(sample_test_check)/len(sample_test_tagged_seq)

print("Vanilla Viterbi accuracy on the sample test data: ", vanilla_viterbi_accuracy_on_sample_test_data)
# Out:
# Vanilla Viterbi accuracy on the sample test data:  0.7513812154696132

# %% [markdown]
# <font color = "green"><h3><b> 2. Testing the accuracy of Vanilla_Viterbi_for_Unknown_Words on sample test data </b></h3></font>

# %%
# tagging the test sentences
sample_test_unknown_word_tagged_seq = Vanilla_Viterbi_for_Unknown_Words(sample_test_tagged_words)

# accuracy
sample_test_unknown_word_check = [i for i, j in zip(sample_test_unknown_word_tagged_seq, sample_test_test_run_base) if i == j]

sample_test_optimized_viterbi_accuracy = len(sample_test_unknown_word_check)/len(sample_test_unknown_word_tagged_seq)

print("Vanilla_Viterbi_for_Unknown_Words accuracy on the sample test data:", sample_test_optimized_viterbi_accuracy)
# Out:
# Vanilla_Viterbi_for_Unknown_Words accuracy on the sample test data: 0.861878453038674

# %% [markdown]
# <font color = "green"><h3><b> 3. Testing the accuracy of viterbi_backedup_by_trigram_tagger on sample test data </b></h3></font>

# %%
# tagging the test sentences
sample_test_viterbi_trigram_tagged_seq = viterbi_backedup_by_trigram_tagger(sample_test_tagged_words)

# accuracy
sample_test_viterbi_trigram_check = [i for i, j in zip(sample_test_viterbi_trigram_tagged_seq, sample_test_test_run_base) if i == j]

sample_test_viterbi_trigram_accuracy = len(sample_test_viterbi_trigram_check)/len(sample_test_viterbi_trigram_tagged_seq)

print("Viterbi_backedup_by_trigram_tagger accuracy on the sample test data: ", sample_test_viterbi_trigram_accuracy)
# Out:
# Viterbi_backedup_by_trigram_tagger accuracy on the sample test data:  0.9281767955801105

# %% [markdown]
# <font color = "green"><h3><b> Comparing the accuracies of the 3 algorithm on sample test data </b></h3></font>

# %%
acccuracy_on_sample_test_data = [['Vanilla Viterbi', vanilla_viterbi_accuracy_on_sample_test_data*100], 
                  ['Optimized Vanilla Viterbi', sample_test_optimized_viterbi_accuracy*100], 
                  ['Viterbi + Trigram_tagger', sample_test_viterbi_trigram_accuracy*100]]

sample_test_data_acccuracy_df = pd.DataFrame(acccuracy_on_sample_test_data, columns = ['Tagging_Algorithm', 'Tagging_Accuracy'])

sample_test_data_acccuracy_df.set_index('Tagging_Algorithm', drop = True, inplace = True)

sample_test_data_acccuracy_df
# Out:
#                            Tagging_Accuracy
# Tagging_Algorithm
# Vanilla Viterbi                   75.138122
# Optimized Vanilla Viterbi         86.187845
# Viterbi + Trigram_tagger          92.817680

# %%
sample_test_data_acccuracy_df.plot.line(rot = 90, legend = False)

# %% [markdown]
# <font color = "green"><h3><b> List down cases which were incorrectly tagged by original POS tagger & got corrected by your modifications </b></h3></font>

# %%
# test sentences
    
test_sentence_1 = sample_test_sentences[0]
print(test_sentence_1)
# Out:
# Android is a mobile operating system developed by Google.

# %% [markdown]
# <font color = "green"><h3><b> Case - 1 </b></h3></font>

# %%
# test_sentence_1 = 'Android is a mobile operating system developed by Google.'

words_test_sentence_1 = nltk.word_tokenize(test_sentence_1)

# pos tags with Vanilla_Viterbi
pos_tagged_sequence_with_vanilla_viterbi = Vanilla_Viterbi(words_test_sentence_1)
print("Tagging sequence with Vanilla_Viterbi -\n\n", pos_tagged_sequence_with_vanilla_viterbi)

print('\n')
print('='*127)

# pos tags with viterbi_backedup_by_trigram_tagger
pos_tagged_sequence_with_viterbi_trigram = viterbi_backedup_by_trigram_tagger(words_test_sentence_1)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", pos_tagged_sequence_with_viterbi_trigram)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('Android', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'PRON'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.')]

# %%
cols = ['vanilla_viterbi_tags', 'viterbi_trigram_tags_with_corrections']
tags_correction_df_1 = pd.DataFrame(columns = cols)
tags_correction_df_1 = tags_correction_df_1.fillna(0)

tags_correction_df_1.vanilla_viterbi_tags = [tup for tup in pos_tagged_sequence_with_vanilla_viterbi]
tags_correction_df_1.viterbi_trigram_tags_with_corrections = [tup for tup in pos_tagged_sequence_with_viterbi_trigram]

tags_correction_df_1
# Out:
#   vanilla_viterbi_tags viterbi_trigram_tags_with_corrections
# 0      (Android, PRON)                       (Android, NOUN)
# 1           (is, VERB)                            (is, VERB)
# 2             (a, DET)                              (a, DET)
# 3        (mobile, ADJ)                         (mobile, ADJ)
# 4    (operating, NOUN)                     (operating, NOUN)
# 5       (system, NOUN)                        (system, NOUN)
# 6    (developed, VERB)                     (developed, VERB)
# 7            (by, ADP)                             (by, ADP)
# 8       (Google, PRON)                        (Google, NOUN)
# 9               (., .)                                (., .)

# %% [markdown]
# #### As we see above in the sample test sentence 1 the word 'Android' was tagged as PRT by vanilla viterbi. The modified algorithm of viterbi backed up by trigram tagger corrected this and tagged 'Android' as NOUN.

# %% [markdown]
# <font color = "green"><h3><b> Case - 2 </b></h3></font>

# %%
# test_sentence_6 = 'The 2018 FIFA World Cup is the 21st FIFA World Cup, 
#                   an international football tournament contested once every four years.'

words_test_sentence_6 = nltk.word_tokenize(test_sentence_6)

# pos tags with Vanilla_Viterbi
pos_tagged_sequence_with_vanilla_viterbi_6 = Vanilla_Viterbi(words_test_sentence_6)
print("Tagging sequence with Vanilla_Viterbi -\n\n", pos_tagged_sequence_with_vanilla_viterbi_6)

print('\n')
print('-'*120)

# pos tags with viterbi_backedup_by_trigram_tagger
pos_tagged_sequence_with_viterbi_trigram_6 = viterbi_backedup_by_trigram_tagger(words_test_sentence_6)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", pos_tagged_sequence_with_viterbi_trigram_6)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('The', 'DET'), ('2018', 'PRON'), ('FIFA', 'PRON'), ('World', 'NOUN'), ('Cup', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'PRON'), ('FIFA', 'PRON'), ('World', 'NOUN'), ('Cup', 'PRON'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'PRON'), ('contested', 'PRON'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('The', 'DET'), ('2018', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'VERB'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.')]

# %%
tags_correction_df_6 = pd.DataFrame(columns = cols)
tags_correction_df_6 = tags_correction_df_6.fillna(0)

tags_correction_df_6.vanilla_viterbi_tags = [tup for tup in pos_tagged_sequence_with_vanilla_viterbi_6]
tags_correction_df_6.viterbi_trigram_tags_with_corrections = [tup for tup in pos_tagged_sequence_with_viterbi_trigram_6]

tags_correction_df_6
# Out:
#     vanilla_viterbi_tags viterbi_trigram_tags_with_corrections
# 0             (The, DET)                            (The, DET)
# 1           (2018, PRON)                           (2018, NUM)
# 2           (FIFA, PRON)                          (FIFA, NOUN)
# 3          (World, NOUN)                         (World, NOUN)
# 4            (Cup, PRON)                           (Cup, NOUN)
# 5             (is, VERB)                            (is, VERB)
# 6             (the, DET)                            (the, DET)
# 7           (21st, PRON)                           (21st, NUM)
# 8           (FIFA, PRON)                          (FIFA, NOUN)
# 9          (World, NOUN)                         (World, NOUN)
# 10           (Cup, PRON)                           (Cup, NOUN)
# 11                (,, .)                                (,, .)
# 12             (an, DET)                             (an, DET)
# 13  (international, ADJ)                  (international, ADJ)
# 14      (football, NOUN)                      (football, NOUN)
# 15    (tournament, PRON)                    (tournament, NOUN)
# 16     (contested, PRON)                     (contested, VERB)
# 17           (once, ADV)                           (once, ADV)
# 18          (every, DET)                          (every, DET)
# 19           (four, NUM)                           (four, NUM)
# 20         (years, NOUN)                         (years, NOUN)
# 21                (., .)                                (., .)

# %% [markdown]
# #### As we see above in the sample test sentence 6 the following words were incorrectly tagged by the vanilla viterbi algorithm -  '2018' - PRT, 'FIFA' - PRT, 'Cup' - PRT, '21st' - PRT, 'tournament' - PRT, 'contested' - PRT.
#
# #### The above words were corrected by viterbi backed up by the trigram tagger. The corrections were made as - '2018' - NUM, 'FIFA' - NOUN, 'Cup' - NOUN, '21st' - NUM, 'tournament' - NOUN, 'contested' - VERB.

# %% [markdown]
# <font color = "green"><h3><b> Case - 3 </b></h3></font>

# %%
# test_sentence_8 = 'Show me the cheapest round trips from Dallas to Atlanta'

words_test_sentence_8 = nltk.word_tokenize(test_sentence_8)

# pos tags with Vanilla_Viterbi
pos_tagged_sequence_with_vanilla_viterbi_8 = Vanilla_Viterbi(words_test_sentence_8)
print("Tagging sequence with Vanilla_Viterbi -\n\n", pos_tagged_sequence_with_vanilla_viterbi_8)

print('\n')
print('-'*120)

# pos tags with viterbi_backedup_by_trigram_tagger
pos_tagged_sequence_with_viterbi_trigram_8 = viterbi_backedup_by_trigram_tagger(words_test_sentence_8)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", pos_tagged_sequence_with_viterbi_trigram_8)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('Show', 'PRON'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'PRON'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN')]

# %%
tags_correction_df_8 = pd.DataFrame(columns = cols)
tags_correction_df_8 = tags_correction_df_8.fillna(0)

tags_correction_df_8.vanilla_viterbi_tags = [tup for tup in pos_tagged_sequence_with_vanilla_viterbi_8]
tags_correction_df_8.viterbi_trigram_tags_with_corrections = [tup for tup in pos_tagged_sequence_with_viterbi_trigram_8]

tags_correction_df_8
# Out:
#   vanilla_viterbi_tags viterbi_trigram_tags_with_corrections
# 0         (Show, PRON)                          (Show, NOUN)
# 1           (me, PRON)                            (me, PRON)
# 2           (the, DET)                            (the, DET)
# 3      (cheapest, ADJ)                       (cheapest, ADJ)
# 4        (round, NOUN)                         (round, NOUN)
# 5        (trips, PRON)                         (trips, NOUN)
# 6          (from, ADP)                           (from, ADP)
# 7       (Dallas, NOUN)                        (Dallas, NOUN)
# 8            (to, PRT)                             (to, PRT)
# 9      (Atlanta, NOUN)                       (Atlanta, NOUN)

# %% [markdown]
# #### As we see in the sample test sentence 8, the vanilla viterbi tagged 'trips' as PRT. This was corrected by the modified viterbi algorithm (backed up by the trigram tagger) and tagged as NOUN.
# #### Now lets see the tags and corrections for all the sample test sentences with both the methods.
#
# #### Method 1 - We used only the transition probability for unknown words.
# #### Method 2 - We used the viterbi algorithm and backed it up with the trigram tagger which was inturn backed up by the rule based regex tagger.

# %%
# Default Vanilla Viterbi
# pos tags with Vanilla_Viterbi
sample_test_tagged_sequence_with_vanilla_viterbi = Vanilla_Viterbi(sample_test_tagged_words)
print("Tagging sequence with Vanilla_Viterbi -\n\n", sample_test_tagged_sequence_with_vanilla_viterbi)

print('\n')
print('-'*120)

# Method 1 - pos tags with Vanilla_Viterbi_for_Unknown_Words
sample_test_tagged_sequence_unknown_words = Vanilla_Viterbi_for_Unknown_Words(sample_test_tagged_words)
print("Tagging sequence with viterbi using only transition probability for unknown words -\n\n", 
      sample_test_tagged_sequence_unknown_words)

print('\n')
print('-'*120)

# Method 2 - pos tags with viterbi_backedup_by_trigram_tagger
sample_test_tagged_sequence_with_viterbi_trigram = viterbi_backedup_by_trigram_tagger(sample_test_tagged_words)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", sample_test_tagged_sequence_with_viterbi_trigram)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('Android', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'PRON'), ('.', '.'), ('Android', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'PRON'), ('worldwide', 'PRON'), ('on', 'ADP'), ('smartphones', 'PRON'), ('since', 'ADP'), ('2011', 'PRON'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'PRON'), ('.', '.'), ('Google', 'PRON'), ('and', 'CONJ'), ('Twitter', 'PRON'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'PRON'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'PRON'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'PRON'), ("'s", 'VERB'), ('firehose', 'PRON'), ('.', '.'), ('Twitter', 'PRON'), ('is', 'VERB'), ('an', 'DET'), ('online', 'PRON'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'PRON'), ('with', 'ADP'), ('messages', 'PRON'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'PRON'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'PRON'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'PRON'), ('.', '.'), ('The', 'DET'), ('2018', 'PRON'), ('FIFA', 'PRON'), ('World', 'NOUN'), ('Cup', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'PRON'), ('FIFA', 'PRON'), ('World', 'NOUN'), ('Cup', 'PRON'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'PRON'), ('contested', 'PRON'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'PRON'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'PRON'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'PRON'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'PRON'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'PRON'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'PRON'), ('invited', 'PRON'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'PRON'), ('Satellite', 'PRON'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi using only transition probability for unknown words -
#
#  [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'DET'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'DET'), ('since', 'ADP'), ('2011', 'DET'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'DET'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'DET'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'X'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'VERB'), ("'s", 'PRT'), ('firehose', 'VERB'), ('.', '.'), ('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'DET'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'DET'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'NOUN'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.'), ('The', 'DET'), ('2018', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'NOUN'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'NOUN'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'NOUN'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'DET'), ('Satellite', 'NOUN'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'VERB'), ('since', 'ADP'), ('2011', 'NUM'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'NUM'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'NUM'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'NOUN'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'NOUN'), ("'s", 'PRT'), ('firehose', 'NOUN'), ('.', '.'), ('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'VERB'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'NOUN'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'VERB'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.'), ('The', 'DET'), ('2018', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'VERB'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'VERB'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'VERB'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'NOUN'), ('Satellite', 'NOUN'), ('.', '.')]

# %%
# A dataframe showing - 
# 1. the actual tags using nltk.pos_tag_sent
# 2. words as tagged by vanilla viterbi
# 3. words as tagged by Vanilla_Viterbi_for_Unknown_Words - METHOD - 1
# 4. words as tagged by viterbi_backedup_by_trigram_tagger - METHOD - 2

cols1 = ['actual_tags', 'as_tagged_by_vanilla_viterbi', 'as_tagged_by_Vanilla_Viterbi_for_Unknown_Words',
            'as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger']

tags_comparison_df = pd.DataFrame(columns = cols1)
tags_comparison_df = tags_comparison_df.fillna(0)

# Actual tags
tags_comparison_df.actual_tags = [tup for tup in sample_test_test_run_base]

# tags by vanilla viterbi
tags_comparison_df.as_tagged_by_vanilla_viterbi = [tup for tup in sample_test_tagged_sequence_with_vanilla_viterbi]

# tags by Vanilla_Viterbi_for_Unknown_Words - METHOD - 1
tags_comparison_df.as_tagged_by_Vanilla_Viterbi_for_Unknown_Words = [tup for tup in sample_test_tagged_sequence_unknown_words]

# tags by viterbi_backedup_by_trigram_tagger - METHOD - 2
tags_comparison_df.as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger = [tup for tup in 
                                                                            sample_test_tagged_sequence_with_viterbi_trigram]

tags_comparison_df[tags_comparison_df.as_tagged_by_vanilla_viterbi != 
                   tags_comparison_df.as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger]
# Out:
#              actual_tags as_tagged_by_vanilla_viterbi  \
# 0        (Android, NOUN)              (Android, PRON)
# 8         (Google, NOUN)               (Google, PRON)
# 10       (Android, NOUN)              (Android, PRON)
# 15            (OS, NOUN)                   (OS, PRON)
# 16     (worldwide, NOUN)            (worldwide, PRON)
# 18   (smartphones, NOUN)          (smartphones, PRON)
# 20           (2011, NUM)                 (2011, PRON)
# 25           (2013, NUM)                 (2013, PRON)
# 27        (Google, NOUN)               (Google, PRON)
# 29       (Twitter, NOUN)              (Twitter, PRON)
# 34           (2015, NUM)                 (2015, PRON)
# 37        (Google, NOUN)               (Google, PRON)
# 40       (Twitter, NOUN)              (Twitter, PRON)
# 41             ('s, PRT)                   ('s, VERB)
# 42      (firehose, NOUN)             (firehose, PRON)
# 44       (Twitter, NOUN)              (Twitter, PRON)
# 47         (online, ADJ)               (online, PRON)
# 58      (interact, NOUN)             (interact, PRON)
# 60      (messages, NOUN)             (messages, PRON)
# 63        (tweets, NOUN)               (tweets, PRON)
# 73    (domineering, ADJ)          (domineering, PRON)
# 78   (personality, NOUN)          (personality, PRON)
# 81           (2018, NUM)                 (2018, PRON)
# 82          (FIFA, NOUN)                 (FIFA, PRON)
# 84           (Cup, NOUN)                  (Cup, PRON)
# 87           (21st, NUM)                 (21st, PRON)
# 88          (FIFA, NOUN)                 (FIFA, PRON)
# 90           (Cup, NOUN)                  (Cup, PRON)
# 95    (tournament, NOUN)           (tournament, PRON)
# 96     (contested, VERB)            (contested, PRON)
# 107          (Cup, NOUN)                  (Cup, PRON)
# 126         (Show, VERB)                 (Show, PRON)
# 131        (trips, NOUN)                (trips, PRON)
# 147         (Show, VERB)                 (Show, PRON)
# 163     (arriving, NOUN)             (arriving, PRON)
# 168         (NASA, NOUN)                 (NASA, PRON)
# 169      (invited, VERB)              (invited, PRON)
# 178     (ICESAT-2, NOUN)             (ICESAT-2, PRON)
# 179    (Satellite, NOUN)            (Satellite, PRON)
#
#     as_tagged_by_Vanilla_Viterbi_for_Unknown_Words  \
# 0                                  (Android, NOUN)
# 8                                    (Google, DET)
# 10                                 (Android, NOUN)
# 15                                      (OS, NOUN)
# 16                               (worldwide, NOUN)
# 18                              (smartphones, DET)
# 20                                     (2011, DET)
# 25                                     (2013, DET)
# 27                                  (Google, NOUN)
# 29                                 (Twitter, NOUN)
# 34                                     (2015, DET)
# 37                                     (Google, X)
# 40                                 (Twitter, VERB)
# 41                                       ('s, PRT)
# 42                                (firehose, VERB)
# 44                                 (Twitter, NOUN)
# 47                                  (online, NOUN)
# 58                                (interact, NOUN)
# 60                                 (messages, DET)
# 63                                   (tweets, DET)
# 73                             (domineering, NOUN)
# 78                             (personality, NOUN)
# 81                                    (2018, NOUN)
# 82                                    (FIFA, NOUN)
# 84                                     (Cup, NOUN)
# 87                                    (21st, NOUN)
# 88                                    (FIFA, NOUN)
# 90                                     (Cup, NOUN)
# 95                              (tournament, NOUN)
# 96                               (contested, NOUN)
# 107                                    (Cup, NOUN)
# 126                                   (Show, NOUN)
# 131                                  (trips, NOUN)
# 147                                   (Show, NOUN)
# 163                               (arriving, NOUN)
# 168                                   (NASA, NOUN)
# 169                                (invited, NOUN)
# 178                                (ICESAT-2, DET)
# 179                              (Satellite, NOUN)
#
#     as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger
# 0                                      (Android, NOUN)
# 8                                       (Google, NOUN)
# 10                                     (Android, NOUN)
# 15                                          (OS, NOUN)
# 16                                   (worldwide, NOUN)
# 18                                 (smartphones, VERB)
# 20                                         (2011, NUM)
# 25                                         (2013, NUM)
# 27                                      (Google, NOUN)
# 29                                     (Twitter, NOUN)
# 34                                         (2015, NUM)
# 37                                      (Google, NOUN)
# 40                                     (Twitter, NOUN)
# 41                                           ('s, PRT)
# 42                                    (firehose, NOUN)
# 44                                     (Twitter, NOUN)
# 47                                      (online, NOUN)
# 58                                    (interact, NOUN)
# 60                                    (messages, VERB)
# 63                                      (tweets, NOUN)
# 73                                 (domineering, VERB)
# 78                                 (personality, NOUN)
# 81                                         (2018, NUM)
# 82                                        (FIFA, NOUN)
# 84                                         (Cup, NOUN)
# 87                                         (21st, NUM)
# 88                                        (FIFA, NOUN)
# 90                                         (Cup, NOUN)
# 95                                  (tournament, NOUN)
# 96                                   (contested, VERB)
# 107                                        (Cup, NOUN)
# 126                                       (Show, NOUN)
# 131                                      (trips, NOUN)
# 147                                       (Show, NOUN)
# 163                                   (arriving, VERB)
# 168                                       (NASA, NOUN)
# 169                                    (invited, VERB)
# 178                                   (ICESAT-2, NOUN)
# 179                                  (Satellite, NOUN)

# %% [markdown]
# # Conclusion -
#
# #### Thus we see that most of the words that were incorrectly tagged by the vanilla viterbi algorithm were corrected by the viterbi algorithm backed up by the trigram tagger.
#
# **In this analysis we used 2 modification techniques for the original vanilla viterbi -**
#
# #### Method 1 -
#     - We used only the transition probability for unknown words.
#     - This method showed an increase in the accuracy (94.4%) but still had some incorrect classification.
#
#     - The accuracy could be increased further and we turned two a second modification in method-2 below.
#
# #### Method 2 -
#     - We used the viterbi algorithm and backed it up with the trigram tagger which was inturn backed up by the rule based
#     regex tagger.
#     - This gave us an accuracy of 95.82% on the test data.
#     - Also on testing this model on the provided sample test data, it achieved an accuracy of 92.81% and comes out to be
#     the winner.

# %%
inv_type = 'Test'

# %%
print(f"Ideal investment type for Spark Funds is: {inv_type}")
# Out:
# Ideal investment type for Spark Funds is: Test
